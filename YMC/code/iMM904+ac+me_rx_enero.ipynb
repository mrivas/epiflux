# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import cobra
from cobra import Model, Reaction, Metabolite
from cobra.io import load_matlab_model, write_sbml_model
model= cobra.io.read_sbml_model("iMM904.xml")
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %%
#Agregar rx 1 
R1 = Reaction('cit_nt')
R1.name = 'citrate transport nuclear'
R1.subsystem = 'transport nuclear'
R1.lower_bound = -1000.  # This is the default
R1.upper_bound = 1000.  # This is the default

#Agregar rx 2 
R2 = Reaction('oaa_nt')
R2.name = 'oxaloacetate transport nuclear'
R2.subsystem = 'transport nuclear'
R2.lower_bound = -1000.  # This is the default
R2.upper_bound = 1000.  # This is the default

#Agregar rx 3 acl_n: atp_n + cit_n + coa_n --> accoa_n + adp_n + oaa_n + pi_n
R3 = Reaction('acl_n')
R3.name = 'ATP-Citrate lyase, nuclear'
R3.subsystem = 'ACLY'
R3.lower_bound = 0.  # This is the default
R3.upper_bound = 1000.  # This is the default

#Agregar rx 4 PACYL: accoa_n + prot_n --> protac_n + coa_n 
R4 = Reaction('PACYL')
R4.name = 'PACYL'
R4.subsystem = 'Acetylation protein'
R4.lower_bound = 0.  # This is the default
R4.upper_bound = 1000.  # This is the default

#Agregar rx 5 EX_PAC: prot_ac_n -->  
R5 = Reaction('EX_PAC')
R5.name = 'Protein acetylation exchange'
R5.subsystem = 'acetylation protein exchange'
R5.lower_bound = 0.  # This is the default
R5.upper_bound = 1000.  # This is the default

#Agregar rx 6 EX_P    --> prot_n
R6 = Reaction('EX_protein_ac')
R6.name = 'Nuclear protein consume reaction'
R6.subsystem = 'nuclear protein'
R6.lower_bound = 0.  # This is the default
R6.upper_bound = 1000.  # This is the default

#Agregar rx 7 h_n    ⇌  h_n
R7 = Reaction('h_n')
R7.name = 'H+'
R7.subsystem = 'n - nucleus'
R7.lower_bound = -1000.  # This is the default
R7.upper_bound = 1000.  # This is the default

#Agregar rx 10 HCYS_nt: hcys__L_c ⇌ hcys__L_h 
R8 = Reaction('HCYS_nt')
R8.name = 'Homocysteine transport nuclear'
R8.subsystem = 'Transport, Nuclear'
R8.lower_bound = -1000.  # This is the default
R8.upper_bound = 1000.  # This is the default

#Agregar rx 11 AHCYS_nt: ahcys_n⇌ ahcys_c
R9 = Reaction('AHCYS_nt')
R9.name = 'S-adenosyl-L-homocysteine transport nucleus'
R9.subsystem = ''
R9.lower_bound = -1000.  # This is the default
R9.upper_bound = 1000.  # This is the default

#Agregar rx 12 AMETtn: amet_c ⇌ amet_n
R10 = Reaction('AMETtn')
R10.name = 'S-Adenosyl-L-methionine transport, nucleus'
R10.subsystem = 'Transport, Nuclear'
R10.lower_bound = -1000.  # This is the default
R10.upper_bound = 1000.  # This is the default

#Agregar rx 13 HCYSMTn: amet_n + hcys__L_n → ahcys_n + h_n + met__L_n 
R11 = Reaction('HCYSMT_n')
R11.name = 'Homocysteine S-methyltransferase'
R11.subsystem = 'S_Alanine_and_Aspartate_Metabolism'
R11.lower_bound = 0.  # This is the default
R11.upper_bound = 1000.  # This is the default

#Agregar rx 14 PMETHYL: amet_n + hcys__L_n + prot_n --> prot2_me_n + h_n + ahcys_n
R12 = Reaction('PMETHYL')
R12.name = 'PMETHYL'
R12.subsystem = ''
R12.lower_bound = 0.  # This is the default
R12.upper_bound = 1000.  # This is the default

#Agregar rx 15 EX_PME: prot_me_n -->  
R13 = Reaction('EX_PME')
R13.name = 'Protein methylation exchange'
R13.subsystem = 'Methylation exchange'
R13.lower_bound = 0.  # This is the default
R13.upper_bound = 1000.  # This is the default

#Agregar rx 14 EX_P2    --> prot2_n
R14 = Reaction('EX_protein_me')
R14.name = 'Nuclear protein consume reaction'
R14.subsystem = 'nuclear protein'
R14.lower_bound = 0.  # This is the default
R14.upper_bound = 1000.  # This is the default

# %%
#Metabolites
cit_n= Metabolite(
    'cit_n',
    formula='C6H5O7',
    name='Citrate',
    compartment='n')

cit_c= Metabolite(
    'cit_c',
    formula='C6H5O7',
    name='Citrate',
    compartment='c')

oaa_n= Metabolite(
    'oaa_n',
    formula='C4H2O5',
    name='Oxaloacetate',
    compartment='n')

coa_n= Metabolite(
    'coa_n',
    formula='C21H32N7O16P3S',
    name='Coenzyme A',
    compartment='n')

accoa_n= Metabolite(
    'accoa_n',
    formula='C23H34N7O17P3S',
    name='Acetyl-CoA',
    compartment='n')

accoa_c= Metabolite(
    'accoa_c',
    formula='C23H34N7O17P3S',
    name='Acetyl-CoA',
    compartment='c')

coa_c= Metabolite(
    'coa_c',
    formula='C21H32N7O16P3S',
    name='Coenzyme A',
    compartment='c')

oaa_c= Metabolite(
    'oaa_c',
    formula='C4H2O5',
    name='Oxaloacetate',
    compartment='c')

atp_n= Metabolite(
    'atp_n',
    formula='C10H12N5O13P3',
    name='atp',
    compartment='n')

adp_n= Metabolite(
    'adp_n',
    formula='C10H12N5O10P2',
    name='adp',
    compartment='n')

pi_n= Metabolite(
    'pi_n',
    formula='HO4P',
    name='Phosphate',
    compartment='n')

prot_n= Metabolite(
    'prot_n',
    formula='',
    name='Protein nucleus',
    compartment='n')

prot_ac_n= Metabolite(
    'prot_ac_n',
    formula='',
    name='Protein acetilation nucleus',
    compartment='n')


o2_n=Metabolite(
    'o2_n',
    formula='O2',
    name='O2',
    compartment='n')

s_n=Metabolite(
    's_n',
    formula='S',
    name='Sulfur',
    compartment='n')

so2_n=Metabolite(
    'so2_n',
    formula='SO2',
    name='Sulfur dioxide',
    compartment='n')

co2_n=Metabolite(
    'co2_n',
    formula='CO2',
    name='CO2',
    compartment='n')

amet_e=Metabolite(
    'amet_e',
    formula='C15H23N6O5S',
    name='S-Adenosyl-L-methionine',
    compartment='e')

amet_c=Metabolite(
    'amet_c',
    formula='C15H23N6O5S',
    name='S-Adenosyl-L-methionine',
    compartment='c')

amet_n=Metabolite(
    'amet_n',
    formula='C15H23N6O5S',
    name='S-Adenosyl-L-methionine',
    compartment='n')

h_c=Metabolite(
    'h_c',
    formula='H+',
    name='H+',
    compartment='c')

h_n=Metabolite(
    'h_n',
    formula='H+',
    name='H+',
    compartment='n')
 
hcys__L_n=Metabolite(
    'hcys__L_n',
    formula='C4H9NO2S',
    name='L-Homocysteine',
    compartment='n')

hcys__L_c=Metabolite(
    'hcys__L_c',
    formula='C4H9NO2S',
    name='L-Homocysteine',
    compartment='c')

ahcys_n=Metabolite(
    'ahcys_n',
    formula='C14H20N6O5S',
    name='S-Adenosyl-L-homocysteine',
    compartment='n')

ahcys_c=Metabolite(
    'ahcys_c',
    formula='C14H20N6O5S',
    name='S-Adenosyl-L-homocysteine',
    compartment='c')

met__L_n=Metabolite(
    'met__L_n',
    formula='C5H11NO2S',
    name='L-Methionine',
    compartment='n')

prot2_me_n= Metabolite(
    'prot2_me_n',
    formula='',
    name='Protein methylation nucleus',
    compartment='n')

prot2_n= Metabolite(
    'prot2_n',
    formula='',
    name='Protein nucleus',
    compartment='n')

# %%
#Agregar metabolitos a la rx.
R1.add_metabolites({ 
    cit_n: -1.0, 
    cit_c: 1.0, 
})

#oaa_n ⇌ oaa_c
R2.add_metabolites({ 
    oaa_n: -1.0, 
    oaa_c: 1.0, 
})

#atp_n + cit_n + coa_n --> accoa_n + adp_n + oaa_n + pi_n
R3.add_metabolites({ 
    atp_n: -1.0, 
    cit_n: -1.0, 
    coa_n: -1.0,
    accoa_n: 1.0,
    adp_n: 1.0,
    oaa_n: 1.0,
    pi_n: 1.0,
})

#R4.reaction  accoa_n + prot_n --> protac_n + coa_n
R4.add_metabolites({ 
    accoa_n: -1.0, 
    prot_n: -1.0, 
    prot_ac_n: 1.0,
    coa_n: 1.0,
})


#protac_n -->  
R5.add_metabolites({ 
    prot_ac_n: -1.0, 

})

#    --> prot_n
R6.add_metabolites({ 
    prot_n: 1.0, 

})

#h_n
R7.add_metabolites({ 
    h_n: -1.0,
    h_c: 1.0,

})

#HCYS_nt: hcys__L_n ⇌ hcys__L_c
R8.add_metabolites({ 
    hcys__L_n: -1.0, 
    hcys__L_c: 1.0,

})

#AHCYS_nt: ahcys_n⇌ ahcys_c    
R9.add_metabolites({
    ahcys_n: -1.0,
    ahcys_c: 1.0, 

})

#AMETtn: amet_c ⇌ amet_n
R10.add_metabolites({
    amet_c: -1.0,
    amet_n: 1.0, 

})
#HCYSMT_n: amet_n + hcys__L_n → ahcys_n + h_n + met__L_n 
R11.add_metabolites({
    amet_n: -1.0,
    hcys__L_n: -1.0,
    ahcys_n: 1.0,
    h_n: 1.0,
    met__L_n: 1.0, 


})

#PMETHYL: amet_n + hcys__L_n + prot2_n --> ahcys_n + h_n + prot_me_n
R12.add_metabolites({
    amet_n: -1.0,
    hcys__L_n: -1.0,
    prot2_n: -1.0,
    ahcys_n: 1.0,
    h_n: 1.0,
    prot2_me_n: 1.0, 


})

#EX_PME: prot_me_n -->
R13.add_metabolites({ 
    prot2_me_n: -1.0, 

})

#    --> prot2_n
R14.add_metabolites({ 
    prot2_n: 1.0, 

})

# %%
print(R1)
print(R2)
print(R3)
print(R4)
print(R5)
print(R6)
print(R7)
print(R8)
print(R9)
print(R10)
print(R11)
print(R12)
print(R13)
print(R14)
# Out:
# cit_nt: cit_n <=> cit_c
# oaa_nt: oaa_n <=> oaa_c
# acl_n: atp_n + cit_n + coa_n --> accoa_n + adp_n + oaa_n + pi_n
# PACYL: accoa_n + prot_n --> coa_n + prot_ac_n
# EX_PAC: prot_ac_n -->
# EX_protein_ac:  --> prot_n
# h_n: h_n <=> h_c
# HCYS_nt: hcys__L_n <=> hcys__L_c
# AHCYS_nt: ahcys_n <=> ahcys_c
# AMETtn: amet_c <=> amet_n
# HCYSMT_n: amet_n + hcys__L_n --> ahcys_n + h_n + met__L_n
# PMETHYL: amet_n + hcys__L_n + prot2_n --> ahcys_n + h_n + prot2_me_n
# EX_PME: prot2_me_n -->
# EX_protein_me:  --> prot2_n

# %%
R1.gene_reaction_rule =''
R2.gene_reaction_rule =''
R3.gene_reaction_rule ='(47_AT1 or 47_AT2)'
R4.gene_reaction_rule =''
R5.gene_reaction_rule =''
R6.gene_reaction_rule =''
R7.gene_reaction_rule =''
R8.gene_reaction_rule =''
R9.gene_reaction_rule =''
R10.gene_reaction_rule=''
R11.gene_reaction_rule=''
R12.gene_reaction_rule=''
R13.gene_reaction_rule=''
R14.gene_reaction_rule=''

# %%
print(f'{len(model.reactions)} reactions initially')
print(f'{len(model.metabolites)} metabolites initially')
print(f'{len(model.genes)} genes initially')
# Out:
# 1577 reactions initially
# 1226 metabolites initially
# 905 genes initially

# %%
model.add_reactions([R1,R2,R3,R4,R5,R6,R7,R8,R9,R10,R11,R12,R13,R14])

# The objects have been added to the model
print(f'{len(model.reactions)} reactions')
print(f'{len(model.metabolites)} metabolites')
print(f'{len(model.genes)} genes')
# Out:
# 1591 reactions
# 1236 metabolites
# 907 genes

# %%
# Iterate through the the objects in the model
print("Reactions")
print("---------")
for x in model.reactions:
    print("%s : %s" % (x.id, x.reaction))

print("")
print("Metabolites")
print("-----------")
for x in model.metabolites:
    print('%9s : %s' % (x.id, x.formula))

print("")
print("Genes")
print("-----")
for x in model.genes:
    associated_ids = (i.id for i in x.reactions)
    print("%s is associated with reactions: %s" %
          (x.id, "{" + ", ".join(associated_ids) + "}"))
# Out:
# Reactions
# ---------
# CITtcp : cit_c + icit_x <=> cit_x + icit_c
# 13BGH : 13BDglcn_c + h2o_c --> glc__D_c
# 13BGHe : 13BDglcn_e + h2o_e --> glc__D_e
# 13GS : udpg_c --> 13BDglcn_c + h_c + udp_c
# 16GS : udpg_c --> 16BDglcn_c + h_c + udp_c
# 23CAPPD : 23camp_c + h2o_c + h_c --> amp2p_c
# 2DDA7Ptm : 2dda7p_c <=> 2dda7p_m
# 2DHPtm : 2dhp_c <=> 2dhp_m
# 2DOXG6PP : 2doxg6p_c + h2o_c --> 2dglc_c + pi_c
# 2HBO : 2hb_c + nad_c <=> 2obut_c + h_c + nadh_c
# 2HBt2 : 2hb_e + h_e <=> 2hb_c + h_c
# 2HMHMBQMTm : 2hpmhmbq_m + amet_m --> ahcys_m + h_m + q6_m
# 2HP6MPMOm : 2hp6mp_m + o2_m --> 2hp6mbq_m + h2o_m
# 2HPMBQMTm : 2hp6mbq_m + amet_m --> 2hpmmbq_m + ahcys_m + h_m
# 2HPMMBQMOm : 2hpmmbq_m + 0.5 o2_m --> 2hpmhmbq_m
# 2MBACt : 2mbac_c --> 2mbac_e
# EX_epistest_SC_e : epistest_SC_e -->
# EX_epist_e : epist_e -->
# 2MBALDt : 2mbald_c <=> 2mbald_e
# 2MBALDtm : 2mbald_c <=> 2mbald_m
# 2MBTOHt : 2mbtoh_c <=> 2mbtoh_e
# ACACT6p : 3otdcoa_x + coa_x --> accoa_x + ddcacoa_x
# 2MBTOHtm : 2mbtoh_c <=> 2mbtoh_m
# ACACT7p : 3ohdcoa_x + coa_x --> accoa_x + tdcoa_x
# 2MPPALt : 2mppal_c <=> 2mppal_e
# ACACT8p : 3ohodcoa_x + coa_x --> accoa_x + pmtcoa_x
# ACACT9p : 3ohxccoa_x + coa_x --> accoa_x + ttccoa_x
# ACALDCD : 2.0 acald_c --> actn__R_c
# ACALDt : acald_e <=> acald_c
# ACALDtm : acald_m <=> acald_c
# ACCOAC : accoa_c + atp_c + hco3_c <=> adp_c + h_c + malcoa_c + pi_c
# ACCOACrm : accoa_m + atp_m + hco3_m <=> adp_m + h_m + malcoa_m + pi_m
# AGAT_SC : 0.01 1ag3p_SC_c + 0.02 dcacoa_c + 0.06 ddcacoa_c + 0.17 hdcoa_c + 0.09 ocdycacoa_c + 0.24 odecoa_c + 0.27 pmtcoa_c + 0.05 stcoa_c + 0.1 tdcoa_c --> coa_c + 0.01 pa_SC_c
# AGPRim : acg5p_m + h_m + nadph_m --> acg5sa_m + nadp_m + pi_m
# AGTi : ala__L_c + glx_c --> gly_c + pyr_c
# AHCYStm : ahcys_c <=> ahcys_m
# ACCOAtn : accoa_c <=> accoa_n
# 2MPPALtm : 2mppal_c <=> 2mppal_m
# ACESt : aces_c --> aces_e
# ACGAM6PS : accoa_c + gam6p_c <=> acgam6p_c + coa_c + h_c
# AHCi : ahcys_c + h2o_c --> adn_c + hcys__L_c
# AHMMPS : air_c + 2.0 h_c --> 4ahmmp_c + gcald_c + pi_c
# AHSERL : achms_c + ch4s_c --> ac_c + h_c + met__L_c
# AHSERL2 : achms_c + h2s_c --> ac_c + h_c + hcys__L_c
# ACGAMPM : acgam6p_c <=> acgam1p_c
# ACGKm : acglu_m + atp_m --> acg5p_m + adp_m
# 2OBUTtm : 2obut_c <=> 2obut_m
# ACGSm : accoa_m + glu__L_m --> acglu_m + coa_m + h_m
# 2OXOADPtim : 2oxoadp_m --> 2oxoadp_c
# ACHBSm : 2obut_m + h_m + pyr_m --> 2ahbut_m + co2_m
# ACHLE1 : h2o_c + iamac_c --> ac_c + h_c + iamoh_c
# 2PHETOHt : 2phetoh_e <=> 2phetoh_c
# ACHLE2 : h2o_c + ibutac_c --> ac_c + h_c + ibutoh_c
# ACHLE3 : aces_c + h2o_c --> ac_c + etoh_c + h_c
# ACLSm : h_m + 2.0 pyr_m --> alac__S_m + co2_m
# 2PHETOHtm : 2phetoh_m <=> 2phetoh_c
# ACOAHim : accoa_m + h2o_m --> ac_m + coa_m + h_m
# 34HPLFM : 34hpp_m + h_m + nadh_m --> 34hpl_m + nad_m
# ACOAO4p : dcacoa_x + o2_x --> dc2coa_x + h2o2_x
# AICART : 10fthf_c + aicar_c <=> fprica_c + thf_c
# AIRCr : air_c + co2_c <=> 5aizc_c + h_c
# AKGDam : akg_m + h_m + lpam_m <=> co2_m + sdhlam_m
# AKGDbm : coa_m + sdhlam_m --> dhlam_m + succoa_m
# ACOAO5p : ddcacoa_x + o2_x --> dd2coa_x + h2o2_x
# ACOAO6p : o2_x + tdcoa_x --> h2o2_x + td2coa_x
# ACOAO7p : o2_x + pmtcoa_x --> h2o2_x + hdd2coa_x
# ACOAO8p : o2_x + stcoa_x --> h2o2_x + od2coa_x
# ACOAO9p : hexccoa_x + o2_x --> h2o2_x + hxc2coa_x
# AKGMAL : akg_c + mal__L_e <=> akg_e + mal__L_c
# AKGt2n : akg_c + h_c <=> akg_n + h_n
# AKGt2r : akg_e + h_e <=> akg_c + h_c
# 34HPPOR : 34hpp_c + o2_c --> co2_c + hgentis_c
# AKGtp : akg_c <=> akg_x
# AKP1 : ahdt_c + 3.0 h2o_c --> dhnpt_c + 2.0 h_c + 3.0 pi_c
# ALASm : gly_m + h_m + succoa_m --> 5aop_m + co2_m + coa_m
# ALATA_L : akg_c + ala__L_c <=> glu__L_c + pyr_c
# ALATA_Lm : akg_m + ala__L_m <=> glu__L_m + pyr_m
# ACOATA : ACP_c + accoa_c <=> acACP_c + coa_c
# ACOATAm : ACP_m + accoa_m <=> acACP_m + coa_m
# ACON3MT : acon_T_c + amet_c --> acon5m_c + ahcys_c
# ALATRS : ala__L_c + atp_c + trnaala_c --> alatrna_c + amp_c + ppi_c
# 34HPPt2m : 34hpp_c + h_c <=> 34hpp_m + h_m
# ALAt2r : ala__L_e + h_e <=> ala__L_c + h_c
# ALAtmi : ala__L_m --> ala__L_c
# ACONT : cit_c <=> icit_c
# ACONT3m : 2mcit_m <=> micit_m
# ACONTm : cit_m <=> icit_m
# ACOTAim : acg5sa_m + glu__L_m --> acorn_m + akg_m
# ALCD19y : glyald_c + h_c + nadph_c --> glyc_c + nadp_c
# ALCD22xi : 2mbald_c + h_c + nadh_c --> 2mbtoh_c + nad_c
# ALCD22xim : 2mbald_m + h_m + nadh_m --> 2mbtoh_m + nad_m
# 34HPPt2p : 34hpp_c + h_c <=> 34hpp_x + h_x
# ALCD22yi : 2mbald_c + h_c + nadph_c --> 2mbtoh_c + nadp_c
# ALCD23xi : 2mppal_c + h_c + nadh_c --> ibutoh_c + nad_c
# ALCD23xim : 2mppal_m + h_m + nadh_m --> ibutoh_m + nad_m
# ALCD23yi : 2mppal_c + h_c + nadph_c --> ibutoh_c + nadp_c
# ALCD24xi : 3mbald_c + h_c + nadh_c --> iamoh_c + nad_c
# ALCD24xim : 3mbald_m + h_m + nadh_m --> iamoh_m + nad_m
# ACP1e : fmn_e + h2o_e --> pi_e + ribflv_e
# ACPSm : coa_m + h2o_m --> 2.0 h_m + pan4p_m + pap_m
# ACRNtm : acrn_c --> acrn_m
# ACRNtp : acrn_x --> acrn_c
# ACS : ac_c + atp_c + coa_c --> accoa_c + amp_c + ppi_c
# ACSm : ac_m + atp_m + coa_m --> accoa_m + amp_m + ppi_m
# ACSp : ac_x + atp_x + coa_x --> accoa_x + amp_x + ppi_x
# ACt2r : ac_e + h_e <=> ac_c + h_c
# ALCD24yi : 3mbald_c + h_c + nadph_c --> iamoh_c + nadp_c
# ALCD25xi : h_c + nadh_c + pacald_c --> 2phetoh_c + nad_c
# ALCD25xim : h_m + nadh_m + pacald_m --> 2phetoh_m + nad_m
# ALCD25yi : h_c + nadph_c + pacald_c --> 2phetoh_c + nadp_c
# ACtm : ac_c <=> ac_m
# 3C3HMPt : 3c3hmp_c <=> 3c3hmp_e
# ACtp : ac_c <=> ac_x
# ACtr : ac_e <=> ac_c
# ADA : adn_c + h2o_c + h_c --> ins_c + nh4_c
# ADCL : 4adcho_c --> 4abz_c + h_c + pyr_c
# ALCD26xi : h_c + id3acald_c + nadh_c --> ind3eth_c + nad_c
# ALCD26xim : h_m + id3acald_m + nadh_m --> ind3eth_m + nad_m
# ALCD2x_copy1 : etoh_c + nad_c --> acald_c + h_c + nadh_c
# ALCD2ir : acald_c + h_c + nadh_c --> etoh_c + nad_c
# ALCD2irm : acald_m + h_m + nadh_m --> etoh_m + nad_m
# ADCS : chor_c + gln__L_c --> 4adcho_c + glu__L_c
# 3C3HMPtm : 3c3hmp_c <=> 3c3hmp_m
# ADD : ade_c + h2o_c + h_c --> hxan_c + nh4_c
# ADEt2 : ade_e + h_e --> ade_c + h_c
# ADEtm : ade_c <=> ade_m
# ADHAPR_SC : 0.01 1agly3p_SC_c + h_c + nadph_c --> 0.01 1ag3p_SC_c + nadp_c
# ADK1 : amp_c + atp_c <=> 2.0 adp_c
# ADK1m : amp_m + atp_m <=> 2.0 adp_m
# ADK3 : amp_c + gtp_c <=> adp_c + gdp_c
# ALCD2x_copy2 : etoh_c + nad_c <=> acald_c + h_c + nadh_c
# ALDD19xr : h2o_c + nad_c + pacald_c --> 2.0 h_c + nadh_c + pac_c
# ALDD20xm : h2o_m + id3acald_m + nad_m --> 2.0 h_m + ind3ac_m + nadh_m
# ALDD20y : h2o_c + id3acald_c + nadp_c --> 2.0 h_c + ind3ac_c + nadph_c
# ALDD20ym : h2o_m + id3acald_m + nadp_m --> 2.0 h_m + ind3ac_m + nadph_m
# ALDD22x : aproa_c + h2o_c + nad_c --> ala_B_c + 2.0 h_c + nadh_c
# ALDD2xm : acald_m + h2o_m + nad_m --> ac_m + 2.0 h_m + nadh_m
# ALDD2y : acald_c + h2o_c + nadp_c --> ac_c + 2.0 h_c + nadph_c
# ALDD2ym : acald_m + h2o_m + nadp_m --> ac_m + 2.0 h_m + nadph_m
# ADK3m : amp_m + gtp_m <=> adp_m + gdp_m
# ADK4 : amp_c + itp_c <=> adp_c + idp_c
# ADK4m : amp_m + itp_m <=> adp_m + idp_m
# ADMDC : amet_c + h_c --> ametam_c + co2_c
# ADNCYC : atp_c --> camp_c + ppi_c
# ADNK1 : adn_c + atp_c --> adp_c + amp_c + h_c
# ADNUC : adn_c + h2o_c --> ade_c + rib__D_c
# ALLTAHr : alltt_c + h2o_c <=> urdglyc_c + urea_c
# ALLTN : alltn_c + h2o_c <=> alltt_c + h_c
# ALLTNti : alltn_e --> alltn_c
# ALLTTti : alltt_e --> alltt_c
# ADNt2 : adn_e + h_e --> adn_c + h_c
# 3C4MOPtm : 3c4mop_c <=> 3c4mop_m
# ADPT : ade_c + prpp_c --> amp_c + ppi_c
# ADSK : aps_c + atp_c --> adp_c + h_c + paps_c
# ALPHNH : allphn_c + h2o_c + 3.0 h_c --> 2.0 co2_c + 2.0 nh4_c
# AMAOTr : 8aonn_c + amet_c <=> amob_c + dann_c
# ADSL1r : dcamp_c <=> amp_c + fum_c
# AMETt2 : amet_e + h_e --> amet_c + h_c
# 3DH5HPBMTm : 3dh5hpb_m + amet_m --> 3hph5mb_m + ahcys_m + h_m
# AMETtm : amet_c <=> amet_m
# AMID : 4gudbd_c + h2o_c --> 4gudbutn_c + nh4_c
# AMID2 : h2o_c + pad_c --> nh4_c + pac_c
# AMID3 : h2o_c + iad_c --> ind3ac_c + nh4_c
# ADSL2r : 25aics_c <=> aicar_c + fum_c
# ADSS : asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
# AMPN : amp_c + h2o_c --> ade_c + r5p_c
# AMPDA : amp_c + h2o_c + h_c --> imp_c + nh4_c
# 3DH5HPBtm : 3dh5hpb_c <=> 3dh5hpb_m
# AMPtn : amp_n <=> amp_c
# ANPRT : anth_c + prpp_c --> ppi_c + pran_c
# ATPS3v : adp_v + 3.0 h_c + pi_v --> atp_v + h2o_v + 2.0 h_v
# 3DSPHR : 3dsphgn_c + h_c + nadph_c --> nadp_c + sphgn_c
# ATPtm_H : adp_c + atp_m + h_c --> adp_m + atp_c + h_m
# ATPtp_H : adp_x + atp_c + h_x --> adp_c + atp_x + h_c
# ANS : chor_c + gln__L_c --> anth_c + glu__L_c + h_c + pyr_c
# AOBUTDs : 2aobut_c + h_c --> aact_c + co2_c
# AP4AH : ap4a_c + h2o_c <=> 2.0 adp_c + 2.0 h_c
# APRTO2 : aprut_c + h2o_c + o2_c --> h2o2_c + n4abutn_c + nh4_c
# ARAB14LO : Dara14lac_c + o2_c <=> ertascb__D_c + h2o2_c
# BACCL : atp_c + btn_c + h_c --> btamp_c + ppi_c
# 3HAO : 3hanthrn_c + o2_c --> cmusa_c + h_c
# ARAB1D2 : arab__D_c + nadp_c --> Dara14lac_c + h_c + nadph_c
# ARABR : arab__L_c + h_c + nadph_c --> abt_c + nadp_c
# 3HPH5MBDCm : 3hph5mb_m --> 2hp6mp_m + co2_m
# ARAB_Dt : arab__D_e <=> arab__D_c
# ARAB_Lt : arab__L_e <=> arab__L_c
# ARGN : arg__L_c + h2o_c --> orn_c + urea_c
# BPNT : h2o_c + pap_c --> amp_c + pi_c
# BTDD_RR : btd_RR_c + nad_c <=> actn__R_c + h_c + nadh_c
# BTDt_RR : btd_RR_c <=> btd_RR_e
# 3IPM3MT : 3c2hmp_c + amet_c --> 3ipmmest_c + ahcys_c
# BTNt2i : btn_e + h_e --> btn_c + h_c
# BTSr : dtbt_c + s_c <=> btn_c + 2.0 h_c
# C14STR : 44mctr_c + h_c + nadph_c --> 44mzym_c + nadp_c
# C22STDS : ergtrol_c + h_c + nadph_c + o2_c --> ergtetrol_c + 2.0 h2o_c + nadp_c
# C22STDSx : ergtrol_c + h_c + nadh_c + o2_c --> ergtetrol_c + 2.0 h2o_c + nad_c
# C24STRer : ergtetrol_r + h_r + nadph_r --> ergst_r + nadp_r
# C3STDH1 : 4mzym_int1_c + nad_c --> 4mzym_int2_c + co2_c + h_c + nadh_c
# ARGSL : argsuc_c <=> arg__L_c + fum_c
# ARGSS : asp__L_c + atp_c + citr__L_c <=> amp_c + argsuc_c + h_c + ppi_c
# ARGTRS : arg__L_c + atp_c + trnaarg_c --> amp_c + argtrna_c + ppi_c
# ARGTRSm : arg__L_m + atp_m + trnaarg_m --> amp_m + argtrna_m + ppi_m
# ARGt2m : arg__L_c + h_c <=> arg__L_m + h_m
# ARGt2r : arg__L_e + h_e <=> arg__L_c + h_c
# ARGt6 : arg__L_c + h_v --> arg__L_v + h_c
# ARMT : amet_c + his__L_c --> NPmehis_c + ahcys_c + h_c
# ASAD : aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c
# C3STDH2 : nad_c + zym_int1_c --> co2_c + h_c + nadh_c + zym_int2_c
# C3STKR1 : 4mzym_int2_c + h_c + nadph_c --> 4mzym_c + nadp_c
# C3STKR2 : h_c + nadph_c + zym_int2_c --> nadp_c + zymst_c
# ASNN : asn__L_c + h2o_c --> asp__L_c + nh4_c
# C4STMO1 : 44mzym_c + 3.0 h_c + 3.0 nadph_c + 3.0 o2_c --> 4mzym_int1_c + 4.0 h2o_c + 3.0 nadp_c
# ASNNe : asn__L_e + h2o_e --> asp__L_e + nh4_e
# C4STMO2 : 4mzym_c + 3.0 h_c + 3.0 nadph_c + 3.0 o2_c --> 4.0 h2o_c + 3.0 nadp_c + zym_int1_c
# ASNS1 : asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c + asn__L_c + glu__L_c + h_c + ppi_c
# 3MBALDt : 3mbald_c <=> 3mbald_e
# ASNTRS : asn__L_c + atp_c + trnaasn_c --> amp_c + asntrna_c + ppi_c
# ASNTRSm : asn__L_m + atp_m + trnaasn_m --> amp_m + asntrna_m + ppi_m
# C5STDS : epist_c + h_c + nadph_c + o2_c --> ergtrol_c + 2.0 h2o_c + nadp_c
# C8STI : fecost_c --> epist_c
# ASNt2m : asn__L_c + h_c <=> asn__L_m + h_m
# ASNt2r : asn__L_e + h_e <=> asn__L_c + h_c
# 3MBALDtm : 3mbald_c <=> 3mbald_m
# ASNt6 : asn__L_c + h_v --> asn__L_v + h_c
# ASNt7 : asn__L_v + h_v --> asn__L_c + h_c
# CAT : 2.0 h2o2_c --> 2.0 h2o_c + o2_c
# CATp : 2.0 h2o2_x --> 2.0 h2o_x + o2_x
# ASPCT : asp__L_c + cbp_c --> cbasp_c + h_c + pi_c
# 3MOBDC : 3mob_c + h_c --> 2mppal_c + co2_c
# ASPGLU2m : asp__L_m + glu__L_c --> asp__L_c + glu__L_m
# ASPGLUtp : asp__L_c + glu__L_x <=> asp__L_x + glu__L_c
# ASPK : asp__L_c + atp_c --> 4pasp_c + adp_c
# ASPOcm : asp__L_c + fad_m --> fadh2_m + h_c + iasp_c
# CBASPtn : cbasp_n <=> cbasp_c
# CBPS : 2.0 atp_c + gln__L_c + h2o_c + hco3_c --> 2.0 adp_c + cbp_c + glu__L_c + 2.0 h_c + pi_c
# CBPtn : cbp_c <=> cbp_n
# CCP2m : 2.0 focytc_m + h2o2_m --> 2.0 ficytc_m + 2.0 h2o_m
# CDPDGPm_SC : 0.01 cdpdag_SC_m + glyc3p_m <=> cmp_m + h_m + 0.01 pgp_SC_m
# ASPTA : akg_c + asp__L_c <=> glu__L_c + oaa_c
# ASPTAm : akg_m + asp__L_m <=> glu__L_m + oaa_m
# 3MOBtm : 3mob_c <=> 3mob_m
# ASPTAp : akg_x + asp__L_x <=> glu__L_x + oaa_x
# ASPTRS : asp__L_c + atp_c + trnaasp_c --> amp_c + asptrna_c + ppi_c
# ASPTRSm : asp__L_m + atp_m + trnaasp_m --> amp_m + asptrna_m + ppi_m
# CDPtn : cdp_c <=> cdp_n
# CER1_24ter : cer1_24_c <=> cer1_24_r
# CER1_26ter : cer1_26_c <=> cer1_26_r
# CER2_24ter : cer2_24_c <=> cer2_24_r
# CER2_26ter : cer2_26_c <=> cer2_26_r
# ASPt2m : asp__L_c + h_c <=> asp__L_m + h_m
# ASPt2n : asp__L_c + h_c <=> asp__L_n + h_n
# CERASE124er : cer1_24_r + coa_r + h_r --> sphgn_r + ttccoa_r
# 3MOPDC : 3mop_c + h_c --> 2mbald_c + co2_c
# CERASE126er : cer1_26_r + coa_r + h_r --> hexccoa_r + sphgn_r
# ASPt2r : asp__L_e + h_e <=> asp__L_c + h_c
# ASPt5n : asp__L_n <=> asp__L_c
# ASPt7 : asp__L_v + h_v --> asp__L_c + h_c
# CERASE224er : cer2_24_r + coa_r + h_r --> psphings_r + ttccoa_r
# CERASE226er : cer2_26_r + coa_r + h_r --> hexccoa_r + psphings_r
# ATHRDHr : athr__L_c + nadp_c <=> 2aobut_c + h_c + nadph_c
# 3MOPt : 3mop_e <=> 3mop_c
# ATP2tp_H : amp_x + atp_c + h_x --> amp_c + atp_x + h_c
# ATPATF1 : adp_c + atp_c + h_c --> ap4a_c + pi_c
# ATPATF2 : adp_c + gtp_c + h_c --> ap4g_c + pi_c
# ATPATF3 : gdp_c + gtp_c + h_c --> gp4g_c + pi_c
# ATPH1 : atp_c + 2.0 h2o_c --> amp_c + 2.0 h_c + 2.0 pi_c
# ATPM : atp_c + h2o_c --> adp_c + h_c + pi_c
# CERH124_copy1 : cer1_24_c + h_c + nadph_c + o2_c --> cer2_24_c + h2o_c + nadp_c
# CERH126_copy1 : cer1_26_c + h_c + nadph_c + o2_c --> cer2_26_c + h2o_c + nadp_c
# CERS124 : sphgn_c + ttccoa_c --> cer1_24_c + coa_c + h_c
# CERS124er : sphgn_r + ttccoa_r --> cer1_24_r + coa_r + h_r
# CERS126 : hexccoa_c + sphgn_c --> cer1_26_c + coa_c + h_c
# CERS126er : hexccoa_r + sphgn_r --> cer1_26_r + coa_r + h_r
# CERS224 : psphings_c + ttccoa_c --> cer2_24_c + coa_c + h_c
# CERS224er : psphings_r + ttccoa_r --> cer2_24_r + coa_r + h_r
# ATPPRT : atp_c + prpp_c --> ppi_c + prbatp_c
# ATPS : atp_c + h2o_c --> adp_c + h_e + pi_c
# ATPS3g : adp_g + 3.0 h_c + pi_g --> atp_g + h2o_g + 2.0 h_g
# ATPS3m : adp_m + 3.0 h_c + pi_m --> atp_m + h2o_m + 2.0 h_m
# CERS226 : hexccoa_c + psphings_c --> cer2_26_c + coa_c + h_c
# CERS226er : hexccoa_r + psphings_r --> cer2_26_r + coa_r + h_r
# CERH124_copy2 : cer1_24_c + h_c + nadph_c + o2_c --> cer2_24_c + h2o_c + nadp_c
# CERH126_copy2 : cer1_26_c + h_c + nadph_c + o2_c --> cer2_26_c + h2o_c + nadp_c
# CITtbm : cit_c + pep_m <=> cit_m + pep_c
# 3MOPtm : 3mop_c <=> 3mop_m
# CITtcm : cit_c + icit_m <=> cit_m + icit_c
# CERS324 : cer2_24_c + h_c + nadph_c + o2_c --> cer3_24_c + h2o_c + nadp_c
# CERS326 : cer2_26_c + h_c + nadph_c + o2_c --> cer3_26_c + h2o_c + nadp_c
# CHLPCTD : cholp_c + ctp_c + h_c --> cdpchol_c + ppi_c
# CHLSTI : amet_c + o2_c + zymst_c --> ahcys_c + ergtetrol_c + 2.0 h2o_c + h_c
# CLPNSm_SC : 0.01 cdpdag_SC_m + 0.01 pg_SC_m --> 0.01 clpn_SC_m + cmp_m + h_m
# 3OPHB5Hm : 3ophb_5_c + 0.5 o2_c --> 3dh5hpb_c
# CMPN : cmp_c + h2o_c --> csn_c + r5p_c
# CHLt2 : chol_e + h_e --> chol_c + h_c
# CHOLK : atp_c + chol_c --> adp_c + cholp_c + h_c
# CHORM : chor_c --> pphn_c
# CHORS : 3psme_c --> chor_c + pi_c
# CHRPL : chor_c --> 4hbz_c + pyr_c
# CO2t : co2_e <=> co2_c
# CO2tg : co2_c <=> co2_g
# CO2tm : co2_c <=> co2_m
# CO2tn : co2_n <=> co2_c
# CO2tp : co2_c <=> co2_x
# CHTNDA : chitin_c + h2o_c --> ac_c + chitos_c + h_c
# CHTNS : udpacgal_c --> chitin_c + h_c + udp_c
# CITt2r : cit_e + h_e <=> cit_c + h_c
# CO2tv : co2_c <=> co2_v
# COAHLp : coa_x + h2o_x --> 2.0 h_x + pan4p_x + pap_x
# 3OPHB_5tm : 3ophb_5_c <=> 3ophb_5_m
# COAtim : coa_c --> coa_m
# CITtam : cit_c + mal__L_m <=> cit_m + mal__L_c
# CITtap : cit_x + mal__L_c <=> cit_c + mal__L_x
# COAtn : coa_c <=> coa_n
# 4ABUTNtm : 4abutn_c <=> 4abutn_m
# COUCOAFm : T4hcinnm_m + atp_m + coa_m --> amp_m + coucoa_m + ppi_m
# CPPPGO : cpppg3_c + 2.0 h_c + o2_c --> 2.0 co2_c + 2.0 h2o_c + pppg9_c
# 4ABUTtm : 4abut_c <=> 4abut_m
# CRNCARtm : acrn_c + crn_m --> acrn_m + crn_c
# CRNCARtp : acrn_x + crn_c --> acrn_c + crn_x
# DCTPD : dctp_c + h2o_c + h_c --> dutp_c + nh4_c
# DCYTD : dcyt_c + h2o_c + h_c --> duri_c + nh4_c
# CRNt : crn_e <=> crn_c
# 4ABZt : 4abz_c <=> 4abz_e
# CRNtim : crn_m --> crn_c
# DCYTt2 : dcyt_e + h_e --> dcyt_c + h_c
# CRNtp : crn_c --> crn_x
# 4ABZtm : 4abz_c <=> 4abz_m
# CSNATm : acrn_m + coa_m <=> accoa_m + crn_m
# DDPA : e4p_c + h2o_c + pep_c --> 2dda7p_c + pi_c
# DDPAm : e4p_m + h2o_m + pep_m --> 2dda7p_m + pi_m
# DESAT14 : h_c + nadph_c + o2_c + tdcoa_c --> 2.0 h2o_c + nadp_c + tdecoa_c
# DESAT16 : h_c + nadph_c + o2_c + pmtcoa_c --> 2.0 h2o_c + hdcoa_c + nadp_c
# DESAT18 : h_c + nadph_c + o2_c + stcoa_c --> 2.0 h2o_c + nadp_c + odecoa_c
# CSNATp : accoa_x + crn_x <=> acrn_x + coa_x
# CSNATr : accoa_c + crn_c <=> acrn_c + coa_c
# CSND : csn_c + h2o_c + h_c --> nh4_c + ura_c
# CSNt2 : csn_e + h_e --> csn_c + h_c
# CSm : accoa_m + h2o_m + oaa_m --> cit_m + coa_m + h_m
# DESAT18_2 : h_c + nadph_c + o2_c + odecoa_c --> 2.0 h2o_c + nadp_c + ocdycacoa_c
# DGDPtn : dgdp_c <=> dgdp_n
# CSp : accoa_x + h2o_x + oaa_x --> cit_x + coa_x + h_x
# DGGH : 6dg_c + h2o_c --> gal_c + glc__D_c
# 4H2OGLTtm : 4h2oglt_c <=> 4h2oglt_m
# DGK1 : atp_c + dgmp_c <=> adp_c + dgdp_c
# DGSNt2 : dgsn_e + h_e --> dgsn_c + h_c
# CTPS1 : atp_c + nh4_c + utp_c --> adp_c + ctp_c + 2.0 h_c + pi_c
# CTPS2 : atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c
# CTPtm : cmp_m + ctp_c + 2.0 h_c --> cmp_c + ctp_m + 2.0 h_m
# DHAD1m : 23dhmb_m --> 3mob_m + h2o_m
# 4H2OGLTtp : 4h2oglt_c <=> 4h2oglt_x
# DHAD2m : 23dhmp_m --> 3mop_m + h2o_m
# DHAK : atp_c + dha_c --> adp_c + dhap_c + h_c
# CYOOm : 4.0 focytc_m + 6.0 h_m + o2_m --> 4.0 ficytc_m + 2.0 h2o_m + 6.0 h_c
# CYOR_u6m : 2.0 ficytc_m + 1.5 h_m + q6h2_m --> 2.0 focytc_m + 1.5 h_c + q6_m
# DHAPtm : dhap_m --> dhap_c
# DHFR : dhf_c + h_c + nadph_c --> nadp_c + thf_c
# CYSS : acser_c + h2s_c --> ac_c + cys__L_c + h_c
# 4HBZCOAFm : coa_m + coucoa_m + h2o_m + nad_m --> 4hbzcoa_m + accoa_m + h_m + nadh_m
# CYSTGL : cyst__L_c + h2o_c --> 2obut_c + cys__L_c + nh4_c
# CYSTL : cyst__L_c + h2o_c --> hcys__L_c + nh4_c + pyr_c
# CYSTLp : cyst__L_x + h2o_x --> hcys__L_x + nh4_x + pyr_x
# CYSTRS : atp_c + cys__L_c + trnacys_c --> amp_c + cystrna_c + ppi_c
# CYSTS : hcys__L_c + ser__L_c --> cyst__L_c + h2o_c
# DHFRim : dhf_m + h_m + nadph_m --> nadp_m + thf_m
# DHFS : atp_c + dhpt_c + glu__L_c --> adp_c + dhf_c + h_c + pi_c
# DHFtm : dhf_c <=> dhf_m
# DHNPAm : dhnpt_m --> 2ahhmp_m + gcald_m + h_m
# DHNPTtm : dhnpt_c <=> dhnpt_m
# DHORD4i : dhor__S_c + q6_m --> orot_c + q6h2_m
# DHORDfum : dhor__S_c + fum_c --> orot_c + succ_c
# CYSTtp : cyst__L_c <=> cyst__L_x
# CYSt2r : cys__L_e + h_e <=> cys__L_c + h_c
# CYTD : cytd_c + h2o_c + h_c --> nh4_c + uri_c
# CYTDK2 : cytd_c + gtp_c --> cmp_c + gdp_c + h_c
# DHORDi : dhor__S_c + o2_c --> h2o2_c + orot_c
# DHORTS : dhor__S_c + h2o_c <=> cbasp_c + h_c
# 4HBZFm : 4hbzcoa_m + h2o_m --> 4hbz_m + coa_m + h_m
# DHPSm : 2ahhmp_m + 4abz_m --> dhpt_m + h2o_m
# DHPTtm : dhpt_c <=> dhpt_m
# DHQS : 2dda7p_c --> 3dhq_c + pi_c
# DHQTi : 3dhq_c --> 3dhsk_c + h2o_c
# CYTDt2 : cytd_e + h_e --> cytd_c + h_c
# CYTK1 : atp_c + cmp_c <=> adp_c + cdp_c
# CYTK2 : atp_c + dcmp_c <=> adp_c + dcdp_c
# DADA : dad_2_c + h2o_c + h_c --> din_c + nh4_c
# DADK : atp_c + damp_c <=> adp_c + dadp_c
# DIAT : accoa_c + sprm_c --> N1sprm_c + coa_c + h_c
# DINSt2 : din_e + h_e --> din_c + h_c
# DADNt2 : dad_2_e + h_e --> dad_2_c + h_c
# DIPS : amet_c + caphis_c --> ahcys_c + cmaphis_c + h_c
# DADPtn : dadp_c <=> dadp_n
# 4HBZtm : 4hbz_c <=> 4hbz_m
# DAGCPT_SC : 0.01 12dgr_SC_c + cdpchol_c --> cmp_c + h_c + 0.01 pc_SC_c
# DAGPYP_SC : h2o_c + 0.01 pa_SC_c --> 0.01 12dgr_SC_c + pi_c
# DKMPPD2 : dkmpp_c + 3.0 h2o_c --> 2kmb_c + for_c + 6.0 h_c + pi_c
# DMATT : dmpp_c + ipdp_c --> grdp_c + ppi_c
# DNMPPA : dhpmp_c + h2o_c --> dhnpt_c + pi_c
# DNTPPA : ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
# DOLK : ctp_c + dolichol_c --> cdp_c + dolp_c + h_c
# DOLPMMer : dolmanp_r --> dolp_r + h_r + mannan_r
# DANNt2 : dann_e + h_e <=> dann_c + h_c
# DASYN_SC : ctp_c + h_c + 0.01 pa_SC_c <=> 0.01 cdpdag_SC_c + ppi_c
# DASYNm_SC : ctp_m + h_m + 0.01 pa_SC_m <=> 0.01 cdpdag_SC_m + ppi_m
# DB4PS : ru5p__D_c --> db4p_c + for_c + h_c
# DBTS : atp_c + co2_c + dann_c <=> adp_c + dtbt_c + 3.0 h_c + pi_c
# DCDPtn : dcdp_c <=> dcdp_n
# DCMPDA : dcmp_c + h2o_c + h_c <=> dump_c + nh4_c
# DOLPMTcer : dolp_c + gdpmann_c --> dolmanp_r + gdp_c
# DOLPt2er : dolp_c + h_c <=> dolp_r + h_r
# 4HGLSDm : 4hglusa_m + h2o_m + nad_m <=> e4hglu_m + 2.0 h_m + nadh_m
# DPCOAK : atp_c + dpcoa_c --> adp_c + coa_c + h_c
# DPCOAKm : atp_m + dpcoa_m --> adp_m + coa_m + h_m
# DPGM : 13dpg_c <=> 23dpg_c + h_c
# DPMVD : 5dpmev_c + atp_c --> adp_c + co2_c + ipdp_c + pi_c
# ECOAH4p : 3hdcoa_x <=> dc2coa_x + h2o_x
# ECOAH5p : 3hddcoa_x <=> dd2coa_x + h2o_x
# DPR : 2dhp_c + h_c + nadph_c --> nadp_c + pant__R_c
# 4HPRO_LTtm : 4hpro_LT_c <=> 4hpro_LT_m
# DPRm : 2dhp_m + h_m + nadph_m --> nadp_m + pant__R_m
# ECOAH6p : 3htdcoa_x <=> h2o_x + td2coa_x
# DRBK : atp_c + drib_c --> 2dr5p_c + adp_c + h_c
# ECOAH7p : 3hhdcoa_x <=> h2o_x + hdd2coa_x
# ECOAH8p : 3hodcoa_x <=> h2o_x + od2coa_x
# DROPPRy : 25dhpp_c + h_c + nadph_c --> 25dthpp_c + nadp_c
# 4HTHRS : h2o_c + phthr_c --> 4hthr_c + pi_c
# DRTPPD : 25dthpp_c + h2o_c + h_c --> 5aprbu_c + nh4_c
# EHGLAT : akg_c + e4hglu_c --> 4h2oglt_c + glu__L_c
# EHGLATm : akg_m + e4hglu_m --> 4h2oglt_m + glu__L_m
# EHGLATp : akg_x + e4hglu_x --> 4h2oglt_x + glu__L_x
# ENO : 2pg_c <=> h2o_c + pep_c
# EPGALURSe : h2o_e + pectin_e --> galur_e
# EPISTAT_SC : 0.01 epist_c + 0.655 hdcoa_c + 0.01 hexccoa_c + 0.27 odecoa_c + 0.02 pmtcoa_c + 0.03 stcoa_c + 0.015 tdcoa_c --> coa_c + 0.01 epistest_SC_c
# DTMPK : atp_c + dtmp_c <=> adp_c + dtdp_c
# DTTPt : dttp_e <=> dttp_c
# DUMPtn : dump_c <=> dump_n
# DURIK1 : atp_c + duri_c --> adp_c + dump_c + h_c
# DURIPP : duri_c + pi_c <=> 2dr1p_c + ura_c
# DURIt2 : duri_e + h_e --> duri_c + h_c
# DUTPDP : dutp_c + h2o_c --> dump_c + h_c + ppi_c
# EPISTESTH_SC : 0.01 epistest_SC_c + h2o_c --> 0.01 epist_c + h_c + 0.02 hdca_c + 0.655 hdcea_c + 0.01 hexc_c + 0.03 ocdca_c + 0.27 ocdcea_c + 0.015 ttdca_c
# EPISTESTH_SCe : 0.01 epistest_SC_e + h2o_e --> 0.01 epist_e + h_e + 0.02 hdca_e + 0.655 hdcea_e + 0.01 hexc_e + 0.03 ocdca_e + 0.27 ocdcea_e + 0.015 ttdca_e
# EPISTt : epist_e <=> epist_c
# DXHPScm : h2o_c + q6_m + spmd_c --> 13dampp_c + 4abutn_c + q6h2_m
# D_LACDcm : 2.0 ficytc_m + lac__D_c --> 2.0 focytc_m + pyr_c
# EPMGH : epm_c + h2o_c <=> gal_c + man_c
# 4MOPDC : 4mop_c + h_c --> 3mbald_c + co2_c
# ERGSTAT_SC : 0.01 ergst_c + 0.655 hdcoa_c + 0.01 hexccoa_c + 0.27 odecoa_c + 0.02 pmtcoa_c + 0.03 stcoa_c + 0.015 tdcoa_c --> coa_c + 0.01 ergstest_SC_c
# ERGSTESTH_SC : 0.01 ergstest_SC_c + h2o_c --> 0.01 ergst_c + h_c + 0.02 hdca_c + 0.655 hdcea_c + 0.01 hexc_c + 0.03 ocdca_c + 0.27 ocdcea_c + 0.015 ttdca_c
# ERGSTESTH_SCe : 0.01 ergstest_SC_e + h2o_e --> 0.01 ergst_e + h_e + 0.02 hdca_e + 0.655 hdcea_e + 0.01 hexc_e + 0.03 ocdca_e + 0.27 ocdcea_e + 0.015 ttdca_e
# ERGSTGLCT : ergst_c + udpg_c --> ergst3glc_c + h_c + udp_c
# D_LACDm : 2.0 ficytc_m + lac__D_m --> 2.0 focytc_m + pyr_m
# D_LACt2 : h_e + lac__D_e <=> h_c + lac__D_c
# D_LACt2m : lac__D_c + pyr_m <=> lac__D_m + pyr_c
# D_LACtm : h_c + lac__D_c <=> h_m + lac__D_m
# E4HGLUtm : e4hglu_c <=> e4hglu_m
# ERGSTt : ergst_e <=> ergst_c
# ERGSTter : ergst_r <=> ergst_c
# ERGTETROLter : ergtetrol_c <=> ergtetrol_r
# E4HGLUtp : e4hglu_c <=> e4hglu_x
# E4Ptm : e4p_c <=> e4p_m
# ETHAK : atp_c + etha_c --> adp_c + ethamp_c + h_c
# 5AOPt2 : 5aop_e + h_e --> 5aop_c + h_c
# ETHAPT_SC : 0.01 12dgr_SC_c + cdpea_c <=> cmp_c + h_c + 0.01 pe_SC_c
# ETHAt : etha_e <=> etha_c
# ETOHt : etoh_e <=> etoh_c
# ETOHtm : etoh_c <=> etoh_m
# ECOAH11p : h2o_x + hxc2coa_x <=> 3hxccoa_x
# EX_ergst_e : ergst_e -->
# EX_ergstest_SC_e : ergstest_SC_e -->
# EX_13BDglcn_e : 13BDglcn_e -->
# EX_etha_e : etha_e -->
# EX_2hb_e : 2hb_e -->
# EX_etoh_e : etoh_e -->
# 5AOPtm : 5aop_c <=> 5aop_m
# EX_fe2_e : fe2_e <=>
# EX_fecost_e : fecost_e -->
# EX_2mbac_e : 2mbac_e -->
# EX_2mbald_e : 2mbald_e -->
# EX_2mbtoh_e : 2mbtoh_e -->
# EX_2mppal_e : 2mppal_e -->
# EX_2phetoh_e : 2phetoh_e -->
# EX_fecostest_SC_e : fecostest_SC_e -->
# EX_fmn_e : fmn_e -->
# EX_3c3hmp_e : 3c3hmp_e -->
# 6PGLter : 6pgl_c <=> 6pgl_r
# EX_3mbald_e : 3mbald_e -->
# EX_for_e : for_e -->
# EX_fru_e : fru_e -->
# EX_3mop_e : 3mop_e -->
# 8AONNt2 : 8aonn_e + h_e <=> 8aonn_c + h_c
# EX_4abut_e : 4abut_e -->
# EX_fum_e : fum_e -->
# EX_g3pc_e : g3pc_e -->
# EX_4abz_e : 4abz_e -->
# AABTN : 4aabutn_c + h2o_c --> 4abut_c + ac_c
# EX_5aop_e : 5aop_e -->
# EX_g3pi_e : g3pi_e -->
# EX_gal_e : gal_e -->
# EX_8aonn_e : 8aonn_e -->
# EX_Nbfortyr_e : Nbfortyr_e -->
# EX_abt_e : abt_e -->
# EX_ac_e : ac_e -->
# EX_acald_e : acald_e -->
# EX_aces_e : aces_e -->
# EX_galur_e : galur_e -->
# EX_gam6p_e : gam6p_e -->
# EX_gcald_e : gcald_e -->
# EX_glc__D_e : glc__D_e <=>
# EX_gln__L_e : gln__L_e -->
# EX_glu__L_e : glu__L_e -->
# EX_glx_e : glx_e -->
# EX_ade_e : ade_e -->
# EX_adn_e : adn_e -->
# EX_akg_e : akg_e -->
# EX_ala__L_e : ala__L_e -->
# EX_gly_e : gly_e -->
# EX_glyc_e : glyc_e -->
# AACTOOR : aact_c + h2o_c + o2_c --> h2o2_c + mthgxl_c + nh4_c
# EX_gsn_e : gsn_e -->
# EX_gthox_e : gthox_e -->
# EX_gthrd_e : gthrd_e -->
# EX_alltn_e : alltn_e -->
# EX_alltt_e : alltt_e -->
# EX_amet_e : amet_e -->
# EX_arab__D_e : arab__D_e -->
# EX_arab__L_e : arab__L_e -->
# EX_gua_e : gua_e -->
# EX_arg__L_e : arg__L_e -->
# EX_h2o_e : h2o_e <=>
# AASAD1 : L2aadp_c + atp_c + h_c + nadph_c --> L2aadp6sa_c + amp_c + nadp_c + ppi_c
# EX_h_e : h_e <=>
# EX_hdca_e : hdca_e -->
# EX_hdcea_e : hdcea_e -->
# EX_asn__L_e : asn__L_e -->
# EX_asp__L_e : asp__L_e -->
# EX_btd_RR_e : btd_RR_e -->
# EX_btn_e : btn_e -->
# EX_hexc_e : hexc_e -->
# AASAD2 : L2aadp_c + atp_c + h_c + nadh_c --> L2aadp6sa_c + amp_c + nad_c + ppi_c
# EX_his__L_e : his__L_e -->
# EX_hxan_e : hxan_e -->
# EX_iamac_e : iamac_e -->
# EX_iamoh_e : iamoh_e -->
# EX_ibutac_e : ibutac_e -->
# EX_chol_e : chol_e -->
# EX_cit_e : cit_e -->
# EX_co2_e : co2_e -->
# EX_crn_e : crn_e -->
# EX_csn_e : csn_e -->
# EX_cys__L_e : cys__L_e -->
# EX_cytd_e : cytd_e -->
# EX_dad_2_e : dad_2_e -->
# EX_dann_e : dann_e -->
# EX_ibutoh_e : ibutoh_e -->
# EX_id3acald_e : id3acald_e -->
# EX_ile__L_e : ile__L_e -->
# EX_ind3eth_e : ind3eth_e -->
# EX_inost_e : inost_e -->
# EX_dca_e : dca_e -->
# EX_dcyt_e : dcyt_e -->
# EX_ddca_e : ddca_e -->
# EX_ins_e : ins_e -->
# EX_k_e : k_e <=>
# EX_dgsn_e : dgsn_e -->
# EX_din_e : din_e -->
# EX_lac__D_e : lac__D_e -->
# AATA : 2oxoadp_c + glu__L_c <=> L2aadp_c + akg_c
# EX_lac__L_e : lac__L_e -->
# EX_lanost_e : lanost_e -->
# EX_lanostest_SC_e : lanostest_SC_e -->
# EX_dttp_e : dttp_e -->
# EX_duri_e : duri_e -->
# EX_leu__L_e : leu__L_e -->
# ABTA : 4abut_c + akg_c --> glu__L_c + sucsal_c
# EX_lys__L_e : lys__L_e -->
# EX_mal__L_e : mal__L_e -->
# EX_malt_e : malt_e -->
# EX_ribflv_e : ribflv_e -->
# EX_sbt__D_e : sbt__D_e -->
# EX_man_e : man_e -->
# ABTt : abt_e <=> abt_c
# EX_melib_e : melib_e -->
# EX_met__L_e : met__L_e -->
# EX_mmet_e : mmet_e -->
# EX_na1_e : na1_e <=>
# EX_nac_e : nac_e -->
# EX_sbt__L_e : sbt__L_e -->
# EX_ser__L_e : ser__L_e -->
# EX_so3_e : so3_e -->
# EX_so4_e : so4_e <=>
# EX_spmd_e : spmd_e -->
# EX_sprm_e : sprm_e -->
# EX_srb__L_e : srb__L_e -->
# EX_succ_e : succ_e -->
# EX_nadp_e : nadp_e -->
# EX_nh4_e : nh4_e <=>
# EX_nmn_e : nmn_e -->
# EX_sucr_e : sucr_e -->
# EX_o2_e : o2_e <=>
# EX_taur_e : taur_e -->
# ABUTDm : 4abutn_m + h2o_m + nad_m --> 4abut_m + 2.0 h_m + nadh_m
# EX_thm_e : thm_e -->
# EX_oaa_e : oaa_e -->
# EX_ocdca_e : ocdca_e -->
# EX_ocdcea_e : ocdcea_e -->
# ABUTt2r : 4abut_e + h_e <=> 4abut_c + h_c
# EX_ocdcya_e : ocdcya_e -->
# EX_orn_e : orn_e -->
# EX_thmmp_e : thmmp_e -->
# EX_thmpp_e : thmpp_e -->
# EX_thr__L_e : thr__L_e -->
# EX_thym_e : thym_e -->
# EX_pacald_e : pacald_e -->
# EX_pap_e : pap_e -->
# EX_thymd_e : thymd_e -->
# ACACT1r : 2.0 accoa_c --> aacoa_c + coa_c
# EX_tre_e : tre_e -->
# EX_trp__L_e : trp__L_e -->
# EX_pc_SC_e : pc_SC_e -->
# EX_pectin_e : pectin_e -->
# EX_pepd_e : pepd_e -->
# EX_phe__L_e : phe__L_e -->
# EX_pheac_e : pheac_e -->
# EX_pi_e : pi_e <=>
# EX_pnto__R_e : pnto__R_e -->
# EX_ttdca_e : ttdca_e -->
# EX_tyr__L_e : tyr__L_e -->
# EX_ura_e : ura_e -->
# EX_urea_e : urea_e -->
# EX_uri_e : uri_e -->
# EX_val__L_e : val__L_e -->
# EX_xan_e : xan_e -->
# EX_xtsn_e : xtsn_e -->
# EX_pro__L_e : pro__L_e -->
# EX_ptd1ino_SC_e : ptd1ino_SC_e -->
# EX_ptrc_e : ptrc_e -->
# EX_pyr_e : pyr_e -->
# EX_xyl__D_e : xyl__D_e -->
# EX_xylt_e : xylt_e -->
# EX_rib__D_e : rib__D_e -->
# ACACT1m : 2.0 accoa_m --> aacoa_m + coa_m
# EX_zymst_e : zymst_e -->
# EX_zymstest_SC_e : zymstest_SC_e -->
# FA100tp : dca_c --> dca_x
# ACACT4p : 3odcoa_x + coa_x --> accoa_x + occoa_x
# FA120ACPHi : ddcaACP_c + h2o_c <=> ACP_c + ddca_c + h_c
# FACOAL161 : atp_c + coa_c + hdcea_c <=> amp_c + hdcoa_c + ppi_c
# FACOAL161p : atp_x + coa_x + hdcea_x <=> amp_x + hdcoa_x + ppi_x
# FA120ACPtm : ddcaACP_m --> ddcaACP_c
# ACACT5p : 3oddcoa_x + coa_x --> accoa_x + dcacoa_x
# FA120tp : ddca_c --> ddca_x
# FA140ACPHi : h2o_c + myrsACP_c <=> ACP_c + h_c + ttdca_c
# FACOAL180 : atp_c + coa_c + ocdca_c <=> amp_c + ppi_c + stcoa_c
# FACOAL181 : atp_c + coa_c + ocdcea_c <=> amp_c + odecoa_c + ppi_c
# FACOAL182 : atp_c + coa_c + ocdcya_c <=> amp_c + ocdycacoa_c + ppi_c
# FA140ACPtm : myrsACP_m --> myrsACP_c
# FACOAL240p : atp_x + coa_x + ttc_x <=> amp_x + ppi_x + ttccoa_x
# FA140COAabcp : atp_x + h2o_x + tdcoa_c --> adp_x + h_x + pi_x + tdcoa_x
# FA140tp : ttdca_c --> ttdca_x
# FA141ACPHi : h2o_c + tdeACP_c <=> ACP_c + h_c + ttdcea_c
# FA141ACPtm : tdeACP_m --> tdeACP_c
# FACOAL260p : atp_x + coa_x + hexc_x <=> amp_x + hexccoa_x + ppi_x
# FACOAL80p : atp_x + coa_x + octa_x <=> amp_x + occoa_x + ppi_x
# FADFMNtm : fad_c + fmn_m --> fad_m + fmn_c
# FALDH : fald_c + gthrd_c + nad_c <=> Sfglutth_c + h_c + nadh_c
# FA141COAabcp : atp_x + h2o_x + tdecoa_c --> adp_x + h_x + pi_x + tdecoa_x
# FAS161ACPm : 4.0 h_m + malACP_m + myrsACP_m + 3.0 nadph_m + o2_m --> ACP_m + co2_m + 3.0 h2o_m + hdeACP_m + 3.0 nadp_m
# FA141tp : ttdcea_c --> ttdcea_x
# FA160ACPHi : h2o_c + palmACP_c <=> ACP_c + h_c + hdca_c
# FA160ACPtm : palmACP_m --> palmACP_c
# FA160COAabcp : atp_x + h2o_x + pmtcoa_c --> adp_x + h_x + pi_x + pmtcoa_x
# FAO141p_even : 6.0 coa_x + 6.0 h2o_x + 6.0 nad_x + nadph_x + 6.0 o2_x + tdecoa_x --> 7.0 accoa_x + 6.0 h2o2_x + 5.0 h_x + 6.0 nadh_x + nadp_x
# FAO141p_odd : 6.0 coa_x + 6.0 h2o_x + 6.0 nad_x + 5.0 o2_x + tdecoa_x --> 7.0 accoa_x + 5.0 h2o2_x + 6.0 h_x + 6.0 nadh_x
# FAO161p_even : 7.0 coa_x + 7.0 h2o_x + hdcoa_x + 7.0 nad_x + nadph_x + 7.0 o2_x --> 8.0 accoa_x + 7.0 h2o2_x + 6.0 h_x + 7.0 nadh_x + nadp_x
# FAO161p_odd : 7.0 coa_x + 7.0 h2o_x + hdcoa_x + 7.0 nad_x + 6.0 o2_x --> 8.0 accoa_x + 6.0 h2o2_x + 7.0 h_x + 7.0 nadh_x
# FAO181p_even : 8.0 coa_x + 8.0 h2o_x + 8.0 nad_x + nadph_x + 8.0 o2_x + odecoa_x --> 9.0 accoa_x + 8.0 h2o2_x + 7.0 h_x + 8.0 nadh_x + nadp_x
# FA160tp : hdca_c --> hdca_x
# FA161ACPHi : h2o_c + hdeACP_c <=> ACP_c + h_c + hdcea_c
# FA161ACPtm : hdeACP_m --> hdeACP_c
# FAO181p_odd : 8.0 coa_x + 8.0 h2o_x + 8.0 nad_x + 7.0 o2_x + odecoa_x --> 9.0 accoa_x + 7.0 h2o2_x + 8.0 h_x + 8.0 nadh_x
# FAS180 : 3.0 h_c + hdca_c + malcoa_c + 2.0 nadph_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + ocdca_c
# FAO182p_eveneven : 8.0 coa_x + 8.0 h2o_x + 8.0 nad_x + 2.0 nadph_x + 8.0 o2_x + ocdycacoa_x --> 9.0 accoa_x + 8.0 h2o2_x + 6.0 h_x + 8.0 nadh_x + 2.0 nadp_x
# FAO182p_evenodd : 8.0 coa_x + 8.0 h2o_x + 8.0 nad_x + nadph_x + 7.0 o2_x + ocdycacoa_x --> 9.0 accoa_x + 7.0 h2o2_x + 7.0 h_x + 8.0 nadh_x + nadp_x
# FAO182p_oddodd : 8.0 coa_x + 8.0 h2o_x + 8.0 nad_x + 6.0 o2_x + ocdycacoa_x --> 9.0 accoa_x + 6.0 h2o2_x + 8.0 h_x + 8.0 nadh_x
# FAO240p : 3.0 coa_x + 3.0 h2o_x + 3.0 nad_x + 3.0 o2_x + ttccoa_x --> 3.0 accoa_x + 3.0 h2o2_x + 3.0 h_x + 3.0 nadh_x + stcoa_x
# FAO80p : 3.0 coa_x + 3.0 h2o_x + 3.0 nad_x + 3.0 o2_x + occoa_x --> 4.0 accoa_x + 3.0 h2o2_x + 3.0 h_x + 3.0 nadh_x
# FAS100 : 3.0 h_c + malcoa_c + 2.0 nadph_c + octa_c --> co2_c + coa_c + dca_c + h2o_c + 2.0 nadp_c
# FA161COAabcp : atp_x + h2o_x + hdcoa_c --> adp_x + h_x + hdcoa_x + pi_x
# FA161tp : hdcea_c --> hdcea_x
# FA180ACPH : h2o_c + ocdcaACP_c <=> ACP_c + h_c + ocdca_c
# FA180ACPtm : ocdcaACP_m --> ocdcaACP_c
# FA180COAabcp : atp_x + h2o_x + stcoa_c --> adp_x + h_x + pi_x + stcoa_x
# FA181ACPH : h2o_c + octeACP_c <=> ACP_c + h_c + ocdcea_c
# FA181ACPtm : octeACP_m --> octeACP_c
# FA181COAabcp : atp_x + h2o_x + odecoa_c --> adp_x + h_x + odecoa_x + pi_x
# FA182ACPH : h2o_c + ocdcyaACP_c <=> ACP_c + h_c + ocdcya_c
# FA182ACPtm : ocdcyaACP_m --> ocdcyaACP_c
# FA182COAabcp : atp_x + h2o_x + ocdycacoa_c --> adp_x + h_x + ocdycacoa_x + pi_x
# FA240tp : ttc_c --> ttc_x
# FAS100ACPm : 3.0 h_m + malACP_m + 2.0 nadph_m + ocACP_m --> ACP_m + co2_m + dcaACP_m + h2o_m + 2.0 nadp_m
# FAS100COA : 3.0 h_c + malcoa_c + 2.0 nadph_c + occoa_c --> co2_c + coa_c + dcacoa_c + h2o_c + 2.0 nadp_c
# FAS120 : dca_c + 3.0 h_c + malcoa_c + 2.0 nadph_c --> co2_c + coa_c + ddca_c + h2o_c + 2.0 nadp_c
# FAS120ACPm : dcaACP_m + 3.0 h_m + malACP_m + 2.0 nadph_m --> ACP_m + co2_m + ddcaACP_m + h2o_m + 2.0 nadp_m
# FAS120COA : dcacoa_c + 3.0 h_c + malcoa_c + 2.0 nadph_c --> co2_c + coa_c + ddcacoa_c + h2o_c + 2.0 nadp_c
# FAS140 : ddca_c + 3.0 h_c + malcoa_c + 2.0 nadph_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + ttdca_c
# FAS140ACPm : ddcaACP_m + 3.0 h_m + malACP_m + 2.0 nadph_m --> ACP_m + co2_m + h2o_m + myrsACP_m + 2.0 nadp_m
# FAS140COA : ddcacoa_c + 3.0 h_c + malcoa_c + 2.0 nadph_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + tdcoa_c
# FAS141 : ddca_c + 4.0 h_c + malcoa_c + 3.0 nadph_c + o2_c --> co2_c + coa_c + 3.0 h2o_c + 3.0 nadp_c + ttdcea_c
# FA260tp : hexc_c --> hexc_x
# FA80tp : octa_c --> octa_x
# FACOAL100p : atp_x + coa_x + dca_x <=> amp_x + dcacoa_x + ppi_x
# FAS141ACPm : ddcaACP_m + 4.0 h_m + malACP_m + 3.0 nadph_m + o2_m --> ACP_m + co2_m + 3.0 h2o_m + 3.0 nadp_m + tdeACP_m
# FACOAL120p : atp_x + coa_x + ddca_x <=> amp_x + ddcacoa_x + ppi_x
# FACOAL140 : atp_c + coa_c + ttdca_c <=> amp_c + ppi_c + tdcoa_c
# FACOAL140p : atp_x + coa_x + ttdca_x <=> amp_x + ppi_x + tdcoa_x
# FACOAL141 : atp_c + coa_c + ttdcea_c <=> amp_c + ppi_c + tdecoa_c
# FACOAL141p : atp_x + coa_x + ttdcea_x <=> amp_x + ppi_x + tdecoa_x
# FAS160 : 3.0 h_c + malcoa_c + 2.0 nadph_c + ttdca_c --> co2_c + coa_c + h2o_c + hdca_c + 2.0 nadp_c
# FAS160ACPm : 3.0 h_m + malACP_m + myrsACP_m + 2.0 nadph_m --> ACP_m + co2_m + h2o_m + 2.0 nadp_m + palmACP_m
# FAS160COA : 3.0 h_c + malcoa_c + 2.0 nadph_c + tdcoa_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + pmtcoa_c
# FAS161 : 4.0 h_c + malcoa_c + 3.0 nadph_c + o2_c + ttdca_c --> co2_c + coa_c + 3.0 h2o_c + hdcea_c + 3.0 nadp_c
# FACOAL160 : atp_c + coa_c + hdca_c <=> amp_c + pmtcoa_c + ppi_c
# FACOAL160p : atp_x + coa_x + hdca_x <=> amp_x + pmtcoa_x + ppi_x
# FAS180ACPm : 3.0 h_m + malACP_m + 2.0 nadph_m + palmACP_m --> ACP_m + co2_m + h2o_m + 2.0 nadp_m + ocdcaACP_m
# G3PDm : fad_m + glyc3p_m --> dhap_m + fadh2_m
# FAS180COA : 3.0 h_c + malcoa_c + 2.0 nadph_c + pmtcoa_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + stcoa_c
# GLUK : atp_c + glc__D_c --> adp_c + g6p_B_c + h_c
# G3PIt : g3pi_e <=> g3pi_c
# FAS181 : 4.0 h_c + hdca_c + malcoa_c + 3.0 nadph_c + o2_c --> co2_c + coa_c + 3.0 h2o_c + 3.0 nadp_c + ocdcea_c
# FAS181ACPm : 4.0 h_m + malACP_m + 3.0 nadph_m + o2_m + palmACP_m --> ACP_m + co2_m + 3.0 h2o_m + 3.0 nadp_m + octeACP_m
# FAS182ACPm : 5.0 h_m + malACP_m + 4.0 nadph_m + 2.0 o2_m + palmACP_m --> ACP_m + co2_m + 5.0 h2o_m + 4.0 nadp_m + ocdcyaACP_m
# G3PT : glyc3p_c + h2o_c --> glyc_c + pi_c
# FAS240_L : 9.0 h_c + 3.0 malcoa_c + 6.0 nadph_c + ocdca_c --> 3.0 co2_c + 3.0 coa_c + 3.0 h2o_c + 6.0 nadp_c + ttc_c
# G5SADs : glu5sa_c <=> 1pyr5c_c + h2o_c + h_c
# G5SADrm : glu5sa_m <=> 1pyr5c_m + h2o_m + h_m
# FAS260 : 3.0 h_c + malcoa_c + 2.0 nadph_c + ttc_c --> co2_c + coa_c + h2o_c + hexc_c + 2.0 nadp_c
# G5SD : glu5p_c + h_c + nadph_c --> glu5sa_c + nadp_c + pi_c
# G5SD2 : glu5p_c + h_c + nadh_c --> glu5sa_c + nad_c + pi_c
# GLUN : gln__L_c + h2o_c --> glu__L_c + nh4_c
# GLUPRT : gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c + pram_c
# G6PDA : gam6p_c + h2o_c --> f6p_c + nh4_c
# FAS80ACPm_L : acACP_m + 9.0 h_m + 3.0 malACP_m + 6.0 nadph_m --> 3.0 ACP_m + 3.0 co2_m + 3.0 h2o_m + 6.0 nadp_m + ocACP_m
# G6PDH2r : g6p_c + nadp_c --> 6pgl_c + h_c + nadph_c
# G6PDH2er : g6p_r + nadp_r --> 6pgl_r + h_r + nadph_r
# G6PI : g6p_c <=> g6p_B_c
# G6PI3 : g6p_B_c <=> f6p_c
# G6Pter : g6p_c <=> g6p_r
# GALIGH : 1Dgali_c + h2o_c <=> gal_c + inost_c
# GALKr : atp_c + gal_c --> adp_c + gal1p_c + h_c
# GALS3 : h2o_c + melib_c --> gal_c + glc__D_c
# GALT : gal1p_c + h_c + utp_c <=> ppi_c + udpgal_c
# GLUSx : akg_c + gln__L_c + h_c + nadh_c --> 2.0 glu__L_c + nad_c
# GLUTRS : atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
# GLUTRSm : atp_m + glu__L_m + trnaglu_m --> amp_m + glutrna_m + ppi_m
# GLUt2n : glu__L_c + h_c <=> glu__L_n + h_n
# GLUt2r : glu__L_e + h_e <=> glu__L_c + h_c
# GLUt5m : glu__L_c + oh1_m --> glu__L_m + oh1_c
# GLUt7 : glu__L_v + h_v --> glu__L_c + h_c
# GLUt7m : glu__L_c --> glu__L_m
# GLXt : glx_c <=> glx_e
# GLXtp : glx_c <=> glx_x
# GLYAT : accoa_c + gly_c <-- 2aobut_c + coa_c
# GLYC3Ptm : glyc3p_c --> glyc3p_m
# GALUi : g1p_c + h_c + utp_c <=> ppi_c + udpg_c
# GALt2 : gal_e + h_e --> gal_c + h_c
# GAM6Pt : gam6p_e <=> gam6p_c
# GAPD : g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
# GLYCDy : glyc_c + nadp_c --> dha_c + h_c + nadph_c
# FAS80COA_L : accoa_c + 9.0 h_c + 3.0 malcoa_c + 6.0 nadph_c --> 3.0 co2_c + 3.0 coa_c + 3.0 h2o_c + 6.0 nadp_c + occoa_c
# GLYCLm : gly_m + nad_m + thf_m --> co2_m + mlthf_m + nadh_m + nh4_m
# GLYCt : glyc_c <=> glyc_e
# GLYCt2 : glyc_e + h_e --> glyc_c + h_c
# GARFT : 10fthf_c + gar_c --> fgam_c + h_c + thf_c
# GAT1_SC : 0.02 dcacoa_c + 0.06 ddcacoa_c + glyc3p_c + 0.17 hdcoa_c + 0.09 ocdycacoa_c + 0.24 odecoa_c + 0.27 pmtcoa_c + 0.05 stcoa_c + 0.1 tdcoa_c --> 0.01 1ag3p_SC_c + coa_c
# GAT2_SC : 0.02 dcacoa_c + 0.06 ddcacoa_c + dhap_c + 0.17 hdcoa_c + 0.09 ocdycacoa_c + 0.24 odecoa_c + 0.27 pmtcoa_c + 0.05 stcoa_c + 0.1 tdcoa_c --> 0.01 1agly3p_SC_c + coa_c
# GBEZ : 14glun_c --> glycogen_c + h2o_c
# GCALDt : gcald_e <=> gcald_c
# GCALDtm : gcald_c <=> gcald_m
# GCC2am : gly_m + h_m + lpam_m <=> alpam_m + co2_m
# GCC2bim : alpam_m + thf_m --> dhlam_m + mlthf_m + nh4_m
# GCC2cm_copy1 : dhlam_m + nad_m <=> h_m + lpam_m + nadh_m
# GCCam : gly_m + h_m + lpro_m <=> alpro_m + co2_m
# GCCbim : alpro_m + thf_m --> dhlpro_m + mlthf_m + nh4_m
# GLYGS : h2o_c + udpg_c --> 14glun_c + h_c + udp_c
# GLYK : atp_c + glyc_c --> adp_c + glyc3p_c + h_c
# GLYOX : h2o_c + lgt__S_c --> gthrd_c + h_c + lac__D_c
# GLYOXm : h2o_m + lgt__S_m --> gthrd_m + h_m + lac__D_m
# GLYTRS : atp_c + gly_c + trnagly_c --> amp_c + glytrna_c + ppi_c
# GLYt2m : gly_c + h_c <=> gly_m + h_m
# GLYt2r : gly_e + h_e <=> gly_c + h_c
# GCCcm : dhlpro_m + nad_m <=> h_m + lpro_m + nadh_m
# GDPMANNtg : gdpmann_c + gmp_g --> gdpmann_g + gmp_c
# GMPS2 : atp_c + gln__L_c + h2o_c + xmp_c --> amp_c + glu__L_c + gmp_c + 2.0 h_c + ppi_c
# GDPt3g : gdp_g + h_c <=> gdp_c + h_g
# GND : 6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c
# FAS80_L : accoa_c + 8.0 h_c + 3.0 malcoa_c + 6.0 nadph_c --> 3.0 co2_c + 4.0 coa_c + 2.0 h2o_c + 6.0 nadp_c + octa_c
# GNNUC : gsn_c + h2o_c --> gua_c + rib__D_c
# GDPtn : gdp_c <=> gdp_n
# GF6PTA : f6p_c + gln__L_c --> gam6p_c + glu__L_c
# GPDDA1 : g3pc_c + h2o_c --> chol_c + glyc3p_c + h_c
# GGLGH : ggl_c + h2o_c <=> gal_c + glyc_c
# FBA : fdp_c <=> dhap_c + g3p_c
# GGTT : ggdp_c + ipdp_c --> pendp_c + ppi_c
# GHMT2r : ser__L_c + thf_c <=> gly_c + h2o_c + mlthf_c
# GHMT2rm : ser__L_m + thf_m <=> gly_m + h2o_m + mlthf_m
# GRTT : grdp_c + ipdp_c --> frdp_c + ppi_c
# GSNK : atp_c + gsn_c --> adp_c + gmp_c + h_c
# GSNt2 : gsn_e + h_e --> gsn_c + h_c
# GK1 : atp_c + gmp_c <=> adp_c + gdp_c
# GK2 : datp_c + gmp_c <=> dadp_c + gdp_c
# GLCGSD : glycogen_c + h2o_c --> glc__D_c
# GLCGSDv : glycogen_v + h2o_v --> glc__D_v
# GSNt2m : gsn_c + h_c <=> gsn_m + h_m
# GTHOr : gthox_c + h_c + nadph_c --> 2.0 gthrd_c + nadp_c
# GTHOXti : gthox_e --> gthox_c
# GTHOm : gthox_m + h_m + nadph_m --> 2.0 gthrd_m + nadp_m
# GLCNtv : glycogen_c --> glycogen_v
# FBA2 : f1p_c <=> dhap_c + glyald_c
# GLCP : glycogen_c + pi_c --> g1p_c
# GLCS2 : udpg_c --> glycogen_c + h_c + udp_c
# GTHPi : 2.0 gthrd_c + h2o2_c <=> gthox_c + 2.0 h2o_c
# GTHPm : 2.0 gthrd_m + h2o2_m <=> gthox_m + 2.0 h2o_m
# GTHRDabcv : atp_v + gthrd_c + h2o_v --> adp_v + gthrd_v + h_v + pi_v
# GTHRDt2 : gthrd_e --> gthrd_c
# GLCt1 : glc__D_e --> glc__D_c
# GLCtv : glc__D_c <=> glc__D_v
# FBA3 : s17bp_c <=> dhap_c + e4p_c
# GLNS : atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + h_c + pi_c
# GLNTRS : atp_c + gln__L_c + trnagln_c --> amp_c + glntrna_c + ppi_c
# GTHS : atp_c + glucys_c + gly_c --> adp_c + gthrd_c + h_c + pi_c
# GTMLT : ala__L_c + gthrd_c --> cgly_c + gluala_c
# GLNt2n : gln__L_c + h_c <=> gln__L_n + h_n
# FBP : fdp_c + h2o_c --> f6p_c + pi_c
# GLNt2r : gln__L_e + h_e <=> gln__L_c + h_c
# GLNt6 : gln__L_c + h_v --> gln__L_v + h_c
# GTPCI : gtp_c + h2o_c --> ahdt_c + for_c + h_c
# GTPCII : gtp_c + 3.0 h2o_c --> 25dhpp_c + for_c + 2.0 h_c + ppi_c
# GTPH1 : gtp_c + 2.0 h2o_c --> gmp_c + 2.0 h_c + 2.0 pi_c
# GLNt7 : gln__L_v + h_v --> gln__L_c + h_c
# GTPt2m : gdp_m + gtp_c + h_c --> gdp_c + gtp_m + h_m
# GLPT : glp_c + tdcoa_c --> coa_c + tglp_c
# FBP26 : f26bp_c + h2o_c --> f6p_c + pi_c
# GLU5K : atp_c + glu__L_c --> adp_c + glu5p_c
# GLUCYS : atp_c + cys__L_c + glu__L_c --> adp_c + glucys_c + h_c + pi_c
# GLUDC : glu__L_c + h_c --> 4abut_c + co2_c
# GUAD : gua_c + h2o_c + h_c --> nh4_c + xan_c
# GUAPRT : gua_c + prpp_c --> gmp_c + ppi_c
# GUAt2r : gua_e + h_e <=> gua_c + h_c
# GUAtm : gua_c <=> gua_m
# H2O2tn : h2o2_c <=> h2o2_n
# H2Ot : h2o_e <=> h2o_c
# GLUDxi : glu__L_c + h2o_c + nad_c --> akg_c + h_c + nadh_c + nh4_c
# GLUDy : glu__L_c + h2o_c + nadp_c <-- akg_c + h_c + nadph_c + nh4_c
# H2Oter : h2o_c <=> h2o_r
# FCLTm : fe2_m + ppp9_m --> 2.0 h_m + pheme_m
# H2Otm : h2o_c <=> h2o_m
# H2Otn : h2o_n <=> h2o_c
# H2Otp : h2o_c <=> h2o_x
# HCITSm : accoa_m + akg_m + h2o_m --> coa_m + h_m + hcit_m
# H2Otv : h2o_c <=> h2o_v
# HCITSn : accoa_n + akg_n + h2o_n --> coa_n + h_n + hcit_n
# FDH : for_c + nad_c --> co2_c + nadh_c
# HACD10p : 3hxccoa_x + nad_x <=> 3ohxccoa_x + h_x + nadh_x
# HACD4p : 3odcoa_x + h_x + nadh_x <=> 3hdcoa_x + nad_x
# FDNG : for_c + h_c + q6_m --> co2_c + q6h2_m
# HACD5p : 3oddcoa_x + h_x + nadh_x <=> 3hddcoa_x + nad_x
# HACD6p : 3otdcoa_x + h_x + nadh_x <=> 3htdcoa_x + nad_x
# HCO3E : co2_c + h2o_c <=> h_c + hco3_c
# HCO3Em : co2_m + h2o_m <=> h_m + hco3_m
# HCO3En : co2_n + h2o_n <=> h_n + hco3_n
# HACD7p : 3ohdcoa_x + h_x + nadh_x <=> 3hhdcoa_x + nad_x
# HACD8p : 3ohodcoa_x + h_x + nadh_x <=> 3hodcoa_x + nad_x
# HCO3tn : hco3_c <=> hco3_n
# HACNHm : b124tc_m + h2o_m <=> hicit_m
# FE2t : fe2_e --> fe2_c
# HBZOPT6m : 4hbz_m + hexdp_m --> 3ophb_5_m + ppi_m
# FE2utm : fe2_c --> fe2_m
# HCYSMT : amet_c + hcys__L_c --> ahcys_c + h_c + met__L_c
# HCYSt2p : h_c + hcys__L_c <=> h_x + hcys__L_x
# HDCAt : hdca_e --> hdca_c
# HDCEAt : hdcea_e --> hdcea_c
# FECOSTAT_SC : 0.01 fecost_c + 0.655 hdcoa_c + 0.01 hexccoa_c + 0.27 odecoa_c + 0.02 pmtcoa_c + 0.03 stcoa_c + 0.015 tdcoa_c --> coa_c + 0.01 fecostest_SC_c
# HEMEOMOm : hemeO_m + nadh_m + o2_m --> h2o_m + hemeA_m + nad_m
# HEMEOSm : frdp_m + h2o_m + pheme_m --> hemeO_m + ppi_m
# HETZK : 4mhetz_c + atp_c --> 4mpetz_c + adp_c + h_c
# FECOSTESTH_SC : 0.01 fecostest_SC_c + h2o_c --> 0.01 fecost_c + h_c + 0.02 hdca_c + 0.655 hdcea_c + 0.01 hexc_c + 0.03 ocdca_c + 0.27 ocdcea_c + 0.015 ttdca_c
# HEX1 : atp_c + glc__D_c --> adp_c + g6p_c + h_c
# HEX4 : atp_c + man_c --> adp_c + h_c + man6p_c
# FECOSTESTH_SCe : 0.01 fecostest_SC_e + h2o_e --> 0.01 fecost_e + h_e + 0.02 hdca_e + 0.655 hdcea_e + 0.01 hexc_e + 0.03 ocdca_e + 0.27 ocdcea_e + 0.015 ttdca_e
# HEX7 : atp_c + fru_c --> adp_c + f6p_c + h_c
# HEXCCOAtx : hexccoa_c <=> hexccoa_x
# HEXDPtm : hexdp_c <=> hexdp_m
# ILEtmi : ile__L_m --> ile__L_c
# FECOSTt : fecost_e <=> fecost_c
# HGNTOR : hgentis_c + o2_c --> 4mlacac_c + h_c
# HICITDm : hicit_m + nad_m <=> h_m + nadh_m + oxag_m
# FEtm : fe2_m --> fe2_c
# IMPC : h2o_c + imp_c <=> fprica_c
# FKYNH : Lfmkynr_c + h2o_c --> Lkynr_c + for_c + h_c
# IMPD : h2o_c + imp_c + nad_c --> h_c + nadh_c + xmp_c
# IND3ACtm : ind3ac_c <=> ind3ac_m
# HISTD : h2o_c + histd_c + 2.0 nad_c --> 3.0 h_c + his__L_c + 2.0 nadh_c
# FMETTRSm : 10fthf_m + mettrna_m --> fmettrna_m + h_m + thf_m
# HISTP : h2o_c + hisp_c --> histd_c + pi_c
# HISTRS : atp_c + his__L_c + trnahis_c --> amp_c + histrna_c + ppi_c
# IND3ETHt : ind3eth_c <=> ind3eth_e
# IND3ETHtm : ind3eth_c <=> ind3eth_m
# INDPYRD : h_c + indpyr_c <=> co2_c + id3acald_c
# HISTRSm : atp_m + his__L_m + trnahis_m --> amp_m + histrna_m + ppi_m
# INSK : atp_c + ins_c --> adp_c + h_c + imp_c
# FMNAT : atp_c + fmn_c + h_c --> fad_c + ppi_c
# HISt2m : h_m + his__L_m <=> h_c + his__L_c
# HISt2r : h_e + his__L_e <=> h_c + his__L_c
# HISt6 : h_v + his__L_c --> h_c + his__L_v
# HKYNH : h2o_c + hLkynr_c --> 3hanthrn_c + ala__L_c
# HMBS : h2o_c + 4.0 ppbng_c --> hmbil_c + 4.0 nh4_c
# INSTt2 : h_e + inost_e --> h_c + inost_c
# INSt2 : h_e + ins_e --> h_c + ins_c
# IPC124PLC_SC : h2o_c + 0.01 ipc124_SC_c --> cer1_24_c + h_c + mi1p__D_c
# IPC126PLC_SC : h2o_c + 0.01 ipc126_SC_c --> cer1_26_c + h_c + mi1p__D_c
# IPC224PLC_SC : h2o_c + 0.01 ipc224_SC_c --> cer2_24_c + h_c + mi1p__D_c
# IPC226PLC_SC : h2o_c + 0.01 ipc226_SC_c --> cer2_26_c + h_c + mi1p__D_c
# HMGCOAR : coa_c + mev__R_c + 2.0 nadp_c <=> 2.0 h_c + hmgcoa_c + 2.0 nadph_c
# HMGCOAS : coa_c + h_c + hmgcoa_c <=> aacoa_c + accoa_c + h2o_c
# HMGCOASm : coa_m + h_m + hmgcoa_m <=> aacoa_m + accoa_m + h2o_m
# IPC324PLC_SC : h2o_c + 0.01 ipc324_SC_c --> cer3_24_c + h_c + mi1p__D_c
# IPC326PLC_SC : h2o_c + 0.01 ipc326_SC_c --> cer3_26_c + h_c + mi1p__D_c
# HMGCOAtm : hmgcoa_c <=> hmgcoa_m
# FMNATm : atp_m + fmn_m + h_m --> fad_m + ppi_m
# HMPK1 : 4ahmmp_c + atp_c --> 4ampm_c + adp_c + h_c
# HPPKm : 2ahhmp_m + atp_m --> 2ahhmd_m + amp_m + h_m
# HPROa : 1p3h5c_c + 2.0 h_c + nadh_c --> 4hpro_LT_c + nad_c
# IPCS124_SC : cer1_24_c + 0.01 ptd1ino_SC_c --> 0.01 12dgr_SC_c + 0.01 ipc124_SC_c
# IPCS126_SC : cer1_26_c + 0.01 ptd1ino_SC_c --> 0.01 12dgr_SC_c + 0.01 ipc126_SC_c
# IPCS224_SC : cer2_24_c + 0.01 ptd1ino_SC_c --> 0.01 12dgr_SC_c + 0.01 ipc224_SC_c
# IPCS226_SC : cer2_26_c + 0.01 ptd1ino_SC_c --> 0.01 12dgr_SC_c + 0.01 ipc226_SC_c
# HPROb : 1p3h5c_c + 2.0 h_c + nadph_c --> 4hpro_LT_c + nadp_c
# HPROxm : 4hpro_LT_m + nad_m --> 1p3h5c_m + 2.0 h_m + nadh_m
# IPCS324_SC : cer3_24_c + 0.01 ptd1ino_SC_c --> 0.01 12dgr_SC_c + 0.01 ipc324_SC_c
# IPCS326_SC : cer3_26_c + 0.01 ptd1ino_SC_c --> 0.01 12dgr_SC_c + 0.01 ipc326_SC_c
# HPROym : 4hpro_LT_m + nadp_m --> 1p3h5c_m + 2.0 h_m + nadph_m
# FMNRx : fmn_c + h_c + nadh_c --> fmnh2_c + nad_c
# HSDxi : aspsa_c + h_c + nadh_c --> hom__L_c + nad_c
# IPDDI : ipdp_c <=> dmpp_c
# FMNRx2 : fmn_c + h_c + nadph_c --> fmnh2_c + nadp_c
# IPDPtm : ipdp_c <=> ipdp_m
# IPMD : 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c
# IPPMIa : 3c2hmp_c <=> 2ippm_c + h2o_c
# IPPMIb : 2ippm_c + h2o_c <=> 3c3hmp_c
# IPPS : 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c
# HSDy : hom__L_c + nadp_c <-- aspsa_c + h_c + nadph_c
# HSERTA : accoa_c + hom__L_c <=> achms_c + coa_c
# HSK : atp_c + hom__L_c --> adp_c + h_c + phom_c
# HSTPT : glu__L_c + imacp_c --> akg_c + hisp_c
# HXANt2r : h_e + hxan_e <=> h_c + hxan_c
# HXPRT : hxan_c + prpp_c --> imp_c + ppi_c
# HYPOE : h2o_c + pyam5p_c --> pi_c + pydam_c
# IAMACt : iamac_c --> iamac_e
# IAMOHt : iamoh_c <=> iamoh_e
# IAMOHtm : iamoh_c <=> iamoh_m
# IBUTACt : ibutac_c --> ibutac_e
# IBUTOHt : ibutoh_c <=> ibutoh_e
# IBUTOHtm : ibutoh_c <=> ibutoh_m
# ICDHxm : icit_m + nad_m --> akg_m + co2_m + nadh_m
# IPPSm : 3mob_m + accoa_m + h2o_m --> 3c3hmp_m + coa_m + h_m
# ITCOALm : atp_m + coa_m + itacon_m <=> adp_m + itaccoa_m + pi_m
# KARA1im : alac__S_m + h_m + nadph_m --> 23dhmb_m + nadp_m
# KARA2im : 2ahbut_m + h_m + nadph_m --> 23dhmp_m + nadp_m
# KYN : Lkynr_c + h2o_c --> ala__L_c + anth_c + h_c
# KYN3OX : Lkynr_c + h_c + nadph_c + o2_c --> h2o_c + hLkynr_c + nadp_c
# Kt2r : h_e + k_e <=> h_c + k_c
# LALDO3 : h_c + mthgxl_c + nadph_c --> lald__L_c + nadp_c
# LANOSTAT_SC : 0.655 hdcoa_c + 0.01 hexccoa_c + 0.01 lanost_c + 0.27 odecoa_c + 0.02 pmtcoa_c + 0.03 stcoa_c + 0.015 tdcoa_c --> coa_c + 0.01 lanostest_SC_c
# ICDHyr : icit_c + nadp_c --> akg_c + co2_c + nadph_c
# ICDHym : icit_m + nadp_m --> akg_m + co2_m + nadph_m
# ICDHyp : icit_x + nadp_x --> akg_x + co2_x + nadph_x
# ICL : icit_c --> glx_c + succ_c
# LANOSTESTH_SC : h2o_c + 0.01 lanostest_SC_c --> h_c + 0.02 hdca_c + 0.655 hdcea_c + 0.01 hexc_c + 0.01 lanost_c + 0.03 ocdca_c + 0.27 ocdcea_c + 0.015 ttdca_c
# FOLD3m : 2ahhmd_m + 4abz_m --> dhpt_m + ppi_m
# LANOSTESTH_SCe : h2o_e + 0.01 lanostest_SC_e --> h_e + 0.02 hdca_e + 0.655 hdcea_e + 0.01 hexc_e + 0.01 lanost_e + 0.03 ocdca_e + 0.27 ocdcea_e + 0.015 ttdca_e
# LANOSTt : lanost_e <=> lanost_c
# LCADi : h2o_c + lald__L_c + nad_c --> 2.0 h_c + lac__L_c + nadh_c
# LCYSTintv : cysi__L_v + h_v --> cysi__L_c + h_c
# LEUTA : akg_c + leu__L_c <=> 4mop_c + glu__L_c
# LEUTAm : akg_m + leu__L_m <=> 4mop_m + glu__L_m
# LEUTRS : atp_c + leu__L_c + trnaleu_c --> amp_c + leutrna_c + ppi_c
# LEUTRSm : atp_m + leu__L_m + trnaleu_m --> amp_m + leutrna_m + ppi_m
# ID3ACALDt : id3acald_c <=> id3acald_e
# ID3ACALDtm : id3acald_c <=> id3acald_m
# IG3PS : gln__L_c + prlp_c --> aicar_c + eig3p_c + glu__L_c + h_c
# ...
# YHR025W is associated with reactions: {HSK}
# YOR375C is associated with reactions: {GLUDy}
# YML123C is associated with reactions: {PIt2r}
# YAL062W is associated with reactions: {GLUDy}
# YIL116W is associated with reactions: {HSTPT}
# YNR013C is associated with reactions: {PIt2r}
# YCR037C is associated with reactions: {PIt2r}
# YNL037C is associated with reactions: {ICDHxm}
# YCL040W is associated with reactions: {GLUK, HEX1}
# YBR296C is associated with reactions: {PIt2r}
# YMR300C is associated with reactions: {GLUPRT}
# YJL198W is associated with reactions: {PIt2r}
# YDL171C is associated with reactions: {GLUSx}
# YOR136W is associated with reactions: {ICDHxm}
# YER053C is associated with reactions: {PIt5m}
# YLR174W is associated with reactions: {ICDHyr}
# YGL245W is associated with reactions: {GLUTRS}
# YOL011W is associated with reactions: {PLBP1I_SCe}
# YOL033W is associated with reactions: {GLUTRSm}
# YDL066W is associated with reactions: {ICDHym}
# YMR006C is associated with reactions: {PLBPC_SCe, PLBP1I_SCe}
# YNL009W is associated with reactions: {ICDHyp}
# YMR008C is associated with reactions: {PLBPC_SCe, PLBP1I_SCe}
# YER065C is associated with reactions: {ICL}
# YML059C is associated with reactions: {PLBPC_SC}
# YBR248C is associated with reactions: {IG3PS}
# YKR031C is associated with reactions: {PLD_SC}
# YOR202W is associated with reactions: {IGPDH}
# YOR143C is associated with reactions: {TMDPPK, TMDPK}
# YFL045C is associated with reactions: {PMANM}
# YOR074C is associated with reactions: {TMDS}
# YJR148W is associated with reactions: {VALTA, LEUTA, ILETA, OMCDC}
# YMR220W is associated with reactions: {PMEVK}
# YHR208W is associated with reactions: {VALTAim, LEUTAm, ILETAm, OMCDCm}
# YDR050C is associated with reactions: {TPI}
# YDR353W is associated with reactions: {TRDR}
# YOR163W is associated with reactions: {PMI1346PH, PMI12346PH}
# YHR106W is associated with reactions: {TRDRm}
# YDR017C is associated with reactions: {PMI12346PS, PMI1346PS}
# YML100W is associated with reactions: {TRE6PS, TRE6PP}
# YBL076C is associated with reactions: {ILETRS}
# YDR531W is associated with reactions: {PNTK}
# YPL040C is associated with reactions: {ILETRSm}
# YCR028C is associated with reactions: {PNTOt2}
# YAR073W is associated with reactions: {IMPD}
# YMR261C is associated with reactions: {TRE6PS, TRE6PP}
# YMR020W is associated with reactions: {POLYAO3, POLYAO, POLYAO2}
# YBR011C is associated with reactions: {PPA}
# YDR074W is associated with reactions: {TRE6PS, TRE6PP}
# YML056C is associated with reactions: {IMPD}
# YMR267W is associated with reactions: {PPAm}
# YLR432W is associated with reactions: {IMPD}
# YBR126C is associated with reactions: {TRE6PS, TRE6PP}
# YGL040C is associated with reactions: {PPBNGS}
# YBR001C is associated with reactions: {TREH}
# YAR075W is associated with reactions: {IMPD}
# YKR097W is associated with reactions: {PPCK}
# YHR216W is associated with reactions: {IMPD}
# YDR001C is associated with reactions: {TREH}
# YBR166C is associated with reactions: {PPND2}
# YNL316C is associated with reactions: {PPNDH}
# YPR026W is associated with reactions: {TREHv}
# YOR245C is associated with reactions: {TRIGS_SC}
# YJR078W is associated with reactions: {TRPO2}
# YOL103W is associated with reactions: {INSTt2}
# YDR497C is associated with reactions: {INSTt2}
# YER019W is associated with reactions: {IPC226PLC_SC, IPC126PLC_SC, MIP2C326PLC_SC, MIPC126PLC_SC, IPC324PLC_SC, MIP2C226PLC_SC, IPC326PLC_SC, MIPC224PLC_SC, MIP2C124PLC_SC, IPC224PLC_SC, MIPC124PLC_SC, MIPC226PLC_SC, MIP2C224PLC_SC, MIP2C324PLC_SC, IPC124PLC_SC, MIPC326PLC_SC, MIP2C126PLC_SC, MIPC324PLC_SC}
# YKL004W is associated with reactions: {IPCS324_SC, IPCS224_SC, IPCS226_SC, IPCS124_SC, IPCS126_SC, IPCS326_SC}
# YER014W is associated with reactions: {PPPGOm}
# YPL117C is associated with reactions: {IPDDI}
# YGL026C is associated with reactions: {TRPS1}
# YBR003W is associated with reactions: {PPTTm}
# YOL097C is associated with reactions: {TRPTRS}
# YGL234W is associated with reactions: {PRAIS, PRAGSr}
# YDR268W is associated with reactions: {TRPTRSm}
# YDR007W is associated with reactions: {PRAIi}
# YCL018W is associated with reactions: {IPMD}
# YGL009C is associated with reactions: {IPPMIb, IPPMIa}
# YDR403W is associated with reactions: {TYRNFT}
# YAR015W is associated with reactions: {PRASCSi}
# YGR185C is associated with reactions: {TYRTRS}
# YOR108W is associated with reactions: {IPPS}
# YNL104C is associated with reactions: {IPPS, IPPSm}
# YGR061C is associated with reactions: {PRFGS}
# YIL020C is associated with reactions: {PRMICI}
# YGR244C is associated with reactions: {ITCOALm, SUCOASm}
# YPL097W is associated with reactions: {TYRTRSm}
# YDL103C is associated with reactions: {UDPACGLP}
# YLR142W is associated with reactions: {PRO1xm}
# YBR019C is associated with reactions: {UDPG4E}
# YOR142W is associated with reactions: {ITCOALm, SUCOASm}
# YHR020W is associated with reactions: {PROTRS}
# YBL098W is associated with reactions: {KYN3OX}
# YER087W is associated with reactions: {PROTRS}
# YPL244C is associated with reactions: {UDPGALt2g}
# YHL011C is associated with reactions: {PRPPS}
# YIR032C is associated with reactions: {UGLYCH}
# YER099C is associated with reactions: {PRPPS}
# YKL024C is associated with reactions: {URIDK2r, UMPK, UMPKn, URIDK2rn}
# YOL151W is associated with reactions: {LALDO3}
# YCR075C is associated with reactions: {LCYSTintv}
# YOL061W is associated with reactions: {PRPPS}
# YBL068W is associated with reactions: {PRPPS}
# YPL160W is associated with reactions: {LEUTRS}
# YKR069W is associated with reactions: {UPP3MT}
# YKL181W is associated with reactions: {PRPPS}
# YOR278W is associated with reactions: {UPP3S}
# YGR170W is associated with reactions: {PSERDv_SC, PSERDg_SC}
# YDR047W is associated with reactions: {UPPDC1}
# YHR128W is associated with reactions: {UPPRT}
# YLR382C is associated with reactions: {LEUTRSm}
# YNL169C is associated with reactions: {PSERDm_SC}
# YML004C is associated with reactions: {LGTHL}
# YBR021W is associated with reactions: {URAt2}
# YER026C is associated with reactions: {PSERSm_SC, PSERS_SC}
# YHL016C is associated with reactions: {UREA2t2}
# YHR007C is associated with reactions: {LNS14DM, LNS14DMx}
# YDR294C is associated with reactions: {SPHPL, PSPHPL}
# YBL042C is associated with reactions: {URIt2}
# YGR208W is associated with reactions: {PSP_L}
# YJR019C is associated with reactions: {PTE2x, PTE12x, PTE11x, PTE8x, PTE9x, PTE10x, PTE7x}
# YGR094W is associated with reactions: {VALTRSm, VALTRS}
# YHR072W is associated with reactions: {LNSTLS}
# YOR273C is associated with reactions: {SPMDt3i, PTRCt3i, SPRMt2i}
# YPR140W is associated with reactions: {LPCAT_SC}
# YJR133W is associated with reactions: {XPPT}
# YLL028W is associated with reactions: {SPMDt3i, PTRCt3i, SPRMt2i}
# YGR194C is associated with reactions: {XYLK}
# YDR037W is associated with reactions: {LYSTRS}
# YKL174C is associated with reactions: {SPMDtex2, PTRCtex2}
# YNL073W is associated with reactions: {LYSTRSm}
# YLR070C is associated with reactions: {XYLTD_D}
# YNL268W is associated with reactions: {LYSt2r}
# YOR347C is associated with reactions: {PYK}
# YML054C is associated with reactions: {L_LACD2cm}
# YAL038W is associated with reactions: {PYK}
# YGL063W is associated with reactions: {YUMPS}
# YDR236C is associated with reactions: {RBFKm, RBFK}
# YPL212C is associated with reactions: {YUMPS}
# YNL117W is associated with reactions: {MALSp, MALS}
# YIR031C is associated with reactions: {MALSp, MALS}
# YOL143C is associated with reactions: {RBFSa}
# YJL216C is associated with reactions: {MALT}
# YBR299W is associated with reactions: {MALT}
# YFL001W is associated with reactions: {YUMPS}
# YBR256C is associated with reactions: {RBFSb}
# YGR287C is associated with reactions: {MALT}
# YIL066C is associated with reactions: {RNDR1, RNDR1n}
# YGR292W is associated with reactions: {MALT}
# YNL292W is associated with reactions: {YUMPS}
# YER060W_A is associated with reactions: {CSNt2, ADEt2, GUAt2r}
# YER070W is associated with reactions: {RNDR1, RNDR2n, RNDR4, RNDR4n, RNDR3n, RNDR2, RNDR3, RNDR1n}
# YJL026W is associated with reactions: {RNDR1, RNDR3, RNDR4, RNDR2}
# YEL017C_A is associated with reactions: {ATPS}
# YIL172C is associated with reactions: {MALT}
# YGR180C is associated with reactions: {RNDR2n, RNDR1n, RNDR4n, RNDR3n}
# YGR289C is associated with reactions: {MALTt2}
# YNL129W is associated with reactions: {RNMK}
# YCR024C_A is associated with reactions: {ATPS}
# YJL121C is associated with reactions: {RPE}
# YHR039C_A is associated with reactions: {ATPS3v, ATPS3g}
# YDL247W is associated with reactions: {MALTt2}
# YOR095C is associated with reactions: {RPI}
# YJR160C is associated with reactions: {MALTt2}
# YBR298C is associated with reactions: {MALTt2}
# YDR322C_A is associated with reactions: {ATPS3m}
# YNR050C is associated with reactions: {SACCD1}
# YML081C_A is associated with reactions: {ATPS3m}
# YIR034C is associated with reactions: {SACCD2}
# YLR348C is associated with reactions: {SUCCtm, MALtm, SUCFUMtm}
# YJR010W is associated with reactions: {SADT}
# YDL055C is associated with reactions: {MAN1PT}
# YER003C is associated with reactions: {MAN6PI}
# YOL077W_A is associated with reactions: {ATPS3m}
# YML008C is associated with reactions: {SAM24MT}
# YHR001W_A is associated with reactions: {CYOR_u6m}
# YPR006C is associated with reactions: {MCITL2m}
# YKR053C is associated with reactions: {SBPP1er, SBPP2er}
# YOL126C is associated with reactions: {MDH}
# YCR073W_A is associated with reactions: {PGL}
# YJL134W is associated with reactions: {SBPP1er, SBPP2er}
# YJR159W is associated with reactions: {SBTD_L, SBTD_D2}
# YBR058C_A is associated with reactions: {SERPT}
# YKL085W is associated with reactions: {MDHm}
# YIL167W is associated with reactions: {SERD_L}
# YDL078C is associated with reactions: {MDHp}
# YCL064C is associated with reactions: {THRD_L, SERD_L}
# YKL029C is associated with reactions: {ME1m, ME2m}
# YDR062W is associated with reactions: {SERPT}
# YMR296C is associated with reactions: {SERPT}
# YLR180W is associated with reactions: {METAT}
# YDR502C is associated with reactions: {METAT}
# YDR023W is associated with reactions: {SERTRS}
# YJR130C is associated with reactions: {METB1}
# YHR011W is associated with reactions: {SERTRS}
# YJL068C is associated with reactions: {SFGTHi}
# YBR213W is associated with reactions: {SHCHD, SHCHF}
# YER091C is associated with reactions: {MHPGLUT, METS}
# YML082W is associated with reactions: {SHSL4r}
# YOR171C is associated with reactions: {SLCBK2, SLCBK1}
# YGR264C is associated with reactions: {METTRS}
# YLR260W is associated with reactions: {SLCBK2, SLCBK1}
# YPL092W is associated with reactions: {SO3ti}
# YGR171C is associated with reactions: {METTRSm}
# YLR092W is associated with reactions: {SO4ti}
# YBR294W is associated with reactions: {SO4ti}
# YGR125W is associated with reactions: {SO4ti}
# YGR055W is associated with reactions: {METt2r}
# YPR069C is associated with reactions: {SPMS}
# YLR146C is associated with reactions: {SPRMS}
# YHL036W is associated with reactions: {METt2r}
# YMR208W is associated with reactions: {MEVK2, MEVK3, MEVK4, MEVK1}
# YPR156C is associated with reactions: {SPRMt2i}
# YJR073C is associated with reactions: {PMETM_SC, MFAPS_SC}
# YGR138C is associated with reactions: {SPRMt2i}
# YGR175C is associated with reactions: {SQLEr, SQLErx}
# YDR315C is associated with reactions: {MI13456PKn}
# YHR190W is associated with reactions: {SQLS}
# YBR006W is associated with reactions: {SSALy}
# YDR173C is associated with reactions: {MI145P6Kn, MI1456PKn, MI1345PKn, MI145PKn}
# YJL045W is associated with reactions: {SUCD2_u6m, SUCD1m, SUCD3_u6m}
# YHR046C is associated with reactions: {MI1PP}
# YKL148C is associated with reactions: {SUCD2_u6m, SUCD1m, SUCD3_u6m}
# YKL141W is associated with reactions: {SUCD2_u6m, SUCD1m, SUCD3_u6m}
# YJL153C is associated with reactions: {MI1PS}
# YLL041C is associated with reactions: {SUCD2_u6m, SUCD1m, SUCD3_u6m}
# YDR072C is associated with reactions: {MIP2CS124_SC, MIP2CS226_SC, MIP2CS324_SC, MIP2CS224_SC, MIP2CS326_SC, MIP2CS126_SC}
# YLR164W is associated with reactions: {SUCD2_u6m, SUCD1m, SUCD3_u6m}
# YPL057C is associated with reactions: {MIPCS126_SC, MIPCS326_SC, MIPCS226_SC, MIPCS224_SC, MIPCS324_SC, MIPCS124_SC}
# YDR178W is associated with reactions: {SUCD2_u6m, SUCD1m, SUCD3_u6m}
# YMR118C is associated with reactions: {SUCD2_u6m, SUCD1m, SUCD3_u6m}
# YBR161W is associated with reactions: {MIPCS126_SC, MIPCS326_SC, MIPCS226_SC, MIPCS224_SC, MIPCS324_SC, MIPCS124_SC}
# YJR095W is associated with reactions: {SUCFUMtm}
# YLL061W is associated with reactions: {MMETt2}
# YIL162W is associated with reactions: {SUCRe}
# YJR137C is associated with reactions: {SULR}
# YBR176W is associated with reactions: {MOHMT}
# YFR030W is associated with reactions: {SULR}
# YLR017W is associated with reactions: {MTAP}
# YMR313C is associated with reactions: {TAGL_SC}
# YDR058C is associated with reactions: {TAGL_SC}
# YKR080W is associated with reactions: {MTHFD2i}
# YLR354C is associated with reactions: {TALA}
# YGR043C is associated with reactions: {TALA}
# YGL125W is associated with reactions: {MTHFR3}
# YLL057C is associated with reactions: {TAUDO}
# YLL048C is associated with reactions: {TCHOLAabcv}
# YPL023C is associated with reactions: {MTHFR3}
# YOR241W is associated with reactions: {THFGLUS}
# YGR260W is associated with reactions: {NACt}
# YMR113W is associated with reactions: {THFGLUS}
# YGL067W is associated with reactions: {NADDPp}
# YKL132C is associated with reactions: {THFGLUS}
# YDR453C is associated with reactions: {THIORDXi}
# YDL085W is associated with reactions: {NADH2_u6cm}
# YCR083W is associated with reactions: {THIORDXm, TRDRm}
# YBL064C is associated with reactions: {THIORDXm}
# YMR145C is associated with reactions: {NADH2_u6cm}
# YML120C is associated with reactions: {NADH2_u6m}
# YIL010W is associated with reactions: {THIORDXni}
# YPL188W is associated with reactions: {NADKm, NADK}
# YLR109W is associated with reactions: {THIORDXp}
# YJR049C is associated with reactions: {NADKm, NADK}
# YBR092C is associated with reactions: {THMPe, THMDPe}
# YEL041W is associated with reactions: {NADKm, NADK}
# YGR096W is associated with reactions: {THMPPt2m}
# YHR074W is associated with reactions: {NADS1n, NADS1}
# YLR237W is associated with reactions: {THMt2}
# YOR071C is associated with reactions: {THMt2}
# YOR209C is associated with reactions: {NAPRTm, NAPRT}
# YOR192C is associated with reactions: {THMt2}
# YLR138W is associated with reactions: {NAt3_1}
# YEL042W is associated with reactions: {NDP3g}
# YEL046C is associated with reactions: {THRA2, THRA}
# YKL218C is associated with reactions: {THRD_L}
# YER086W is associated with reactions: {THRD_Lm}
# YKL067W is associated with reactions: {NDPK4, NDPK7, NDPK6, NDPK2, NDPK9, NDPK1, NDPK8, NDPK5, NDPK3}
# YBR180W is associated with reactions: {NFORTYRt}
# YIL078W is associated with reactions: {THRTRS}
# YDR402C is associated with reactions: {NFTYROX}
# YKL194C is associated with reactions: {THRTRSm}
# YGR121C is associated with reactions: {NH4t}
# YNL142W is associated with reactions: {NH4t}
# YBR117C is associated with reactions: {TKT1, TKT2}
# YPR138C is associated with reactions: {NH4t}
# YPR074C is associated with reactions: {TKT1, TKT2}
# YDR384C is associated with reactions: {NH4ti}
# YGR010W is associated with reactions: {NMNAT}
# YLR328W is associated with reactions: {NMNATm, NNATr, NNATm}
# YGL037C is associated with reactions: {NNAM, NNAMrm}
# YFR047C is associated with reactions: {NNDPRm, NNDPR}
# YLR285W is associated with reactions: {NNMT}
# YOR155C is associated with reactions: {NTD11}
# YGL224C is associated with reactions: {NTD4, NTD2}
# YJL126W is associated with reactions: {NTRLASE3, NTRLASE2, NTRLASE}
# YIL164C is associated with reactions: {NTRLASE3, NTRLASE2, NTRLASE}
# YLR351C is associated with reactions: {NTRLASE3, NTRLASE2, NTRLASE}
# YKL120W is associated with reactions: {OAAt2m}
# YJL088W is associated with reactions: {OCBT}
# YOR377W is associated with reactions: {OHACT4, OHACT5, OHACT1, OHACT2, OHACT3}
# YGR177C is associated with reactions: {OHACT4, OHACT5, OHACT1, OHACT2, OHACT3}
# YOR184W is associated with reactions: {PSERT, OHPBAT}
# YEL021W is associated with reactions: {OMPDC}
# YKL184W is associated with reactions: {ORNDC}
# 47_AT1 is associated with reactions: {acl_n}
# 47_AT2 is associated with reactions: {acl_n}

# %%
cobra.io.write_sbml_model(model, "iMM904_ac_me_jan_06.xml")
