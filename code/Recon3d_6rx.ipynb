# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import cobra
from cobra import Model, Reaction, Metabolite
from cobra.io import load_matlab_model, write_sbml_model
model= cobra.io.read_sbml_model("Recon3D.xml") #Utilizaremos como base el modelo recon3d, el cual contiene mas reacciones, metabolitos e información de la red metabolica humana (actualmente).
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %%
model
# Out:
# <Model Recon3D at 0x7f67dd5de3a0>

# %%
#Agregar rx 1 
R1 = Reaction('cit_nt')
R1.name = 'cit_nt'
R1.subsystem = ''
R1.lower_bound = -1000.  # This is the default
R1.upper_bound = 1000.  # This is the default

#Agregar rx 2 
R2 = Reaction('oaa_nt')
R2.name = 'oaa_nt'
R2.subsystem = ''
R2.lower_bound = -1000.  # This is the default
R2.upper_bound = 1000.  # This is the default

#Agregar rx 3 
R3 = Reaction('acl_n')
R3.name = 'ATP-Citrate lyase, nuclear'
R3.subsystem = ''
R3.lower_bound = 0.  # This is the default
R3.upper_bound = 1000.  # This is the default

#Agregar rx 4 PACYL: accoa_n + prot_n --> protac_n + coa_n 
R4 = Reaction('PACYL')
R4.name = 'PACYL'
R4.subsystem = ''
R4.lower_bound = 0.  # This is the default
R4.upper_bound = 1000.  # This is the default

#Agregar rx 5 EX_PAC: protac_n -->  
R5 = Reaction('EX_PAC')
R5.name = 'protein acetylation exchange'
R5.subsystem = 'acetylation exchange'
R5.lower_bound = 0.  # This is the default
R5.upper_bound = 1000.  # This is the default

#Agregar rx 6 EX_P    --> prot_n
R6 = Reaction('EX_P')
R6.name = 'nuclear protein consume reaction'
R6.subsystem = 'nuclear protein'
R6.lower_bound = 0.  # This is the default
R6.upper_bound = 1000.  # This is the default

# %%
#Metabolites

cit_n= Metabolite(
    'cit_n',
    formula='C6H5O7',
    name='Citrate',
    compartment='n')

cit_c= Metabolite(
    'cit_c',
    formula='C6H5O7',
    name='Citrate',
    compartment='c')

oaa_n= Metabolite(
    'oaa_n',
    formula='C4H2O5',
    name='Oxaloacetate',
    compartment='n')

coa_n= Metabolite(
    'coa_n',
    formula='C21H32N7O16P3S',
    name='Coenzyme A',
    compartment='n')

accoa_n= Metabolite(
    'accoa_n',
    formula='C23H34N7O17P3S',
    name='Acetyl-CoA',
    compartment='n')

accoa_c= Metabolite(
    'accoa_c',
    formula='C23H34N7O17P3S',
    name='Acetyl-CoA',
    compartment='c')

coa_c= Metabolite(
    'coa_c',
    formula='C21H32N7O16P3S',
    name='Coenzyme A',
    compartment='c')

oaa_c= Metabolite(
    'oaa_c',
    formula='C4H2O5',
    name='Oxaloacetate',
    compartment='c')

atp_n= Metabolite(
    'atp_n',
    formula='C10H12N5O13P3',
    name='atp',
    compartment='n')

adp_n= Metabolite(
    'adp_n',
    formula='C10H12N5O10P2',
    name='adp',
    compartment='n')

pi_n= Metabolite(
    'pi_n',
    formula='HO4P',
    name='Phosphate',
    compartment='n')

prot_n= Metabolite(
    'prot_n',
    formula='',
    name='Protein nucleus',
    compartment='n')

protac_n= Metabolite(
    'protac_n',
    formula='',
    name='Protein acetilation nucleus',
    compartment='n')

protac_c= Metabolite(
    'protac_c',
    formula='',
    name='Protein acetilation citosol',
    compartment='c')

prot_e= Metabolite(
    'prot_e',
    formula='',
    name='Protein extracellular',
    compartment='e')

prot_c= Metabolite(
    'prot_c',
    formula='',
    name='Protein citosol',
    compartment='c')

# %%
#Agregar metabolitos a la rx.

R1.add_metabolites({ 
    cit_n: -1.0, 
    cit_c: 1.0, 
})
#R1.reaction 

R2.add_metabolites({ 
    oaa_n: -1.0, 
    oaa_c: 1.0, 
})
#R2.reaction 

R3.add_metabolites({ 
    atp_n: -1.0, 
    cit_n: -1.0, 
    coa_n: -1.0,
    accoa_n: 1.0,
    adp_n: 1.0,
    oaa_n: 1.0,
    pi_n: 1.0,
})
#R3.reaction 

#R4.reaction  accoa_n + prot_n --> protac_n + coa_n
R4.add_metabolites({ 
    accoa_n: -1.0, 
    prot_n: -1.0, 
    protac_n: 1.0,
    coa_n: 1.0,
})


#EX_PAC: protac_n -->  
R5.add_metabolites({ 
    protac_n: -1.0, 

})

#    --> prot_n
R6.add_metabolites({ 
    prot_n: 1.0, 

})

# %%
#Verificar rx. agregadas
print(R1)
print(R2)
print(R3)
print(R4)
print(R5)
print(R6)
# Out:
# cit_nt: cit_n <=> cit_c
# oaa_nt: oaa_n <=> oaa_c
# acl_n: atp_n + cit_n + coa_n --> accoa_n + adp_n + oaa_n + pi_n
# PACYL: accoa_n + prot_n --> coa_n + protac_n
# EX_PAC: protac_n -->
# EX_P:  --> prot_n

# %%
#Incluir gene reaction rule, en este caso solo contamos con la grr en R3
R1.gene_reaction_rule =''
R2.gene_reaction_rule =''
R3.gene_reaction_rule ='(47_AT1 or 47_AT2)'
R4.gene_reaction_rule =''
R5.gene_reaction_rule =''
R6.gene_reaction_rule =''

# %%
print(f'{len(model.reactions)} reactions initially')
print(f'{len(model.metabolites)} metabolites initially')
print(f'{len(model.genes)} genes initially')
# Out:
# 10600 reactions initially
# 5835 metabolites initially
# 2248 genes initially

# %%
model.add_reactions([R1,R2,R3,R4,R5,R6])

# The objects have been added to the model
print(f'{len(model.reactions)} reactions')
print(f'{len(model.metabolites)} metabolites')
print(f'{len(model.genes)} genes')
# Out:
# 10606 reactions
# 5839 metabolites
# 2248 genes

# %%
# Iterate through the the objects in the model
print("Reactions")
print("---------")
for x in model.reactions:
    print("%s : %s" % (x.id, x.reaction))

print("")
print("Metabolites")
print("-----------")
for x in model.metabolites:
    print('%9s : %s' % (x.id, x.formula))

print("")
print("Genes")
print("-----")
for x in model.genes:
    associated_ids = (i.id for i in x.reactions)
    print("%s is associated with reactions: %s" %
          (x.id, "{" + ", ".join(associated_ids) + "}"))
# Out:
# Reactions
# ---------
# 24_25DHVITD3tm : 2425dhvitd3_m --> 2425dhvitd3_c
# 25HVITD3t : 25hvitd3_c --> 25hvitd3_e
# COAtl : coa_c <=> coa_l
# EX_5adtststerone_e : 5adtststerone_e <=>
# EX_5adtststerones_e : 5adtststerones_e <=>
# EX_5fthf_e : 5fthf_e <=>
# EX_5htrp_e : 5htrp_e <=>
# EX_5mthf_e : 5mthf_e <=>
# EX_5thf_e : 5thf_e <=>
# EX_6dhf_e : 6dhf_e <=>
# 24_25VITD3Hm : 25hvitd3_m + h_m + nadph_m + o2_m --> 2425dhvitd3_m + h2o_m + nadp_m
# 24NPHte : 24nph_e <=> 24nph_c
# 10FTHF7GLUtl : 10fthf7glu_c --> 10fthf7glu_l
# 10FTHFtm : 10fthf_c <=> 10fthf_m
# 11DOCRTSLtr : 11docrtsl_c <=> 11docrtsl_r
# 13DAMPPOX : 13dampp_c + h2o_c + o2_c --> bamppald_c + h2o2_c + nh4_c
# 24_25DHVITD2t : 2425dhvitd2_c --> 2425dhvitd2_e
# 24_25DHVITD2tm : 2425dhvitd2_m --> 2425dhvitd2_c
# 24_25DHVITD3t : 2425dhvitd3_c --> 2425dhvitd3_e
# 25VITD2Hm : 25hvitd2_m + h_m + nadph_m + o2_m --> 1a25dhvitd2_m + h2o_m + nadp_m
# 2AMACHYD : 2amac_c + h2o_c --> nh4_c + pyr_c
# 2AMACSULT : 2amac_c + nadph_c + paps_c --> Lcyst_c + nadp_c + pap_c
# 2AMADPTm : L2aadp_c + akg_m --> L2aadp_m + akg_c
# 2MCITt : 2mcit_c <=> 2mcit_e
# 2OXOADOXm : 2oxoadp_m + coa_m + nad_m --> co2_m + glutcoa_m + nadh_m
# 2OXOADPTm : 2oxoadp_c + akg_m <=> 2oxoadp_m + akg_c
# 34DHPHEt : 34dhphe_e <=> 34dhphe_c
# 34DHXMANDACOX : 34dhmald_c + h2o_c + nad_c --> 34dhoxmand_c + 2.0 h_c + nadh_c
# 34HPLFM : 34hpp_m + h_m + nadh_m --> 34hpl_m + nad_m
# 3AIBtm : 3aib_m --> 3aib_c
# 3HAO : 3hanthrn_c + o2_c --> cmusa_c + h_c
# 3MOBt2im : 3mob_c + h_c --> 3mob_m + h_m
# 3MOPt2im : 3mop_c + h_c --> 3mop_m + h_m
# 3MOXTYROX : 3moxtyr_c + h2o_c + o2_c --> 3mox4hpac_c + h2o2_c + nh4_c
# 3SALAOX : 2.0 3sala_c + 2.0 h_c + o2_c --> 2.0 Lcyst_c
# 42A12BOOX : dopa_c + h2o_c + o2_c --> 34dhpac_c + h2o2_c + nh4_c
# 4HBZCOAFm : coa_m + coucoa_m + h2o_m + nad_m --> 4hbzcoa_m + accoa_m + h_m + nadh_m
# 4HBZFm : 4hbzcoa_m + h2o_m --> 4hbz_m + coa_m + h_m
# 4HDEBRISOQUINEte : 4hdebrisoquine_e <=> 4hdebrisoquine_c
# 4HOXPACDOX_NADP : 4hoxpacd_c + h2o_c + nadp_c <=> 4hphac_c + 2.0 h_c + nadph_c
# 4MOPt2im : 4mop_c + h_c --> 4mop_m + h_m
# 4MPTNLte : 4mptnl_c <=> 4mptnl_e
# 4NPHSULT : 4nph_c + paps_c --> 4nphsf_c + h_c + pap_c
# 4PYRDX : 4pyrdx_c + atp_c + h2o_c --> 4pyrdx_e + adp_c + h_c + pi_c
# 5ADTSTSTERONEGLCtr : 5adtststeroneglc_c <=> 5adtststeroneglc_r
# 5ADTSTSTERONESULT : 5adtststerone_c + paps_c --> 5adtststerones_c + h_c + pap_c
# 5ADTSTSTERONEte : 5adtststerone_e <=> 5adtststerone_c
# 5FTHFt2_1 : 5fthf_e + h2o_c <=> 5fthf_c + h2o_e
# 5HOXINOXDA : h2o_c + o2_c + srtn_c --> 5hoxindact_c + h2o2_c + nh4_c
# 5THFtl : 5thf_c --> 5thf_l
# 5THFtm : 5thf_m --> 5thf_c
# 7DHCHSTEROLtr : 7dhchsterol_r <=> 7dhchsterol_c
# 7DHFtm : 7dhf_m --> 7dhf_c
# A4GALTc : galgluside_hs_c + udpgal_c --> h_c + thcrm_hs_c + udp_c
# A4GALTg : galgluside_hs_g + udpgal_g --> h_g + thcrm_hs_g + udp_g
# A4GNT2g : core2_g + uacgam_g --> gncore2_g + h_g + udp_g
# AACTtm : aact_m --> aact_c
# ABO1g : fucgalacglcgalgluside_hs_g + udpacgal_g --> acgalfucgalacglcgalgluside_hs_g + h_g + udp_g
# ABO4g : fuc12gal14acglcgalgluside_hs_g + udpacgal_g --> acgalfuc12gal14acglcgalgluside_hs_g + h_g + udp_g
# ABO5g : fucgalacgalfuc12gal14acglcgalgluside_hs_g + udpacgal_g --> acgalfucgalacgalfuc12gal14acglcgalgluside_hs_g + h_g + udp_g
# ABO6g : fucgalacglcgal14acglcgalgluside_hs_g + udpacgal_g --> acgalfucgalacglcgal14acglcgalgluside_hs_g + h_g + udp_g
# ABO7g : fucgalacgalfucgalacglcgal14acglcgalgluside_hs_g + udpacgal_g --> acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs_g + h_g + udp_g
# ABO9g : fucfucgalacglcgalacglcgal14acglcgalgluside_hs_g + 2.0 udpgal_g --> galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_g + 2.0 h_g + 2.0 udp_g
# ABTArm : 4abut_m + akg_m <=> glu__L_m + sucsal_m
# ABTt : abt_e <-- abt_c
# ABUTt2rL : 4abut_l + h_l <=> 4abut_c + h_c
# ACACT10m : 2maacoa_m + coa_m <=> accoa_m + ppcoa_m
# ACACT5p : 3oddcoa_x + coa_x --> accoa_x + dcacoa_x
# ACACT8p : 3ohodcoa_x + coa_x --> accoa_x + pmtcoa_x
# ACACT9p : 3ohxccoa_x + coa_x --> accoa_x + ttccoa_x
# ACALDtr : acald_r <=> acald_c
# ACALDtx : acald_x <=> acald_c
# ACCOALm : atp_m + coa_m + ppa_m --> amp_m + ppcoa_m + ppi_m
# ACCOAtr : accoa_c <=> accoa_r
# ACETONEt2 : acetone_e + h_e <=> acetone_c + h_c
# ACGAGBSIDEtl : acgagbside_hs_c <=> acgagbside_hs_l
# ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEte : acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs_e <=> acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs_c
# ACGALtlg : acgal_g <=> acgal_c
# ACGAMK : acgam_c + atp_c --> acgam6p_c + adp_c + h_c
# ACGAMPM : acgam6p_c <=> acgam1p_c
# ACGAMtly : acgam_l --> acgam_c
# ACGBGBSIDEtl : acgbgbside_hs_c <=> acgbgbside_hs_l
# ACHtn : ach_n <=> ach_c
# ACHVESSEC_1 : ach_c + atp_c + h2o_c --> ach_e + adp_c + h_c + pi_c
# ACN13ACNGALGBSIDEtg : acn13acngalgbside_hs_c <=> acn13acngalgbside_hs_g
# ACNACNGAL14ACGLCGALGLUSIDEtg : acnacngal14acglcgalgluside_hs_g <=> acnacngal14acglcgalgluside_hs_c
# ACNACNGALGBSIDEtg : acnacngalgbside_hs_c <=> acnacngalgbside_hs_g
# ACNAMlt : acnam_c + h_c <=> acnam_l + h_l
# ACNAMtn : acnam_c --> acnam_n
# ACNGALACGLCGAL14ACGLCGALGLUSIDEte : acngalacglcgal14acglcgalgluside_hs_e <=> acngalacglcgal14acglcgalgluside_hs_c
# ACNML : acnam_c <=> acmana_c + pyr_c
# ACOAD10m : 2mbcoa_m + fad_m --> 2mb2coa_m + fadh2_m
# ACOAD8m : fad_m + ivcoa_m --> 3mb2coa_m + fadh2_m
# ACOAD9m : fad_m + ibcoa_m --> 2mp2coa_m + fadh2_m
# ACOAO7p : o2_x + pmtcoa_x --> h2o2_x + hdd2coa_x
# ACODA : acorn_c + h2o_c --> ac_c + orn_c
# ACONTm : cit_m <=> icit_m
# ACP1_FMN : fmn_c + h2o_c --> pi_c + ribflv_c
# ACS2 : atp_c + coa_c + ppa_c --> amp_c + ppcoa_c + ppi_c
# ACSRTNMT : Nacsertn_c + amet_c --> ahcys_c + h_c + melatn_c
# ACt2r : ac_e + h_e <=> ac_c + h_c
# ADEt : ade_e <=> ade_c
# ADK3 : amp_c + gtp_c <=> adp_c + gdp_c
# ADK3m : amp_m + gtp_m <=> adp_m + gdp_m
# ADKd : damp_c + datp_c <=> 2.0 dadp_c
# ADMDC : amet_c + h_c --> ametam_c + co2_c
# ADNt4 : adn_e + na1_e --> adn_c + na1_c
# ADNtl : adn_l <=> adn_c
# ADNtm : adn_c <=> adn_m
# ADPMAN : adpman_c + h2o_c --> amp_c + 2.0 h_c + man1p_c
# ADPRIBt : adprib_e --> adprib_c
# ADRNCOAtx : adrncoa_c <=> adrncoa_x
# ADRNCRNt : adrncrn_c <=> adrncrn_m
# ADSL2r : 25aics_c --> aicar_c + fum_c
# AG13T16g : ksii_core4_pre2_g + uacgam_g --> h_g + ksii_core4_pre3_g + udp_g
# AG13T18g : ksii_core4_pre7_g + uacgam_g --> h_g + ksii_core4_pre8_g + udp_g
# AG13T2g : ksii_core2_pre4_g + uacgam_g --> h_g + ksii_core2_pre5_g + udp_g
# AGMTm : agm_m + h2o_m --> ptrc_m + urea_m
# AGTim : ala__L_m + glx_m --> gly_m + pyr_m
# AHANDROSTANGLCte : ahandrostanglc_c + atp_c + h2o_c --> adp_c + ahandrostanglc_e + h_c + pi_c
# AHEXASE2ly : 3.0 h2o_l + n2m2nmn_l --> 3.0 acgam_l + m2mn_l
# AIRCr : air_c + co2_c <=> 5aizc_c + h_c
# AKGMALtm : akg_m + mal__L_c <=> akg_c + mal__L_m
# AKGt4_3 : akg_e + 3.0 na1_e <=> akg_c + 3.0 na1_c
# AKR1C41 : h_c + nadh_c + xol7ah_c --> nad_c + xol7ah2_c
# AKR1D : h_c + nadph_c + xol7aone_c --> nadp_c + xol7ah_c
# ALAGLYexR : ala__L_e + gly_c <=> ala__L_c + gly_e
# ALASERNaEx : ala__L_e + na1_e + ser__L_c --> ala__L_c + na1_c + ser__L_e
# ALASm : gly_m + h_m + succoa_m --> 5aop_m + co2_m + coa_m
# ALATHRNaEx : ala__L_e + na1_e + thr__L_c --> ala__L_c + na1_c + thr__L_e
# ALCD21_D : 12ppd__R_c + nad_c --> h_c + lald__D_c + nadh_c
# ALCD22_D : lald__D_c + nad_c --> h_c + mthgxl_c + nadh_c
# ALCD2y : etoh_c + nadp_c --> acald_c + h_c + nadph_c
# ALDD20xm : h2o_m + id3acald_m + nad_m --> 2.0 h_m + ind3ac_m + nadh_m
# ALDD2xm : acald_m + h2o_m + nad_m --> ac_m + 2.0 h_m + nadh_m
# ALDD2y : acald_c + h2o_c + nadp_c --> ac_c + 2.0 h_c + nadph_c
# ALDSTRNte : aldstrn_c <=> aldstrn_e
# ALDSTRNtm : aldstrn_c <=> aldstrn_m
# ALOX15 : arachd_c + o2_c --> 15HPET_c
# ALR2 : h_c + mthgxl_c + nadph_c --> acetol_c + nadp_c
# ALR3 : acetol_c + h_c + nadph_c --> 12ppd__S_c + nadp_c
# AMACR2p : dhcholestancoa_x + 0.5 o2_x --> dhcholoylcoa_x + h2o_x
# AMACRp : cholcoar_x --> cholcoas_x
# AMETr : amet_c <=> amet_r
# AMETt2m : ahcys_m + amet_c <=> ahcys_c + amet_m
# AMPDA : amp_c + h2o_c + h_c --> imp_c + nh4_c
# AMY2e : glygn2_e + 8.0 h2o_e --> 8.0 glc__D_e + glygn4_e
# ANDRSTRNGLCte : andrstrnglc_c + atp_c + h2o_c --> adp_c + andrstrnglc_e + h_c + pi_c
# ANDRSTRNGLCtr : andrstrnglc_c <=> andrstrnglc_r
# ANDRSTRNtr : andrstrn_r <=> andrstrn_c
# ANTIPYRENEte : antipyrene_e <=> antipyrene_c
# APOCFm : apoC_m + lys__L_m --> apoC_Lys_m + h2o_m + h_m
# APOC_LYS_BTNP : apoC_Lys_btn_c + h2o_c --> apoC_c + biocyt_c
# APRTO2 : aprut_c + h2o_c + o2_c --> h2o2_c + n4abutn_c + nh4_c
# ARAB_Lt : arab__L_e <=> arab__L_c
# ARABR : arab__L_c + h_c + nadph_c --> abt_c + nadp_c
# ARACHDCOAtx : arachdcoa_c <=> arachdcoa_x
# ARACHDt2 : arachd_e <=> arachd_c
# ARACHt : arach_e <=> arach_c
# ARGDCm : arg__L_m + h_m --> agm_m + co2_m
# ARGLYSex : arg__L_e + lys__L_c --> arg__L_c + lys__L_e
# ARGSS : asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + h_c + ppi_c
# ARGt4 : arg__L_e + na1_e --> arg__L_c + na1_c
# ARTCOAL3_cho : Rtotal3coa_c + h2o_c --> Rtotal3_c + coa_c + h_c
# R_group_phosphotase_2 : Rtotal2_c + atp_c + coa_c --> Rtotal2coa_c + amp_c + ppi_c
# R_group_phosphotase_3 : Rtotal3_c + atp_c + coa_c --> Rtotal3coa_c + amp_c + ppi_c
# ASCBOX_1 : ascb__L_c + 3.0 h_c + 2.0 o2s_c --> dhdascb_c + 2.0 h2o2_c
# ASCBt : ascb__L_e <=> ascb__L_c
# ASNCYSNaEx : asn__L_e + cys__L_c + na1_e --> asn__L_c + cys__L_e + na1_c
# ASNGLNNaEx : asn__L_e + gln__L_c + na1_e --> asn__L_c + gln__L_e + na1_c
# ASNNm : asn__L_m + h2o_m --> asp__L_m + nh4_m
# ASNS1 : asp__L_c + atp_c + gln__L_c + h2o_c --> amp_c + asn__L_c + glu__L_c + h_c + ppi_c
# ASNt4 : asn__L_e + na1_e --> asn__L_c + na1_c
# ASPDxt : asp__D_x <=> asp__D_c
# ASPGLUm : asp__L_m + glu__L_c + h_c --> asp__L_c + glu__L_m + h_m
# ASPNATm : accoa_m + asp__L_m --> Nacasp_m + coa_m + h_m
# ASPt6 : asp__L_e + h_e + k_c + 3.0 na1_e --> asp__L_c + h_c + k_e + 3.0 na1_c
# ASPTAm : akg_m + asp__L_m <=> glu__L_m + oaa_m
# ATP1ter : adp_r + atp_c <=> adp_c + atp_r
# BILGLCURte : atp_c + bilglcur_c + h2o_c --> adp_c + bilglcur_e + h_c + pi_c
# BILIRED : biliverd_c + h_c + nadph_c --> bilirub_c + nadp_c
# EX_6htststerone_e : 6htststerone_e <=>
# ATPasel_1 : atp_c + h2o_c --> adp_c + h_l + pi_c
# ATPtn : atp_c <=> atp_n
# ATPtx : atp_c <=> atp_x
# AVITE2t : avite2_e --> avite2_c
# B3GALT3g : thcrm_hs_g + udpacgal_g --> gbside_hs_g + h_g + udp_g
# B3GALT42g : gm2_hs_g + udpgal_g --> gm1_hs_g + h_g + udp_g
# B3GALTg : acglcgalgluside_hs_g + udpgal_g --> galacglcgalgluside_hs_g + h_g + udp_g
# B3GNT11g : gal14acglcgalgluside_hs_g + uacgam_g --> acglcgal14acglcgalgluside_hs_g + h_g + udp_g
# B3GNT310g : acglcgalgluside_hs_g + udpgal_g --> gal14acglcgalgluside_hs_g + h_g + udp_g
# B3GNT315g : acglc13galacglcgal14acglcgalgluside_hs_g + udpgal_g --> galacglc13galacglcgal14acglcgalgluside_hs_g + h_g + udp_g
# B3GNT31g : thcrm_hs_g + udpgal_g --> galthcrm_hs_g + h_g + udp_g
# B3GNT34g : galgbside_hs_g + uacgam_g --> acglcgalgbside_hs_g + h_g + udp_g
# B3GNT37g : gm2a_hs_g + udpgal_g --> gm1a_hs_g + h_g + udp_g
# B3GNT39g : gluside_hs_g + udpgal_g --> galgluside_hs_g + h_g + udp_g
# B3GNT51g : galgluside_hs_g + uacgam_g --> acglcgalgluside_hs_g + h_g + udp_g
# BAAT1x : cholcoa_x + gly_x --> coa_x + gchola_x
# BAAT3x : dgcholcoa_x + gly_x --> coa_x + dgchol_x
# BACCL : atp_c + btn_c + h_c --> btamp_c + ppi_c
# BALAVECSEC_1 : ala_B_c + atp_c + h2o_c --> adp_c + ala_B_e + h_c + pi_c
# BDHm : bhb_m + nad_m <=> acac_m + h_m + nadh_m
# BETALDHxm : betald_m + h2o_m + nad_m --> glyb_m + 2.0 h_m + nadh_m
# BHBtm : bhb_c + h_c <=> bhb_m + h_m
# BHMT : glyb_c + hcys__L_c --> dmgly_c + met__L_c
# BILDGLCURt : bildglcur_e + hco3_c <=> bildglcur_c + hco3_e
# BTNDm : biocyt_m + h2o_m --> btn_m + lys__L_m
# BTNPL : apoC_Lys_c + btamp_c --> amp_c + apoC_Lys_btn_c + h_c
# BTNt2m : btn_c + h_c <=> btn_m + h_m
# BTNt3i_1 : atp_c + btn_e + h2o_c + na1_e --> adp_c + btn_c + h_c + na1_c + pi_c
# BVITEt : bvite_e --> bvite_c
# BZtr : bz_c <=> bz_r
# C160CPT1 : crn_c + pmtcoa_c <=> coa_c + pmtcrn_c
# C160CPT2 : coa_m + pmtcrn_m <=> crn_m + pmtcoa_m
# C160CRNt : pmtcrn_c <=> pmtcrn_m
# C161CPT1 : crn_c + hdcoa_c <=> coa_c + hdcecrn_c
# C161CPT12 : crn_c + hdd2coa_c <=> coa_c + hdd2crn_c
# C161CPT2 : coa_m + hdcecrn_m <=> crn_m + hdcoa_m
# C161CRN2t : hdd2crn_c <=> hdd2crn_m
# C161CRNt : hdcecrn_c <=> hdcecrn_m
# C180CPT1 : crn_c + stcoa_c <=> coa_c + stcrn_c
# C181CPT1 : crn_c + odecoa_c <=> coa_c + odecrn_c
# C181CRNt : odecrn_c <=> odecrn_m
# C204CPT1 : arachdcoa_c + crn_c <=> arachdcrn_c + coa_c
# C204CPT2 : arachdcrn_m + coa_m <=> arachdcoa_m + crn_m
# C226COAtx : c226coa_c <=> c226coa_x
# C226CPT1 : c226coa_c + crn_c <=> c226crn_c + coa_c
# C226CPT2 : c226crn_m + coa_m <=> c226coa_m + crn_m
# C226CRNt : c226crn_c <=> c226crn_m
# C3STDH1r : 4mzym_int1_r + nad_r --> 4mzym_int2_r + co2_r + h_r + nadh_r
# C4STMO1r : 44mzym_r + 3.0 h_r + 3.0 nadph_r + 3.0 o2_r --> 4mzym_int1_r + 4.0 h2o_r + 3.0 nadp_r
# C4STMO2Pr : 4mzym_int2_r + nadp_r + o2_r --> co2_r + h_r + nadph_r + zym_int2_r
# CAATPS_1 : atp_c + ca2_c + h2o_c --> adp_c + ca2_e + h_e + pi_c
# CAROtr : caro_e <=> caro_c
# CAt7r : ca2_c + 3.0 na1_e <=> ca2_e + 3.0 na1_c
# CATm : 2.0 h2o2_m --> 2.0 h2o_m + o2_m
# CATp : 2.0 h2o2_x --> 2.0 h2o_x + o2_x
# CBL2tm : cbl2_c --> cbl2_m
# CBPPer : cbp_r + glc__D_r + h_r --> co2_r + g6p_r + nh4_r
# CBR2 : h_c + nadph_c + prostge2_c --> nadp_c + prostgf2_c
# CDIPTr : cdpdag_hs_c + inost_c <=> cmp_c + h_c + pail_hs_c
# CDPDAGtm : cdpdag_hs_c <=> cdpdag_hs_m
# CDS : ctp_c + h_c + pa_hs_c --> cdpdag_hs_c + ppi_c
# CERT1gt : crm_hs_c <=> crm_hs_g
# CERT1rt : crm_hs_c <=> crm_hs_r
# CERT2rt : gluside_hs_c <=> gluside_hs_r
# CH25H : chsterol_r + h_r + nadph_r + o2_r --> h2o_r + nadp_r + xol25oh_r
# CHATn : accoa_n + chol_n <=> ach_n + coa_n
# CHLP : cholp_c + h2o_c --> chol_c + pi_c
# CHOLD2m : chol_m + fad_m --> betald_m + fadh2_m
# CHOLK : atp_c + chol_c --> adp_c + cholp_c + h_c
# CHOLPtl : cholp_c <=> cholp_l
# CHOLtn : chol_c <=> chol_n
# CHOLtr : chol_r <=> chol_c
# CHSTEROLt3 : chsterol_c <=> chsterol_m
# CITRtm : citr__L_m <=> citr__L_c
# CITtam : cit_c + mal__L_m <=> cit_m + mal__L_c
# CK_cho : atp_m + creat_m --> adp_m + h_m + pcreat_m
# CLHCO3tex2 : 2.0 cl_e + hco3_c --> 2.0 cl_c + hco3_e
# CLOXAtex2 : 2.0 cl_e + oxa_c --> 2.0 cl_c + oxa_e
# CLPNDCOAtx : clpndcoa_c <=> clpndcoa_x
# CLPNDCPT1 : clpndcoa_c + crn_c <=> clpndcrn_c + coa_c
# CLPNDt : clpnd_e <=> clpnd_c
# CMPACNAtn : cmpacna_n --> cmpacna_c
# ACNMCT : acnam_c + ctp_c --> cmpacna_c + ppi_c
# CO2tg : co2_c <=> co2_g
# CO2tm : co2_c <=> co2_m
# COAtim : coa_c <=> coa_m
# COKECBESr : coke_r + h2o_r --> bz_r + egme_r + h_r
# COQ3m : 2dpmhobq_m + amet_m --> ahcys_m + h_m + q10_m
# COQ6m : 2dp6mep_m + o2_m --> 2dp6mobq_m + h2o_m
# COQ7m : 2dp6mobq_me_m + h_m + nadph_m + o2_m --> 2dpmhobq_m + h2o_m + nadp_m
# CORE3GTg : Tn_antigen_g + uacgam_g --> core3_g + h_g + udp_g
# CORE6GTg : Tn_antigen_g + uacgam_g --> core6_g + h_g + udp_g
# CORE7GTg : Tn_antigen_g + udpacgal_g --> core7_g + h_g + udp_g
# CREATt4_2_r : creat_e + 2.0 na1_e <=> creat_c + 2.0 na1_c
# CREATtmdiffir : creat_c --> creat_m
# CRMPte : crmp_hs_c <=> crmp_hs_e
# CRNCAR3tp : crn_c + pcrn_x --> crn_x + pcrn_c
# CRNCARtp : acrn_x + crn_c --> acrn_c + crn_x
# CRNt : crn_e <=> crn_c
# CRNtHa : crn_c + h_e --> crn_e + h_c
# CRNtuNa : crn_e + na1_e --> crn_c + na1_c
# CRTNsyn_cho : pcreat_c --> crtn_c + pi_c
# CRTSLt : crtsl_e <=> crtsl_c
# CRTSLtm : crtsl_c <=> crtsl_m
# CRTSLtr : crtsl_c <=> crtsl_r
# CRVNCtr : crvnc_e <=> crvnc_c
# CSAPASEly : cspg_a_l + h2o_l --> Ser_Gly_Ala_X_Gly_l + cs_a_l
# CSCPASEly : cspg_c_l + h2o_l --> Ser_Gly_Ala_X_Gly_l + cs_c_l
# CSEPASEly : cspg_e_l + h2o_l --> Ser_Gly_Ala_X_Gly_l + cs_e_l
# CSNAT2m : coa_m + pcrn_m <=> crn_m + ppcoa_m
# CSNAT2x : crn_x + dmnoncoa_x <=> coa_x + dmnoncrn_x
# CSNAT3x : crn_x + ppcoa_x <=> coa_x + pcrn_x
# CSNATm : acrn_m + coa_m <=> accoa_m + crn_m
# CSNATp : accoa_x + crn_x <=> acrn_x + coa_x
# CSNATr : accoa_c + crn_c <=> acrn_c + coa_c
# CSPG_Atly : cspg_a_e --> cspg_a_l
# CSPG_Ct : cspg_c_g --> cspg_c_e
# CSPG_Ctly : cspg_c_e --> cspg_c_l
# CSPG_Dt : cspg_d_g --> cspg_d_e
# CSPG_Dtly : cspg_d_e --> cspg_d_l
# CTPtn : ctp_c <=> ctp_n
# CYANt : cyan_e <=> cyan_c
# CYANtm : cyan_c <=> cyan_m
# CYSALANaEx : ala__L_c + cys__L_e + na1_e --> ala__L_e + cys__L_c + na1_c
# CYSASNNaEx : asn__L_c + cys__L_e + na1_e --> asn__L_e + cys__L_c + na1_c
# CYSGLYex : cys__L_c + gly_e <=> cys__L_e + gly_c
# CYSO : cys__L_c + o2_c --> 3sala_c + 2.0 h_c
# CYSSERNaEx : cys__L_e + na1_e + ser__L_c --> cys__L_c + na1_c + ser__L_e
# CYStec : cys__L_e <=> cys__L_c
# CYSTGLUex : cysi__L_e + glu__L_c --> cysi__L_c + glu__L_e
# CYTD : cytd_c + h2o_c + h_c --> nh4_c + uri_c
# CYTDn : cytd_n + h2o_n + h_n --> nh4_n + uri_n
# CYTDt : cytd_e <=> cytd_c
# CYTDtl : cytd_l <=> cytd_c
# CYTK12 : dcmp_c + dctp_c <=> 2.0 dcdp_c
# CYTK12n : dcmp_n + dctp_n <=> 2.0 dcdp_n
# CYTK13n : datp_n + dcmp_n <=> dadp_n + dcdp_n
# CYTK14 : dcmp_c + utp_c <=> dcdp_c + udp_c
# CYTK1m : atp_m + cmp_m <=> adp_m + cdp_m
# CYTK2n : atp_n + dcmp_n <=> adp_n + dcdp_n
# CYTK3 : cmp_c + gtp_c <=> cdp_c + gdp_c
# CYTK4 : dcmp_c + gtp_c <=> dcdp_c + gdp_c
# CYTK5n : cmp_n + gtp_n <=> cdp_n + gdp_n
# CPK1 : cmp_c + ctp_c <=> 2.0 cdp_c
# CYTK6n : cmp_n + ctp_n <=> 2.0 cdp_n
# CYTK7 : cmp_c + utp_c <=> cdp_c + udp_c
# CYTK7n : cmp_n + utp_n <=> cdp_n + udp_n
# CYTK8 : cmp_c + datp_c <=> cdp_c + dadp_c
# CYTK8n : cmp_n + datp_n <=> cdp_n + dadp_n
# DADNK : atp_c + dad_2_c --> adp_c + damp_c + h_c
# DAG_HSter : dag_hs_r --> dag_hs_c
# DAGK_hs : atp_c + dag_hs_c --> adp_c + h_c + pa_hs_c
# DARGOp : arg__D_x + h2o_x + o2_x --> 5g2oxpt_x + h2o2_x + nh4_x
# DASCBH : dhdascb_c + h2o_c --> 23doguln_c + h_c
# DASPO1p : asp__D_x + h2o_x + o2_x --> h2o2_x + nh4_x + oaa_x
# DATPtn : datp_c <=> datp_n
# DCK1m : atp_m + dcyt_m <=> adp_m + dcmp_m + h_m
# DCK1n : atp_n + dcyt_n <=> adp_n + dcmp_n + h_n
# DLNLCGCPT2 : coa_m + dlnlcgcrn_m <=> crn_m + dlnlcgcoa_m
# DCSPTN1CPT1 : crn_c + dcsptn1coa_c <=> coa_c + dcsptn1crn_c
# DCSPTN1CRNt : dcsptn1crn_c <=> dcsptn1crn_m
# DCSPTN1t : dcsptn1_e <=> dcsptn1_c
# DCTPtn : dctp_c <=> dctp_n
# DCYTD : dcyt_c + h2o_c + h_c --> duri_c + nh4_c
# DCYTDn : dcyt_n + h2o_n + h_n --> duri_n + nh4_n
# DCYTt : dcyt_e <=> dcyt_c
# DECDPtm : decdp_c <=> decdp_m
# DEDOLP2_L : 0.1 dedolp__L_c + h2o_c --> 0.1 dedol__L_c + pi_c
# DESAT18_10 : h_c + lnlncacoa_c + nadh_c + o2_c --> 2.0 h2o_c + nad_c + strdnccoa_c
# DESAT18_6 : h_c + nadh_c + o2_c + odecoa_c --> 2.0 h2o_c + lneldccoa_c + nad_c
# DESAT18_12 : h_c + nadh_c + o2_c + octd11ecoa_c --> 2.0 h2o_c + lneldccoa_c + nad_c
# DESAT22_2p : clpndcoa_x + h_x + nadh_x + o2_x --> c226coa_x + 2.0 h2o_x + nad_x
# DESAT24_1 : h_c + nadh_c + o2_c + tetpent3coa_c --> 2.0 h2o_c + nad_c + tethex3coa_c
# DGCHOLte : dgchol_e <=> dgchol_c
# DGSNt : dgsn_e <=> dgsn_c
# DGSNtm : dgsn_c <=> dgsn_m
# DHCRD2 : dhcrm_hs_c + fad_c --> crm_hs_c + fadh2_c
# DHDPBMTm : 3dpdhb_m + amet_m --> 3dpdhb_me_m + ahcys_m + h_m
# DHEASt : dheas_e + hco3_c <=> dheas_c + hco3_e
# DHEASULT : dhea_c + paps_c --> dheas_c + h_c + pap_c
# DHEAtr : dhea_r <=> dhea_c
# DHFtl : dhf_c <=> dhf_l
# DHFtm : dhf_c <=> dhf_m
# DHORD9 : dhor__S_c + q10_m --> orot_c + q10h2_m
# DHPM1 : 56dura_c + h2o_c --> cala_c + h_c
# DIGALSGALSIDEtg : digalsgalside_hs_c <=> digalsgalside_hs_g
# DIGALSIDEtl : digalside_hs_c <=> digalside_hs_l
# DITPtn : ditp_c <=> ditp_n
# D_LACt2 : h_e + lac__D_e <=> h_c + lac__D_c
# DLNLCGCPT1 : crn_c + dlnlcgcoa_c <=> coa_c + dlnlcgcrn_c
# DM_Asn_X_Ser_Thr_l : Asn_X_Ser_Thr_l -->
# DM_core5_g : core5_g -->
# DM_dem2emgacpail_prot_hs_r : dem2emgacpail_prot_hs_r -->
# DM_dgpi_prot_hs_r : dgpi_prot_hs_r -->
# DM_dsT_antigen_g : dsT_antigen_g -->
# DM_kdn_c : kdn_c -->
# DM_melanin_c : melanin_c -->
# DM_n5m2masn_g : n5m2masn_g -->
# DM_oretn_n : oretn_n -->
# DM_Ser_Thr_l : Ser_Thr_l -->
# DM_Ser_Gly_Ala_X_Gly_l : Ser_Gly_Ala_X_Gly_l -->
# DM_sprm_c : sprm_c -->
# DMANTIPYRINEte : dmantipyrine_e <=> dmantipyrine_c
# DMATTx : dmpp_x + ipdp_x --> grdp_x + ppi_x
# DMGDHm : dmgly_m + fad_m + h2o_m --> fadh2_m + fald_m + sarcs_m
# DMGtm : dmgly_c <=> dmgly_m
# DMHPTCRNCPT2 : coa_m + dmhptcrn_m <=> crn_m + dmhptcoa_m
# DMHPTCRNte : dmhptcrn_c <=> dmhptcrn_e
# C110CPT2m : coa_m + dmnoncrn_m <=> crn_m + dmnoncoa_m
# DMNONCRNt : dmnoncrn_c <=> dmnoncrn_m
# DNADtn : dnad_c <=> dnad_n
# DNDPt10m : dadp_c + dcdp_m --> dadp_m + dcdp_c
# DNDPt11m : dadp_c + dgdp_m --> dadp_m + dgdp_c
# DNDPt13m : atp_m + dadp_c --> atp_c + dadp_m
# DNDPt14m : dtdp_m + dudp_c --> dtdp_c + dudp_m
# DNDPt15m : dgdp_m + dudp_c --> dgdp_c + dudp_m
# DNDPt16m : dadp_m + dudp_c --> dadp_c + dudp_m
# DNDPt17m : dcdp_m + dudp_c --> dcdp_c + dudp_m
# DNDPt18m : adp_m + dudp_c --> adp_c + dudp_m
# DNDPt1m : adp_m + datp_c --> adp_c + datp_m
# DNDPt20m : atp_m + dtdp_c --> atp_c + dtdp_m
# DNDPt21m : adp_m + dtdp_c --> adp_c + dtdp_m
# DNDPt25m : dcdp_m + dtdp_c --> dcdp_c + dtdp_m
# DNDPt28m : dcdp_c + dgdp_m --> dcdp_m + dgdp_c
# DNDPt32m : atp_m + dgdp_c --> atp_c + dgdp_m
# DNDPt37m : dtdp_m + dutp_c --> dtdp_c + dutp_m
# DNDPt38m : dudp_m + dutp_c --> dudp_c + dutp_m
# DNDPt39m : dgdp_m + dutp_c --> dgdp_c + dutp_m
# DNDPt40m : dadp_m + dutp_c --> dadp_c + dutp_m
# DNDPt42m : adp_m + dutp_c --> adp_c + dutp_m
# DNDPt43m : atp_m + dutp_c --> atp_c + dutp_m
# DNDPt45m : adp_m + dttp_c --> adp_c + dttp_m
# DNDPt49m : dadp_m + dttp_c --> dadp_c + dttp_m
# DNDPt50m : dcdp_m + dttp_c --> dcdp_c + dttp_m
# DNDPt52m : dctp_c + dudp_m --> dctp_m + dudp_c
# DNDPt55m : adp_m + dctp_c --> adp_c + dctp_m
# DNDPt56m : atp_m + dctp_c --> atp_c + dctp_m
# DNDPt57m : atp_m + dgtp_c --> atp_c + dgtp_m
# DNDPt59m : dadp_m + dgtp_c --> dadp_c + dgtp_m
# DNDPt5m : datp_c + dtdp_m --> datp_m + dtdp_c
# DNDPt60m : dgtp_c + dudp_m --> dgtp_m + dudp_c
# DNDPt61m : dgtp_c + dtdp_m --> dgtp_m + dtdp_c
# DNDPt62m : dgdp_m + dgtp_c --> dgdp_c + dgtp_m
# DNDPt63m : dcdp_m + dgtp_c --> dcdp_c + dgtp_m
# DNDPt6m : datp_c + dgdp_m --> datp_m + dgdp_c
# DOLGPP_Ler : 0.1 dolglcp__L_r + h2o_r --> 0.1 dolp__L_r + glc__D_r + h_r
# DOLICHOL_Lter : 0.1 dolichol__L_r <=> 0.1 dolichol__L_c
# DOLICHOL_Uter : 0.1 dolichol_U_r <=> 0.1 dolichol_U_c
# DOLK_U : ctp_c + 0.1 dolichol_U_c --> cdp_c + 0.1 dolp_U_c + h_c
# DOLPH_Uer : 0.1 dolp_U_r + h2o_r --> 0.1 dolichol_U_r + pi_r
# DOLPMT_U : 0.1 dolp_U_c + gdpmann_c --> 0.1 dolmanp_U_c + gdp_c
# DOLP_Lter : 0.1 dolp__L_r --> 0.1 dolp__L_c
# DOLP_Uter : 0.1 dolp_U_r --> 0.1 dolp_U_c
# DOPAt4_2_r : dopa_e + 2.0 na1_e <=> dopa_c + 2.0 na1_c
# DOPAtu : dopa_e <=> dopa_c
# DOPAVESSEC_1 : atp_c + dopa_c + h2o_c --> adp_c + dopa_e + h_c + pi_c
# DPCOAtl : dpcoa_l <=> dpcoa_c
# DPGase : 23dpg_c + h2o_c --> 3pg_c + pi_c
# DSAT : Rtotalcoa_c + sphgn_c --> coa_c + dhcrm_hs_c + h_c
# DTDPtn : dtdp_c <=> dtdp_n
# DUDPtn : dudp_c <=> dudp_n
# DURAD : 56dura_c + nadp_c <=> h_c + nadph_c + ura_c
# DURAD2 : 56dthm_c + nadp_c <=> h_c + nadph_c + thym_c
# DURIK1 : atp_c + duri_c --> adp_c + dump_c + h_c
# DURIt : duri_e <=> duri_c
# DUTPDPm : dutp_m + h2o_m --> dump_m + h_m + ppi_m
# EBASTINEOHtr : ebastineoh_r <=> ebastineoh_c
# EBASTINEte : ebastine_e <=> ebastine_c
# ECOAH12m : 2mp2coa_m + h2o_m <=> 3hibutcoa_m
# ECOAH9m : 2mb2coa_m + h2o_m <=> 3hmbcoa_m
# EICOSTETCPT1 : crn_c + eicostetcoa_c <=> coa_c + eicostetcrn_c
# ENGASE2ly : h2o_l + n2m2nm_l --> acgam_l + n2m2nmn_l
# ESTRADIOLGLCtr : estradiolglc_c <=> estradiolglc_r
# ESTRADIOLt : estradiol_e <=> estradiol_c
# ESTRIOLGLCte : atp_c + estriolglc_c + h2o_c --> adp_c + estriolglc_e + h_c + pi_c
# ESTRIOLtr : estriol_r <=> estriol_c
# ESTRONEGLCt : atp_c + estroneglc_c + h2o_c --> adp_c + estroneglc_e + h_c + pi_c
# ESTRONESt : estrones_e + hco3_c <=> estrones_c + hco3_e
# ESTRONESt2 : estrones_e + 2.0 na1_e --> estrones_c + 2.0 na1_c
# ESTRONEtr : estrone_r <=> estrone_c
# ETF : etfox_m + fadh2_m --> etfrd_m + fad_m
# ETFQO : etfrd_m + q10_m --> etfox_m + q10h2_m
# ETHAK : atp_c + etha_c --> adp_c + ethamp_c + h_c
# EX_10fthf5glu_e : 10fthf5glu_e <=>
# EX_10fthf6glu_e : 10fthf6glu_e <=>
# EX_10fthf7glu_e : 10fthf7glu_e <=>
# EX_11_cis_retfa_e : 11_cis_retfa_e <=>
# EX_13_cis_retnglc_e : 13_cis_retnglc_e <=>
# EX_24nph_e : 24nph_e <=>
# EX_25hvitd3_e : 25hvitd3_e <=>
# EX_2hb_e : 2hb_e <=>
# EX_2mcit_e : 2mcit_e <=>
# EX_34dhphe_e : 34dhphe_e <=>
# EX_35cgmp_e : 35cgmp_e <=>
# EX_4hphac_e : 4hphac_e <=>
# EX_4mptnl_e : 4mptnl_e <=>
# EX_7dhf_e : 7dhf_e <=>
# EX_7thf_e : 7thf_e <=>
# EX_9_cis_retfa_e : 9_cis_retfa_e <=>
# EX_acetone_e : acetone_e <=>
# EX_acgalfucgalacgalfuc12gal14acglcgalgluside_hs_e : acgalfucgalacgalfuc12gal14acglcgalgluside_hs_e <=>
# EX_acnacngal14acglcgalgluside_hs_e : acnacngal14acglcgalgluside_hs_e <=>
# EX_adp_e : adp_e <=>
# EX_ahandrostanglc_e : ahandrostanglc_e <=>
# EX_ala_B_e : ala_B_e <=>
# EX_ala__D_e : ala__D_e <=>
# EX_aldstrn_e : aldstrn_e <=>
# EX_andrstrn_e : andrstrn_e <=>
# EX_andrstrnglc_e : andrstrnglc_e <=>
# EX_antipyrene_e : antipyrene_e <=>
# EX_appnn_e : appnn_e <=>
# EX_arach_e : arach_e <=>
# EX_avite1_e : avite1_e <=>
# EX_avite2_e : avite2_e <=>
# EX_bhb_e : bhb_e <=>
# EX_bildglcur_e : bildglcur_e <=>
# EX_biocyt_e : biocyt_e <=>
# EX_bvite_e : bvite_e <=>
# EX_caro_e : caro_e <=>
# EX_carveol_e : carveol_e <=>
# EX_chol_e : chol_e <=>
# EX_cholate_e : cholate_e <=>
# EX_chtn_e : chtn_e <=>
# EX_clpnd_e : clpnd_e <=>
# EX_coumarin_e : coumarin_e <=>
# EX_creat_e : creat_e <=>
# EX_crmp_hs_e : crmp_hs_e <=>
# EX_crn_e : crn_e <=>
# EX_crtstrn_e : crtstrn_e <=>
# EX_crvnc_e : crvnc_e <=>
# EX_cspg_c_e : cspg_c_e <=>
# EX_cspg_e_e : cspg_e_e <=>
# EX_cyan_e : cyan_e <=>
# EX_dag_hs_e : dag_hs_e <=>
# EX_dcsptn1_e : dcsptn1_e <=>
# EX_dhdascb_e : dhdascb_e <=>
# EX_dheas_e : dheas_e <=>
# EX_dhf_e : dhf_e <=>
# EX_digalsgalside_hs_e : digalsgalside_hs_e <=>
# EX_dlnlcg_e : dlnlcg_e <=>
# EX_dmantipyrine_e : dmantipyrine_e <=>
# EX_dmhptcrn_e : dmhptcrn_e <=>
# EX_dopa_e : dopa_e <=>
# EX_eaflatoxin_e : eaflatoxin_e <=>
# EX_ebastine_e : ebastine_e <=>
# EX_eicostet_e : eicostet_e <=>
# EX_estradiolglc_e : estradiolglc_e <=>
# EX_fucacngalacglcgalgluside_hs_e : fucacngalacglcgalgluside_hs_e <=>
# EX_fucfuc12gal14acglcgalgluside_hs_e : fucfuc12gal14acglcgalgluside_hs_e <=>
# EX_fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_e : fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_e <=>
# EX_fucfucgalacglcgalgluside_hs_e : fucfucgalacglcgalgluside_hs_e <=>
# EX_fucgal14acglcgalgluside_hs_e : fucgal14acglcgalgluside_hs_e <=>
# EX_fucgalgbside_hs_e : fucgalgbside_hs_e <=>
# EX_fuc__L_e : fuc__L_e <=>
# EX_galacglcgalgbside_hs_e : galacglcgalgbside_hs_e <=>
# EX_galfucgalacglcgal14acglcgalgluside_hs_e : galfucgalacglcgal14acglcgalgluside_hs_e <=>
# EX_gd1c_hs_e : gd1c_hs_e <=>
# EX_gdp_e : gdp_e <=>
# EX_gluala_e : gluala_e <=>
# EX_glyc__S_e : glyc__S_e <=>
# EX_gp1calpha_hs_e : gp1calpha_hs_e <=>
# EX_gq1balpha_hs_e : gq1balpha_hs_e <=>
# EX_gsn_e : gsn_e <=>
# EX_gt1a_hs_e : gt1a_hs_e <=>
# EX_gthox_e : gthox_e <=>
# EX_ha_e : ha_e <=>
# EX_ha_pre1_e : ha_pre1_e <=>
# EX_hcoumarin_e : hcoumarin_e <=>
# EX_hdcea_e : hdcea_e <=>
# EX_hexc_e : hexc_e <=>
# EX_hom__L_e : hom__L_e <=>
# EX_hspg_e : hspg_e <=>
# EX_htaxol_e : htaxol_e <=>
# EX_i_e : i_e <=>
# EX_imp_e : imp_e <=>
# EX_ksi_e : ksi_e <=>
# EX_ksii_core4_e : ksii_core4_e <=>
# EX_lac__D_e : lac__D_e <=>
# EX_cysi__L_e : cysi__L_e <=>
# EX_leuktrB4_e : leuktrB4_e <=>
# EX_leuktrC4_e : leuktrC4_e <=>
# EX_leuktrD4_e : leuktrD4_e <=>
# EX_leuktrE4_e : leuktrE4_e <=>
# EX_limnen_e : limnen_e <=>
# EX_lipoate_e : lipoate_e <=>
# EX_lnlc_e : lnlc_e <=>
# EX_lnlnca_e : lnlnca_e <=>
# EX_lpchol_hs_e : lpchol_hs_e <=>
# EX_meoh_e : meoh_e <=>
# EX_mercplaccys_e : mercplaccys_e <=>
# EX_mthgxl_e : mthgxl_e <=>
# EX_nad_e : nad_e <=>
# EX_nadp_e : nadp_e <=>
# EX_nifedipine_e : nifedipine_e <=>
# EX_npthl_e : npthl_e <=>
# EX_nrpphr_e : nrpphr_e <=>
# EX_oagd3_hs_e : oagd3_hs_e <=>
# EX_oagt3_hs_e : oagt3_hs_e <=>
# EX_ocdca_e : ocdca_e <=>
# EX_ocdcea_e : ocdcea_e <=>
# EX_octa_e : octa_e <=>
# EX_onpthl_e : onpthl_e <=>
# EX_oxa_e : oxa_e <=>
# EX_paf_hs_e : paf_hs_e <=>
# EX_pchol_hs_e : pchol_hs_e <=>
# EX_perillyl_e : perillyl_e <=>
# EX_pheacgln_e : pheacgln_e <=>
# EX_phllqne_e : phllqne_e <=>
# EX_phyt_e : phyt_e <=>
# EX_prostgd2_e : prostgd2_e <=>
# EX_prostge2_e : prostge2_e <=>
# EX_prostgf2_e : prostgf2_e <=>
# EX_ps_hs_e : ps_hs_e <=>
# EX_retfa_e : retfa_e <=>
# EX_retinol_e : retinol_e <=>
# EX_Rtotal2_e : Rtotal2_e <=>
# EX_Rtotal3_e : Rtotal3_e <=>
# EX_s2l2n2m2masn_e : s2l2n2m2masn_e <=>
# EX_sarcs_e : sarcs_e <=>
# EX_spc_hs_e : spc_hs_e <=>
# EX_sph1p_e : sph1p_e <=>
# EX_strdnc_e : strdnc_e <=>
# EX_tag_hs_e : tag_hs_e <=>
# EX_taxol_e : taxol_e <=>
# EX_tchola_e : tchola_e <=>
# EX_tcynt_e : tcynt_e <=>
# EX_tdchola_e : tdchola_e <=>
# EX_tetpent3_e : tetpent3_e <=>
# EX_tetpent6_e : tetpent6_e <=>
# EX_thmmp_e : thmmp_e <=>
# EX_thym_e : thym_e <=>
# EX_triodthy_e : triodthy_e <=>
# EX_triodthysuf_e : triodthysuf_e <=>
# EX_tststeroneglc_e : tststeroneglc_e <=>
# EX_tststerones_e : tststerones_e <=>
# EX_ttdca_e : ttdca_e <=>
# EX_tymsf_e : tymsf_e <=>
# EX_Tyr_ggn_e : Tyr_ggn_e <=>
# EX_udp_e : udp_e <=>
# EX_vitd3_e : vitd3_e <=>
# EX_whddca_e : whddca_e <=>
# EX_whhdca_e : whhdca_e <=>
# EX_whttdca_e : whttdca_e <=>
# EX_xoltri25_e : xoltri25_e <=>
# EX_xoltri27_e : xoltri27_e <=>
# F1Atg : f1a_g <=> f1a_l
# FACOAL140 : atp_c + coa_c + ttdca_c --> amp_c + ppi_c + tdcoa_c
# FACOAL160 : atp_c + coa_c + hdca_c --> amp_c + pmtcoa_c + ppi_c
# FACOAL170 : atp_c + coa_c + hpdca_c --> amp_c + hpdcacoa_c + ppi_c
# FACOAL181 : atp_c + coa_c + ocdcea_c --> amp_c + odecoa_c + ppi_c
# FACOAL1821 : atp_c + coa_c + lnlc_c --> amp_c + lnlccoa_c + ppi_c
# FACOAL1822 : atp_c + coa_c + lneldc_c --> amp_c + lneldccoa_c + ppi_c
# FACOAL1831 : atp_c + coa_c + lnlncg_c --> amp_c + lnlncgcoa_c + ppi_c
# FACOAL184 : atp_c + coa_c + strdnc_c --> amp_c + ppi_c + strdnccoa_c
# FACOAL203 : atp_c + coa_c + dlnlcg_c --> amp_c + dlnlcgcoa_c + ppi_c
# FACOAL204 : arachd_c + atp_c + coa_c --> amp_c + arachdcoa_c + ppi_c
# FACOAL2042 : atp_c + coa_c + eicostet_c --> amp_c + eicostetcoa_c + ppi_c
# FACOAL205 : atp_c + coa_c + tmndnc_c --> amp_c + ppi_c + tmndnccoa_c
# FACOAL2251 : atp_c + coa_c + dcsptn1_c --> amp_c + dcsptn1coa_c + ppi_c
# FACOAL2252 : atp_c + clpnd_c + coa_c --> amp_c + clpndcoa_c + ppi_c
# FACOAL240_1 : atp_c + coa_c + lgnc_c --> amp_c + ppi_c + ttccoa_c
# FACOAL241 : atp_c + coa_c + nrvnc_c --> amp_c + nrvnccoa_c + ppi_c
# FACOAL245_1 : atp_c + coa_c + tetpent6_c --> amp_c + ppi_c + tetpent6coa_c
# FACOAL40im : atp_m + but_m + coa_m --> amp_m + btcoa_m + ppi_m
# FACOAL80 : atp_c + coa_c + octa_c --> amp_c + occoa_c + ppi_c
# FADH2tru : fadh2_c --> fadh2_r
# FADH2tx : fadh2_c <=> fadh2_x
# FADtru : fad_r --> fad_c
# FADtx : fad_c <=> fad_x
# FAEL184 : 5.0 h_c + malcoa_c + 4.0 nadph_c + o2_c + strdnccoa_c --> co2_c + coa_c + eicostetcoa_c + 3.0 h2o_c + 4.0 nadp_c
# FAEL204 : arachdcoa_c + 5.0 h_c + malcoa_c + 4.0 nadph_c + o2_c --> adrncoa_c + co2_c + coa_c + 3.0 h2o_c + 4.0 nadp_c
# FAEL205 : 5.0 h_c + malcoa_c + 4.0 nadph_c + o2_c + tmndnccoa_c --> clpndcoa_c + co2_c + coa_c + 3.0 h2o_c + 4.0 nadp_c
# FAH1 : ddca_c + h_c + nadph_c + o2_c --> h2o_c + nadp_c + whddca_c
# FAH2 : h_c + nadph_c + o2_c + ttdca_c --> h2o_c + nadp_c + whttdca_c
# FALDH : fald_c + gthrd_c + nad_c <=> Sfglutth_c + h_c + nadh_c
# FALDtly : fald_l <=> fald_c
# FALDtm : fald_m <=> fald_c
# FAOXC11 : coa_m + dmnoncoa_m + h2o_m + nad_m --> accoa_m + dmhptcoa_m + h_m + nadh_m
# FAOXC16080m : 4.0 coa_m + 4.0 fad_m + 4.0 h2o_m + 4.0 nad_m + pmtcoa_m --> 4.0 accoa_m + 4.0 fadh2_m + 4.0 h_m + 4.0 nadh_m + occoa_m
# FAOXC16080x : 4.0 coa_x + 4.0 h2o_x + 4.0 nad_x + 4.0 o2_x + pmtcoa_x --> 4.0 accoa_x + 4.0 h2o2_x + 4.0 h_x + 4.0 nadh_x + occoa_x
# FAOXC180x : coa_x + h2o_x + nad_x + o2_x + stcoa_x --> accoa_x + h2o2_x + h_x + nadh_x + pmtcoa_x
# FAOXC1811601m : 5.0 coa_m + 4.0 fad_m + 5.0 h2o_m + 5.0 nad_m + od2coa_m --> 5.0 accoa_m + 4.0 fadh2_m + 5.0 h_m + 5.0 nadh_m + occoa_m
# FAOXC1811603m : 5.0 coa_m + 4.0 fad_m + 5.0 h2o_m + 5.0 nad_m + odecoa_m --> 5.0 accoa_m + 4.0 fadh2_m + 5.0 h_m + 5.0 nadh_m + occoa_m
# FAOXC182806m : 5.0 coa_m + 3.0 fad_m + 5.0 h2o_m + lnlccoa_m + 5.0 nad_m --> 5.0 accoa_m + 3.0 fadh2_m + 5.0 h_m + 5.0 nadh_m + occoa_m
# FAOXC18280m : 5.0 coa_m + 3.0 fad_m + 5.0 h2o_m + lneldccoa_m + 5.0 nad_m --> 5.0 accoa_m + 3.0 fadh2_m + 5.0 h_m + 5.0 nadh_m + occoa_m
# FAOXC183806m : 5.0 coa_m + 5.0 h2o_m + lnlncgcoa_m + 5.0 nad_m + 2.0 o2_m --> 5.0 accoa_m + 2.0 h2o2_m + 5.0 h_m + 5.0 nadh_m + occoa_m
# FAOXC18480m : 5.0 coa_m + fad_m + 5.0 h2o_m + 5.0 nad_m + strdnccoa_m --> 5.0 accoa_m + fadh2_m + 5.0 h_m + 5.0 nadh_m + occoa_m
# FAOXC200180x : arachcoa_x + coa_x + h2o_x + nad_x + o2_x --> accoa_x + h2o2_x + h_x + nadh_x + stcoa_x
# FAOXC2031836m : coa_m + dlnlcgcoa_m + fad_m + h2o_m + nad_m --> accoa_m + fadh2_m + h_m + lnlncgcoa_m + nadh_m
# FAOXC204 : arachdcoa_m + 9.0 coa_m + 5.0 fad_m + 9.0 h2o_m + 9.0 nad_m --> 10.0 accoa_m + 5.0 fadh2_m + 9.0 h_m + 9.0 nadh_m
# FAOXC2051843m : coa_m + h2o_m + nad_m + tmndnccoa_m --> accoa_m + h_m + nadh_m + strdnccoa_m
# FAOXC2051843x : coa_x + h2o_x + nad_x + tmndnccoa_x --> accoa_x + h_x + nadh_x + strdnccoa_x
# FAOXC2251836m : 2.0 coa_m + dcsptn1coa_m + 2.0 h2o_m + 2.0 nad_m --> 2.0 accoa_m + 2.0 h_m + lnlncgcoa_m + 2.0 nadh_m
# FAOXC2252053m : coa_m + dcsptn1coa_m + h2o_m + nad_m + o2_m --> accoa_m + h2o2_m + h_m + nadh_m + tmndnccoa_m
# FAOXC2252053x : coa_x + dcsptn1coa_x + h2o_x + nad_x + o2_x --> accoa_x + h2o2_x + h_x + nadh_x + tmndnccoa_x
# GCHOLAte : gchola_e <=> gchola_c
# FAOXC226205m : c226coa_m + coa_m + h2o_m + nad_m --> accoa_m + h_m + nadh_m + tmndnccoa_m
# FAOXC2442246x : coa_x + h2o_x + nad_x + o2_x + tettet6coa_x --> accoa_x + adrncoa_x + h2o2_x + h_x + nadh_x
# FAOXC2452253x : coa_x + h2o_x + nad_x + o2_x + tetpent3coa_x --> accoa_x + clpndcoa_x + h2o2_x + h_x + nadh_x
# FAOXC2452256x : coa_x + h2o_x + nad_x + o2_x + tetpent6coa_x --> accoa_x + dcsptn1coa_x + h2o2_x + h_x + nadh_x
# FAOXC246226x : coa_x + h2o_x + nad_x + o2_x + tethex3coa_x --> accoa_x + c226coa_x + h2o2_x + h_x + nadh_x
# FAOXC260240x_1 : coa_x + h2o_x + hexccoa_x + nad_x + o2_x --> accoa_x + h2o2_x + h_x + nadh_x + ttccoa_x
# FAS160COA : 3.0 h_c + malcoa_c + 2.0 nadph_c + tdcoa_c --> co2_c + coa_c + h2o_c + 2.0 nadp_c + pmtcoa_c
# FATP1t : hdca_c + na1_c <=> hdca_e + na1_e
# FATP2t : na1_c + ocdcea_c <=> na1_e + ocdcea_e
# FATP3t : na1_c + ocdca_c <=> na1_e + ocdca_e
# FATP7t : crvnc_c + na1_c <=> crvnc_e + na1_e
# FATP8t : lgnc_c + na1_c <=> lgnc_e + na1_e
# FBA5 : tag1p__D_c <=> dhap_c + glyald_c
# FDH : for_c + nad_c --> co2_c + nadh_c
# FE2t : fe2_e --> fe2_c
# FE3R2e_1 : ascb__L_e + 2.0 fe3_e --> dhdascb_e + 2.0 fe2_e + h_e
# FK : atp_c + fuc__L_c --> adp_c + fuc1p__L_c + h_c
# FKYNH : Lfmkynr_c + h2o_c --> Lkynr_c + for_c + h_c
# FORMCOAtx : forcoa_x <=> forcoa_c
# FORtm : for_m <=> for_c
# FORtr : for_c <=> for_r
# FPGS2 : 5thf_c + atp_c + glu__L_c --> 6thf_c + adp_c + h_c + pi_c
# FPGS2m : 5thf_m + atp_m + glu__L_m --> 6thf_m + adp_m + h_m + pi_m
# FPGS3 : 6thf_c + atp_c + glu__L_c --> 7thf_c + adp_c + h_c + pi_c
# FPGS4_1 : atp_c + dhf_c + 4.0 glu__L_c --> 5dhf_c + adp_c + 3.0 h2o_c + h_c + pi_c
# FPGS4m_1 : atp_m + dhf_m + 4.0 glu__L_m --> 5dhf_m + adp_m + 3.0 h2o_m + h_m + pi_m
# FPGS5 : 5dhf_c + atp_c + glu__L_c --> 6dhf_c + adp_c + h_c + pi_c
# FPGS5m : 5dhf_m + atp_m + glu__L_m --> 6dhf_m + adp_m + h_m + pi_m
# FPGS6m : 6dhf_m + atp_m + glu__L_m --> 7dhf_m + adp_m + h_m + pi_m
# FPGS7m_1 : 10fthf_m + atp_m + 4.0 glu__L_m --> 10fthf5glu_m + adp_m + 3.0 h2o_m + h_m + pi_m
# FPGS8m : 10fthf5glu_m + atp_m + glu__L_m --> 10fthf6glu_m + adp_m + h_m + pi_m
# FPGS9 : 10fthf6glu_c + atp_c + glu__L_c --> 10fthf7glu_c + adp_c + h_c + pi_c
# FPGSm_1 : atp_m + 4.0 glu__L_m + thf_m --> 5thf_m + adp_m + 3.0 h2o_m + h_m + pi_m
# FRDPtc : frdp_x <=> frdp_c
# FRDPtr : frdp_x <=> frdp_r
# FRUt1r : fru_e <=> fru_c
# FTHFDH : 10fthf_c + h2o_c + nadp_c --> co2_c + h_c + nadph_c + thf_c
# FTHFLmi : atp_m + for_m + thf_m --> 10fthf_m + adp_m + pi_m
# FUC14GALACGLCGALGLUSIDEte : fuc14galacglcgalgluside_hs_e <=> fuc14galacglcgalgluside_hs_c
# FUC14GALACGLCGALGLUSIDEtg : fuc14galacglcgalgluside_hs_g <=> fuc14galacglcgalgluside_hs_c
# FUCACGALFUCGALACGLCGALGLUSIDEte : fucacgalfucgalacglcgalgluside_hs_e <=> fucacgalfucgalacglcgalgluside_hs_c
# FUCACNGAL14ACGLCGALGLUSIDEte : fucacngal14acglcgalgluside_hs_e <=> fucacngal14acglcgalgluside_hs_c
# FUCACNGAL14ACGLCGALGLUSIDEtg : fucacngal14acglcgalgluside_hs_g <=> fucacngal14acglcgalgluside_hs_c
# FUCACNGALACGLCGALGLUSIDEte : fucacngalacglcgalgluside_hs_e <=> fucacngalacglcgalgluside_hs_c
# FUCASE2ly : h2o_l + ksi_l --> fuc__L_l + ksi_deg1_l
# FUCASEe : h2o_e + s2l2fn2m2masn_e --> fuc__L_e + s2l2n2m2masn_e
# FUCFUC132GALACGLCGAL14ACGLCGALGLUSIDEte : fucfuc132galacglcgal14acglcgalgluside_hs_e <=> fucfuc132galacglcgal14acglcgalgluside_hs_c
# FUCFUC132GALACGLCGAL14ACGLCGALGLUSIDEtg : fucfuc132galacglcgal14acglcgalgluside_hs_g <=> fucfuc132galacglcgal14acglcgalgluside_hs_c
# FUCFUCFUCGALACGLC13GALACGLCGAL14ACGLCGALGLUSIDEte : fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_e <=> fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_c
# FUCFUCFUCGALACGLC13GALACGLCGAL14ACGLCGALGLUSIDEtg : fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_g <=> fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_c
# FUCFUCFUCGALACGLCGAL14ACGLCGALGLUSIDEte : fucfucfucgalacglcgal14acglcgalgluside_hs_e <=> fucfucfucgalacglcgal14acglcgalgluside_hs_c
# FUCFUCFUCGALACGLCGAL14ACGLCGALGLUSIDEtg : fucfucfucgalacglcgal14acglcgalgluside_hs_g <=> fucfucfucgalacglcgal14acglcgalgluside_hs_c
# FUCGALFUCGALACGLCGALGLUSIDEtg : fucgalfucgalacglcgalgluside_hs_g <=> fucgalfucgalacglcgalgluside_hs_c
# FUCGALGBSIDEte : fucgalgbside_hs_c <=> fucgalgbside_hs_e
# FUCGALGBSIDEtg : fucgalgbside_hs_c <=> fucgalgbside_hs_g
# FUCtly : fuc__L_l --> fuc__L_c
# FUMAC : 4fumacac_c + h2o_c --> acac_c + fum_c + h_c
# FUMSO4tm : fum_c + so4_m <=> fum_m + so4_c
# FUMtm : fum_c + pi_m <=> fum_m + pi_c
# FUT15g : galacgalfuc12gal14acglcgalgluside_hs_g + gdpfuc_g --> fucgalacgalfuc12gal14acglcgalgluside_hs_g + gdp_g + h_g
# FUT16g : galacglcgal14acglcgalgluside_hs_g + gdpfuc_g --> fucgalacglcgal14acglcgalgluside_hs_g + gdp_g + h_g
# FUT32g : acngalacglcgalgluside_hs_g + gdpfuc_g --> fucacngalacglcgalgluside_hs_g + gdp_g + h_g
# FUT911g : fucfucgalacglc13galacglcgal14acglcgalgluside_hs_g + gdpfuc_g --> fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_g + gdp_g + h_g
# FUT91g : gal14acglcgalgluside_hs_g + gdpfuc_g --> fucgal14acglcgalgluside_hs_g + gdp_g + h_g
# FUT94g : fucgalacglcgal14acglcgalgluside_hs_g + gdpfuc_g --> fucfucgalacglcgal14acglcgalgluside_hs_g + gdp_g + h_g
# FUT96g : galacglcgal14acglcgalgluside_hs_g + gdpfuc_g --> fuc132galacglcgal14acglcgalgluside_hs_g + gdp_g + h_g
# FUT97g : fuc132galacglcgal14acglcgalgluside_hs_g + gdpfuc_g --> fucfuc132galacglcgal14acglcgalgluside_hs_g + gdp_g + h_g
# FUT99g : galacglc13galacglcgal14acglcgalgluside_hs_g + gdpfuc_g --> fucgalacglc13galacglcgal14acglcgalgluside_hs_g + gdp_g + h_g
# G14T20g : ksii_core4_pre6_g + udpgal_g --> h_g + ksii_core4_pre7_g + udp_g
# G14T21g : ksii_core4_pre9_g + udpgal_g --> h_g + ksii_core4_pre10_g + udp_g
# G14T2g : ksii_core2_pre1_g + udpgal_g --> h_g + ksii_core2_pre2_g + udp_g
# G14T5g : ksii_core2_pre9_g + udpgal_g --> h_g + ksii_core2_pre10_g + udp_g
# G5SDym : glu5p_m + h_m + nadph_m --> glu5sa_m + nadp_m + pi_m
# G6PDH1er : g6p_r + nad_r <=> 6pgl_r + h_r + nadh_r
# G6PDH2er : g6p_r + nadp_r <=> 6pgl_r + h_r + nadph_r
# G6PPer : g6p_r + h2o_r --> glc__D_r + pi_r
# GABAVESSEC_1 : 4abut_c + atp_c + h2o_c --> 4abut_e + adp_c + h_c + pi_c
# GACMTRc : amet_c + gudac_c <=> ahcys_c + creat_c + h_c
# GACPAILter : gacpail_hs_c --> gacpail_hs_r
# GALACGLCGALGBSIDEte : galacglcgalgbside_hs_c <=> galacglcgalgbside_hs_e
# GALACGLCGALGBSIDEtg : galacglcgalgbside_hs_c <=> galacglcgalgbside_hs_g
# GALASE10ly : h2o_l + ksi_deg26_l --> gal_l + ksi_deg27_l
# GALASE12ly : h2o_l + ksi_deg32_l --> gal_l + ksi_deg33_l
# GALASE13ly : h2o_l + ksi_deg35_l --> gal_l + ksi_deg36_l
# GALASE15ly : h2o_l + ksi_deg40_l --> gal_l + ksi_deg41_l
# GALASE16ly : 2.0 h2o_l + ksii_core2_deg2_l --> 2.0 gal_l + ksii_core2_deg3_l
# GALASE17ly : h2o_l + ksii_core2_deg5_l --> gal_l + ksii_core2_deg6_l
# GALASE19ly : f1a_l + h2o_l --> core6_l + gal_l
# GALASE1ly : 2.0 h2o_l + l2n2m2mn_l --> 2.0 gal_l + n2m2mn_l
# GALASE20ly : 2.0 h2o_l + ksii_core4_deg2_l --> 2.0 gal_l + ksii_core4_deg3_l
# GALASE4ly : h2o_l + ksi_deg8_l --> gal_l + ksi_deg9_l
# GALASE7ly : h2o_l + ksi_deg17_l --> gal_l + ksi_deg18_l
# GALASE8ly : h2o_l + ksi_deg20_l --> gal_l + ksi_deg21_l
# GALASE9ly : h2o_l + ksi_deg23_l --> gal_l + ksi_deg24_l
# GALFUC12GAL14ACGLCGALGLUSIDEtg : galfuc12gal14acglcgalgluside_hs_g <=> galfuc12gal14acglcgalgluside_hs_c
# GALGALFUCFUCGALACGLCGALACGLCGAL14ACGLCGALGLUSIDEte : galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_e <=> galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_c
# GALGALFUCFUCGALACGLCGALACGLCGAL14ACGLCGALGLUSIDEtg : galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_g <=> galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_c
# GALGALGALTHCRMtg : galgalgalthcrm_hs_c <=> galgalgalthcrm_hs_g
# GALGT2 : gm3_hs_g + udpacgal_g --> gm2_hs_g + h_g + udp_g
# GALGT3 : gd3_hs_g + udpacgal_g --> gd2_hs_g + h_g + udp_g
# GALNACT1g : cs_hs_linkage_g + udpacgal_g --> cs_pre_g + h_g + udp_g
# GALNACT2g : cs_a_b_pre2_g + uacgam_g --> cs_a_b_pre3_g + h_g + udp_g
# GALNACT3g : cs_c_pre2_g + uacgam_g --> cs_c_pre3_g + h_g + udp_g
# GALNACT4g : cs_d_pre3_g + uacgam_g --> cs_d_pre4_g + h_g + udp_g
# GALNACT5g : cs_e_pre3_g + uacgam_g --> cs_e_pre4_g + h_g + udp_g
# GALSIDEtg : galside_hs_c <=> galside_hs_g
# GALSIDEtl : galside_hs_c <=> galside_hs_l
# GALt1r : gal_e <=> gal_c
# GALT2g : lxser_g + udpgal_g --> h_g + l2xser_g + udp_g
# GALtly : gal_l --> gal_c
# GAO1g : accoa_g + gd3_hs_g --> coa_g + oagd3_hs_g
# GARFT : 10fthf_c + gar_c <=> fgam_c + h_c + thf_c
# GASNASE2ly : h2o_l + n2m2nmasn_l --> Asn_X_Ser_Thr_l + n2m2nm_l
# GASNASEly : h2o_l + s2l2n2m2masn_l --> Asn_X_Ser_Thr_l + s2l2n2m2m_l
# GBA : gluside_hs_c + h2o_c --> crm_hs_c + glc__D_c
# GBGT1 : gbside_hs_g + udpacgal_g --> acgagbside_hs_g + h_g + udp_g
# GBSIDEte : gbside_hs_c <=> gbside_hs_e
# GBSIDEtl : gbside_hs_c <=> gbside_hs_l
# GCCam : gly_m + h_m + lpro_m <=> alpro_m + co2_m
# GCHOLAt2 : gchola_e + 2.0 na1_e --> gchola_c + 2.0 na1_c
# GD1B2te : gd1b2_hs_c <=> gd1b2_hs_e
# GD1Cte : gd1c_hs_c <=> gd1c_hs_e
# GDPFUCtg : gdpfuc_c + gmp_g <=> gdpfuc_g + gmp_c
# GFUCS : gdpddman_c + h_c + nadph_c --> gdpfuc_c + nadp_c
# GGH_10FTHF7GLUl : 10fthf7glu_l + h2o_l --> 10fthf6glu_l + glu__L_l
# GGH_5THFl : 5thf_l + 4.0 h2o_l --> 4.0 glu__L_l + thf_l
# GGH_6DHFl : 6dhf_l + h2o_l --> 5dhf_l + glu__L_l
# GGH_7THFe : 7thf_e + h2o_e --> 6thf_e + glu__L_e
# GGLUCT : gluala_e --> 5oxpro_c + ala__L_c
# GHMT2rm : ser__L_m + thf_m <=> gly_m + h2o_m + mlthf_m
# GLAl : digalside_hs_l + h2o_l --> gal_l + galside_hs_l
# GLB1 : galgluside_hs_l + h2o_l --> gal_l + gluside_hs_l
# GLCAASE4ly : cs_a_deg2_l + h2o_l --> cs_a_deg3_l + glcur_l
# GLCAASE6ly : cs_d_deg3_l + h2o_l --> cs_d_deg4_l + glcur_l
# GLCAASE7ly : cs_e_deg3_l + h2o_l --> cs_e_deg4_l + glcur_l
# GLCAASE8ly : h2o_l + ha_l --> glcur_l + ha_deg1_l
# GLCAASE9ly : 2.0 h2o_l + ha_pre1_l --> acgam_l + glcur_l
# GLCAT4g : cs_d_pre2_g + udpglcur_g --> cs_d_pre3_g + h_g + udp_g
# GLCAT5g : cs_e_pre2_g + udpglcur_g --> cs_e_pre3_g + h_g + udp_g
# GLCAT6g : hs_pre1_g + udpglcur_g --> h_g + hs_pre2_g + udp_g
# GLCAT7g : hs_pre3_g + udpglcur_g --> h_g + hs_pre4_g + udp_g
# GLCAT8g : hs_pre5_g + udpglcur_g --> h_g + hs_pre6_g + udp_g
# GLCNACASE5ly : h2o_l + hs_deg24_l --> acgam_l + hs_deg25_l
# GLCNACDASg : 4.0 h2o_g + hs_pre9_g + 4.0 paps_g --> 4.0 ac_g + 4.0 h_g + hs_pre10_g + 4.0 pap_g
# GLCNACT2g : hs_pre2_g + uacgam_g --> h_g + hs_pre3_g + udp_g
# GLCNACT5g : hs_pre8_g + uacgam_g --> h_g + hs_pre9_g + udp_g
# GLCter : glc__D_c <=> glc__D_r
# GLCtly : glc__D_l --> glc__D_c
# GLGNS1 : ggn_c + 3.0 udpg_c --> glygn1_c + 3.0 h_c + 3.0 udp_c
# GLNALANaEx : ala__L_c + gln__L_e + na1_e --> ala__L_e + gln__L_c + na1_c
# GLNASNNaEx : asn__L_c + gln__L_e + na1_e --> asn__L_e + gln__L_c + na1_c
# GLNCYSNaEx : cys__L_c + gln__L_e + na1_e --> cys__L_e + gln__L_c + na1_c
# GLNtm : gln__L_c --> gln__L_m
# GLPASE1 : glygn2_c + 3.0 pi_c --> dxtrn_c + 3.0 g1p_c
# GLPASE2 : glygn3_c + 7.0 h2o_c --> Tyr_ggn_c + 7.0 glc__D_c
# GLRASE : gullac_c + nadp_c <=> glac_c + h_c + nadph_c
# GLUt6 : glu__L_e + h_e + k_c + 3.0 na1_e --> glu__L_c + h_c + k_e + 3.0 na1_c
# GLXO2p : glx_x + h2o_x + o2_x --> h2o2_x + h_x + oxa_x
# GLXtp : glx_c <=> glx_x
# GLYAMDTRc : arg__L_c + gly_c <=> gudac_c + orn_c
# GLYBt4_2_r : glyb_e + 2.0 na1_e <=> glyb_c + 2.0 na1_c
# GLYCK2 : atp_c + glyc__R_c --> 2pg_c + adp_c + h_c
# GLYCLTDym : glx_m + h_m + nadph_m --> glyclt_m + nadp_m
# GLYCLTtp : glyclt_c --> glyclt_x
# GLYC_St : glyc__S_c --> glyc__S_e
# GLYOp : gly_x + h2o_x + o2_x --> glx_x + h2o2_x + nh4_x
# GLYt4 : gly_e + na1_e --> gly_c + na1_c
# GLYt7_211_r : cl_e + gly_e + 2.0 na1_e <=> cl_c + gly_c + 2.0 na1_c
# GLYtm : gly_c <=> gly_m
# GLYVESSEC_1 : atp_c + gly_c + h2o_c --> adp_c + gly_e + h_c + pi_c
# GMPtg : gmp_c <=> gmp_g
# GMPtn : gmp_c <=> gmp_n
# GNDer : 6pgc_r + nadp_r --> co2_r + nadph_r + ru5p__D_r
# GNMT : amet_c + gly_c --> ahcys_c + h_c + sarcs_c
# GP1CALPHAtg : gp1calpha_hs_c <=> gp1calpha_hs_g
# GPAM_hs_1 : Rtotalcoa_c + glyc3p_c --> alpa_hs_c + coa_c + 2.0 h_c
# GPIDA2er : em2emgacpail_prot_hs_r + h2o_r --> dem2emgacpail_prot_hs_r + h_r + hdca_r
# GPIDAer : gpi_prot_hs_r + h2o_r --> dgpi_prot_hs_r + h_r + hdca_r
# GQ1BALPHAte : gq1balpha_hs_c <=> gq1balpha_hs_e
# GQ1Btg : gq1b_hs_c <=> gq1b_hs_g
# GT1Ate : gt1a_hs_c <=> gt1a_hs_e
# GT1Atg : gt1a_hs_c <=> gt1a_hs_g
# DHAOX_c : dhdascb_c + 2.0 gthrd_c --> ascb__L_c + gthox_c + h_c
# GTHOm : gthox_m + h_m + nadph_m --> 2.0 gthrd_m + nadp_m
# GTHPi : 2.0 gthrd_c + h2o2_c --> gthox_c + 2.0 h2o_c
# GTHPm : 2.0 gthrd_m + h2o2_m --> gthox_m + 2.0 h2o_m
# GTHS : atp_c + glucys_c + gly_c --> adp_c + gthrd_c + h_c + pi_c
# GULLACter : gullac_c --> gullac_r
# GULN3D : guln__L_c + nad_c <=> 3dhguln_c + h_c + nadh_c
# GULNDer : glcur_r + h_r + nadph_r <=> guln__L_r + nadp_r
# GULNter : guln__L_r --> guln__L_c
# GUR1PP : glcur1p_c + h2o_c --> glcur_c + pi_c
# HCO3Em : co2_m + h2o_m --> h_m + hco3_m
# H2O2syn : h_c + nadph_c + o2_c --> h2o2_c + nadp_c
# H2O2t : h2o2_e <=> h2o2_c
# H2O2tm : h2o2_c --> h2o2_m
# H2Oter : h2o_c <=> h2o_r
# H2Otg : h2o_c <=> h2o_g
# H3MTer_U : 0.1 dolmanp_U_r + m2gacpail_hs_r --> 0.1 dolp_U_r + h_r + m3gacpail_hs_r
# H4ET3er : m3gacpail_hs_r + pe_hs_r --> dag_hs_r + em3gacpail_hs_r
# H4ETer : m3gacpail_hs_r + pe_hs_r --> dag_hs_r + m2emgacpail_hs_r
# H6ET3er : m2emgacpail_hs_r + pe_hs_r --> dag_hs_r + em2emgacpail_hs_r
# H7ET2er : em2emgacpail_hs_r + pe_hs_r --> dag_hs_r + gpi_hs_r
# HACD1x : aacoa_x + h_x + nadh_x <=> 3hbcoa_x + nad_x
# HACD9m : 3hmbcoa_m + nad_m <=> 2maacoa_m + h_m + nadh_m
# HAS1 : uacgam_c + udpglcur_c --> 2.0 h_c + ha_pre1_e + 2.0 udp_c
# HAtly : ha_e --> ha_l
# HBZOPT10m : 4hbz_m + decdp_m --> 3dphb_m + ppi_m
# HCO3_CLt : cl_c + hco3_e <=> cl_e + hco3_c
# HCOUMARINte : hcoumarin_e <=> hcoumarin_c
# HDCAt : hdca_e <=> hdca_c
# HDD2COAtx : hdd2coa_c <=> hdd2coa_x
# HESTRATRIOLte : hestratriol_c <=> hestratriol_e
# HESTRATRIOLtr : hestratriol_c <=> hestratriol_r
# HEX4 : atp_c + man_c --> adp_c + h_c + man6p_c
# HEXCt : hexc_e <=> hexc_c
# HISDC : h_c + his__L_c --> co2_c + hista_c
# HISt4 : his__L_e + na1_e --> his__L_c + na1_c
# HISTAVESSEC_1 : atp_c + h2o_c + hista_c --> adp_c + h_c + hista_e + pi_c
# HMGCOASm : coa_m + h_m + hmgcoa_m <-- aacoa_m + accoa_m + h2o_m
# HMGCOAtm : hmgcoa_c <=> hmgcoa_m
# HMGCOAtx : hmgcoa_c <=> hmgcoa_x
# HMGLm : hmgcoa_m --> acac_m + accoa_m
# HMGLx : hmgcoa_x --> acac_x + accoa_x
# HOMt4 : hom__L_e + na1_e --> hom__L_c + na1_c
# HPACtr : 4hphac_c <=> 4hphac_e
# HPDCACRNCPT1 : crn_c + hpdcacoa_c <=> coa_c + hpdcacrn_c
# HPDCACRNCPT2 : coa_m + hpdcacrn_m <=> crn_m + hpdcacoa_m
# HPYRDCm : h_m + hpyr_m --> co2_m + gcald_m
# HPYRR2x_1 : 3.0 h_c + 2.0 hpyr_c + nadh_c --> 2.0 glyc__S_c + nad_c
# HPYRtp : hpyr_c <=> hpyr_x
# HS2ly : h2o_l + hs_deg6_l --> h_l + hs_deg7_l + so4_l
# HSAT2ly : accoa_c + hs_deg7_l --> coa_c + h_l + hs_deg8_l
# HSAT3ly : accoa_c + hs_deg13_l --> coa_c + h_l + hs_deg14_l
# HSD17B42x_1 : 2.0 h_x + 2.0 nadph_x + o2_x + thcholoylcoa_x --> dhcholoylcoa_x + 3.0 h2o_x + 2.0 nadp_x
# HSD17B4x : cholcoads_x + h_x + nadph_x + o2_x --> cholcoaone_x + h2o_x + nadp_x
# HSD17B7r : estrone_r + h_r + nadph_r --> estradiol_r + nadp_r
# HSD17B8r : estrone_r + h_r + nadh_r --> estradiol_r + nad_r
# HSD17B9r : andrstrn_r + h_r + nadph_r + 1.5 o2_r --> eandrstrn_r + 2.0 h2o_r + nadp_r
# HSD3A1r : andrstandn_r + h_r + nadh_r <=> andrstrn_r + nad_r
# HSD3B11 : nad_c + prgnlone_c --> h_c + nadh_c + prgstrn_c
# HSD3B12r : dhea_r + nad_r --> andrstndn_r + h_r + nadh_r
# HSD3B13 : 17ahprgnlone_c + nad_c --> 17ahprgstrn_c + h_c + nadh_c
# HSD3B3r : eandrstrn_r + h_r + nadph_r --> andrstandn_r + h2o_r + nadp_r
# HSD3B7P : nadp_r + xol7a_r --> h_r + nadph_r + xol7aone_r
# HSPASEly : h2o_l + hspg_l --> Ser_Gly_Ala_X_Gly_l + hs_l
# HSPGt : hspg_g --> hspg_e
# HTAXOLte : htaxol_e <=> htaxol_c
# Htx : h_c <=> h_x
# HXANtx : hxan_c --> hxan_x
# HYPTROX_cho : 2.0 hyptaur_c + o2_c --> 2.0 taur_c
# ICDHyr : icit_c + nadp_c --> akg_c + co2_c + nadph_c
# ICDHyp : icit_x + nadp_x --> akg_x + co2_x + nadph_x
# ...
# 8446_AT1 is associated with reactions: {HMR_6545}
# 2173_AT1 is associated with reactions: {HMR_0270, HMR_0432, HMR_0244, HMR_0278, HMR_0203, HMR_0304, HMR_0254, HMR_0183, HMR_0292, HMR_0392, HMR_0232, HMR_0170, HMR_0208, HMR_0191, BUTt, HMR_0428, HMR_0380, HMR_0388, HMR_0240, HMR_0288, HMR_0296, HMR_0344, HMR_0326, HMR_0164, HMR_0167, HMR_0300, HMR_0308, HMR_0322, HMR_0176, HMR_0384, HMR_0436}
# 51496_AT1 is associated with reactions: {HMR_6545}
# 374462_AT1 is associated with reactions: {HMR_6545}
# 2169_AT1 is associated with reactions: {HMR_0270, HMR_0432, HMR_0244, HMR_0278, HMR_0203, HMR_0304, HMR_0254, HMR_0183, HMR_0292, HMR_0392, HMR_0232, HMR_0170, HMR_0208, HMR_0191, BUTt, HMR_0428, HMR_0380, HMR_0388, HMR_0240, HMR_0288, HMR_0296, HMR_0344, HMR_0326, HMR_0164, HMR_0167, HMR_0300, HMR_0308, HMR_0322, HMR_0176, HMR_0384, HMR_0436}
# 403313_AT1 is associated with reactions: {HMR_6545}
# 23203_AT1 is associated with reactions: {HMR_6545}
# 2171_AT1 is associated with reactions: {HMR_0270, HMR_0432, HMR_0244, HMR_0278, HMR_0203, HMR_0304, HMR_0254, HMR_0183, HMR_0292, HMR_0392, HMR_0232, HMR_0170, HMR_0208, HMR_0191, BUTt, HMR_0428, HMR_0380, HMR_0388, HMR_0240, HMR_0288, HMR_0296, HMR_0344, HMR_0326, HMR_0164, HMR_0167, HMR_0300, HMR_0308, HMR_0322, HMR_0176, HMR_0384, HMR_0436}
# 145553_AT1 is associated with reactions: {HMR_6545}
# 646480_AT1 is associated with reactions: {HMR_0270, HMR_0432, HMR_0244, HMR_0278, HMR_0203, HMR_0304, HMR_0254, HMR_0183, HMR_0292, HMR_0392, HMR_0232, HMR_0170, HMR_0208, HMR_0191, BUTt, HMR_0428, HMR_0380, HMR_0388, HMR_0240, HMR_0288, HMR_0296, HMR_0344, HMR_0326, HMR_0164, HMR_0167, HMR_0300, HMR_0308, HMR_0322, HMR_0176, HMR_0384, HMR_0436}
# 2170_AT1 is associated with reactions: {HMR_0270, HMR_0432, HMR_0244, HMR_0278, HMR_0203, HMR_0304, HMR_0254, HMR_0183, HMR_0292, HMR_0392, HMR_0232, HMR_0170, HMR_0208, HMR_0191, BUTt, HMR_0428, HMR_0380, HMR_0388, HMR_0240, HMR_0288, HMR_0296, HMR_0344, HMR_0326, HMR_0164, HMR_0167, HMR_0300, HMR_0308, HMR_0322, HMR_0176, HMR_0384, HMR_0436}
# 64419_AT1 is associated with reactions: {HMR_6545}
# 54988_AT1 is associated with reactions: {HMR_0180, HMR_0156, HMR_0168, HMR_0177, HMR_0165, HMR_0171, HMR_0184}
# 55613_AT1 is associated with reactions: {HMR_6545}
# 341392_AT1 is associated with reactions: {HMR_0180, HMR_0156, HMR_0168, HMR_0177, HMR_0165, HMR_0171, HMR_0184}
# 138639_AT1 is associated with reactions: {HMR_6545}
# 9562_AT1 is associated with reactions: {MITKP}
# 123876_AT1 is associated with reactions: {HMR_0180, HMR_0156, HMR_0168, HMR_0177, HMR_0165, HMR_0171, HMR_0184}
# 3705_AT1 is associated with reactions: {ITKPK}
# 6296_AT1 is associated with reactions: {HMR_0180, HMR_0156, HMR_0168, HMR_0177, HMR_0165, HMR_0171, HMR_0184}
# 138429_AT1 is associated with reactions: {HMR_6595, HMR_6580}
# 348158_AT1 is associated with reactions: {HMR_0180, HMR_0156, HMR_0168, HMR_0177, HMR_0165, HMR_0171, HMR_0184}
# 344967_AT1 is associated with reactions: {HMR_0394, HMR_0346, FACOAE1829Z12Z, FACOAE140, HMR_0206, HMR_0193, HMR_0362, HMR_0210, ACChex, HMR_0276, HMR_0328, HMR_0374, HMR_0214, HMR_0306, HMR_0378, HMR_0438, HMR_0426, HMR_0324, HMR_0382, HMR_0298, HMR_0390, FACOAE1839Z12Z15Z, HMR_0430, HMR_0256, HMR_0406, HMR_0418, HMR_0370, HMR_0366, HMR_0414, HMR_0422, HMR_0246, HMR_0358, HMR_0242, FACOAE1836Z9Z12Z, HMR_0310, HMR_0268, FACOAE120, HMR_0302, HMR_0238, HMR_0386, HMR_0354, HMR_0410, HMR_0201, HMR_0234, HMR_0290, HMR_0434, HMR_0272, FACOAE161, HMR_0280, HMR_0260}
# 10170_AT1 is associated with reactions: {HMR_6632}
# 9249_AT1 is associated with reactions: {HMR_6632}
# 220074_AT1 is associated with reactions: {HMR_6755}
# 51099_AT1 is associated with reactions: {HMR_0593}
# 154141_AT1 is associated with reactions: {HMR_0593}
# 1733_AT1 is associated with reactions: {HMR_6834, HMR_6826, HMR_6854}
# 253558_AT1 is associated with reactions: {HMR_0593}
# 64748_AT1 is associated with reactions: {HMR_0767, HMR_0597, HMR_0598, HMR_0601}
# 23175_AT1 is associated with reactions: {HMR_0601, HMR_0598, HMR_0597, HMR_0767, SBPP3}
# 1735_AT1 is associated with reactions: {HMR_6826}
# 1734_AT1 is associated with reactions: {HMR_6834, HMR_6826, HMR_6854}
# 27284_AT1 is associated with reactions: {HMR_6850, HMR_6838, HMR_6844}
# 6819_AT1 is associated with reactions: {HMR_6850, HMR_6838, HMR_6844}
# 84513_AT1 is associated with reactions: {HMR_0767, HMR_0597, HMR_0598, HMR_0601}
# 79948_AT1 is associated with reactions: {HMR_0767, HMR_0597, HMR_0598, HMR_0601}
# 84274_AT1 is associated with reactions: {HMR_6908}
# 9890_AT1 is associated with reactions: {HMR_0767, HMR_0597, HMR_0598, HMR_0601}
# 84787_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 79813_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 64900_AT1 is associated with reactions: {HMR_0601, HMR_0598, HMR_0597, HMR_0767, SBPP3}
# 9663_AT1 is associated with reactions: {HMR_0601, HMR_0598, HMR_0597, HMR_0767, SBPP3}
# 9757_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 196051_AT1 is associated with reactions: {HMR_0767, HMR_0597, HMR_0598, HMR_0601}
# 9869_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 85465_AT1 is associated with reactions: {HMR_0614}
# 23646_AT1 is associated with reactions: {HMR_0642, HMR_0629}
# 122618_AT1 is associated with reactions: {HMR_0642, HMR_0629}
# 29072_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 201164_AT1 is associated with reactions: {HMR_0629}
# 590_AT1 is associated with reactions: {HMR_0641}
# 80854_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 55750_AT1 is associated with reactions: {HMR_0678}
# 387893_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 84444_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 4297_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 91012_AT1 is associated with reactions: {HMR_0750, HMR_0758}
# 204219_AT1 is associated with reactions: {HMR_0750, HMR_0758}
# 10715_AT1 is associated with reactions: {HMR_0750, HMR_0758}
# 58508_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 253782_AT1 is associated with reactions: {HMR_0750, HMR_0758}
# 55870_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 29956_AT1 is associated with reactions: {HMR_0750, HMR_0758}
# 10919_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 6839_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 79603_AT1 is associated with reactions: {HMR_0750, HMR_0758}
# 64324_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 56624_AT1 is associated with reactions: {HMR_0753}
# 6419_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 170384_AT1 is associated with reactions: {HMR_0765}
# 23067_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 56886_AT1 is associated with reactions: {HMR_0765}
# 54904_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 2526_AT1 is associated with reactions: {HMR_0765, HMR_0878, HMR_0911}
# 152586_AT1 is associated with reactions: {HMR_0765}
# 148789_AT1 is associated with reactions: {HMR_0765}
# 200810_AT1 is associated with reactions: {HMR_0765}
# 55624_AT1 is associated with reactions: {HMR_0765}
# 64754_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 56983_AT1 is associated with reactions: {HMR_0765}
# 79723_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 644378_AT1 is associated with reactions: {HMR_0765}
# 55904_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 644974_AT1 is associated with reactions: {HMR_0765}
# 8702_AT1 is associated with reactions: {HMR_0890, HMR_0765, HMR_0875}
# 9739_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 8473_AT1 is associated with reactions: {HMR_0765}
# 55830_AT1 is associated with reactions: {HMR_0765}
# 7468_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 3703_AT1 is associated with reactions: {HMR_0765}
# 83852_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 8085_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 283358_AT1 is associated with reactions: {HMR_0765}
# 51111_AT1 is associated with reactions: {HMR_6976, HMR_6977, HMR_6975}
# 55757_AT1 is associated with reactions: {HMR_0765}
# 60559_AT1 is associated with reactions: {HMR_6978}
# 23478_AT1 is associated with reactions: {HMR_6978}
# 146664_AT1 is associated with reactions: {HMR_0765}
# 28972_AT1 is associated with reactions: {HMR_6978}
# 2529_AT1 is associated with reactions: {HMR_0765, HMR_0878}
# 360203_AT1 is associated with reactions: {HMR_0765}
# 90701_AT1 is associated with reactions: {HMR_6978}
# 9789_AT1 is associated with reactions: {HMR_6978}
# 57171_AT1 is associated with reactions: {HMR_7256}
# 4249_AT1 is associated with reactions: {HMR_7328}
# 25834_AT1 is associated with reactions: {HMR_7329}
# 7837_AT1 is associated with reactions: {HMR_7628}
# 140687_AT1 is associated with reactions: {HMR_0765}
# 137902_AT1 is associated with reactions: {HMR_7628}
# 8708_AT1 is associated with reactions: {HMR_0765, HMR_0860}
# 9677_AT1 is associated with reactions: {PMI12346PS}
# 23262_AT1 is associated with reactions: {PMI12346PS}
# 201595_AT1 is associated with reactions: {HMR_0765}
# 26007_AT1 is associated with reactions: {HMR_7755}
# 83468_AT1 is associated with reactions: {HMR_0765}
# 158584_AT1 is associated with reactions: {HMR_7756}
# 84752_AT1 is associated with reactions: {HMR_0765}
# 283209_AT1 is associated with reactions: {HMR_8585}
# 145173_AT1 is associated with reactions: {HMR_0765}
# 23491_AT1 is associated with reactions: {HMR_8643}
# 124872_AT1 is associated with reactions: {HMR_0765}
# 84750_AT1 is associated with reactions: {HMR_0765}
# 221223_AT1 is associated with reactions: {HMR_8643}
# 338707_AT1 is associated with reactions: {HMR_0765}
# 1066_AT1 is associated with reactions: {HMR_8643}
# 1208_AT1 is associated with reactions: {HMR_9561}
# 146802_AT1 is associated with reactions: {HMR_9582, HMR_9584, HMR_9619}
# 168391_AT1 is associated with reactions: {HMR_0765}
# 55244_AT1 is associated with reactions: {HMR_9582, HMR_9584, HMR_9619}
# 345274_AT1 is associated with reactions: {HMR_9621}
# 116085_AT1 is associated with reactions: {HMR_9622}
# 8707_AT1 is associated with reactions: {HMR_0765, HMR_0860}
# 123688_AT1 is associated with reactions: {HMR_9801}
# 51228_AT1 is associated with reactions: {HMR_0770}
# 51171_AT1 is associated with reactions: {HMR_9804}
# 284004_AT1 is associated with reactions: {HMR_0836, HMR_0828, HMR_0807, HMR_0821, HMR_0808}
# 79411_AT1 is associated with reactions: {HMR_0830, HMR_0819}
# 51741_AT1 is associated with reactions: {HMR_9804}
# 27090_AT1 is associated with reactions: {HMR_0823}
# 129807_AT1 is associated with reactions: {HMR_0825, HMR_0847}
# 441282_AT1 is associated with reactions: {HMR_9804}
# 2524_AT1 is associated with reactions: {HMR_0864, HMR_0908, HMR_0909}
# 10202_AT1 is associated with reactions: {HMR_9804}
# 2527_AT1 is associated with reactions: {HMR_0873, HMR_8271, HMR_0911, HMR_0870}
# 10553_AT1 is associated with reactions: {HMR_9804}
# 121214_AT1 is associated with reactions: {HMR_9804}
# 374875_AT1 is associated with reactions: {HMR_9804}
# 2528_AT1 is associated with reactions: {HMR_0873, HMR_8271, HMR_0911, HMR_0870}
# 113612_AT1 is associated with reactions: {HMR_0942, HMR_2457, HMR_0946, HMR_0950, HMR_0954, HMR_2029}
# 56898_AT1 is associated with reactions: {HMR_9804}
# 493869_AT1 is associated with reactions: {HMR_0960, HMR_0963}
# 1487_AT1 is associated with reactions: {HMR_9804}
# 64174_AT1 is associated with reactions: {HMR_1085}
# 100288072_AT1 is associated with reactions: {HMR_9804}
# 64180_AT1 is associated with reactions: {HMR_1085}
# 93517_AT1 is associated with reactions: {HMR_9804}
# 10728_AT1 is associated with reactions: {PGESc}
# 84869_AT1 is associated with reactions: {HMR_9804}
# 340811_AT1 is associated with reactions: {HMR_9804}
# 91179_AT1 is associated with reactions: {HMR_1321}
# 133121_AT1 is associated with reactions: {HMR_9805}
# 11102_AT1 is associated with reactions: {HMR_1321}
# 85007_AT1 is associated with reactions: {HMR_9807}
# 250_AT1 is associated with reactions: {HMR_4816}
# 8644_AT1 is associated with reactions: {HMR_2018, HMR_1325, HMR_2016, HMR_1329}
# 10826_AT1 is associated with reactions: {HMR_1548, HMR_1504, HMR_1490, HMR_1549, HMR_1494, HMR_1543, HMR_1544, HMR_1550, HMR_1493, HMR_1545, HMR_1502, HMR_1503}
# 251_AT1 is associated with reactions: {HMR_4816}
# 266740_AT1 is associated with reactions: {HMR_1495}
# 200931_AT1 is associated with reactions: {UDCHOLt, 7DHCDCHOLt, ISOCHOLt, 3DHLCAt, HYOCHOLt, ICDCHOLt, UCHOLt, 7DHCHOLt, 3DHCHOLt, THYOCHOLt, 3DHDCAt, 3DHCDCHOLt, COPROSTt, 12DHCHOLt}
# 3930_AT1 is associated with reactions: {HMR_1540, C14STR}
# 123264_AT1 is associated with reactions: {UDCHOLt, 7DHCDCHOLt, ISOCHOLt, 3DHLCAt, HYOCHOLt, ICDCHOLt, UCHOLt, 7DHCHOLt, 3DHCHOLt, THYOCHOLt, 3DHDCAt, 3DHCDCHOLt, COPROSTt, 12DHCHOLt}
# 10941_AT1 is associated with reactions: {HDCA24GSr, LCA24GSr, DCA24GSr, CA24GSr, DCA3GSc, CDCA3GSr, HCA24GSc, LCA3GSr, HDCA6GSr, LCA24GSc, HCA24GSr, DCA24GSc, LCA3GSc, DCA3GSr, HDCA6GSc, CA24GSc, CDCA3GSc, CDCA24GSc, HDCA24GSc, CDCA24GSr}
# 79799_AT1 is associated with reactions: {HDCA24GSr, LCA24GSr, HCA24GSc, LCA3GSr, HDCA6GSr, LCA24GSc, HCA24GSr, LCA3GSc, HDCA6GSc, CDCA3GSc, CDCA24GSc, HDCA24GSc, CDCA24GSr, CDCA3GSr}
# 4645_AT1 is associated with reactions: {HMR_3329, HMR_3505, HMR_3353, HMR_3101, HMR_1653, HMR_3069, HMR_3333, HMR_3097, HMR_3065, HMR_3341, HMR_3349, HMR_3345, HMR_3337, HMR_3073}
# 5446_AT1 is associated with reactions: {6HMSMVACIDhep, LVSTACIDhep, 3HLVSTAChep, 2HATVACIDhc, 3HSMVACIDhep, 4HATVACIDhc, SMVHYDROhep, ATVACIDhc, 6CSMVACIDhep, RSVSPONhc, 6MELACAChep, 6HSMVACIDhep, PTVSThc, 6HLVSTAChep}
# 4864_AT1 is associated with reactions: {HMR_1916}
# 506_AT1 is associated with reactions: {ATPS4mi}
# 3069_AT1 is associated with reactions: {HMR_1916}
# 10632_AT1 is associated with reactions: {ATPS4mi}
# 515_AT2 is associated with reactions: {ATPS4mi}
# 10476_AT1 is associated with reactions: {ATPS4mi}
# 513_AT1 is associated with reactions: {ATPS4mi}
# 522_AT1 is associated with reactions: {ATPS4mi}
# 539_AT1 is associated with reactions: {ATPS4mi}
# 9551_AT1 is associated with reactions: {ATPS4mi}
# 516_AT2 is associated with reactions: {ATPS4mi}
# 9551_AT3 is associated with reactions: {ATPS4mi}
# 509_AT1 is associated with reactions: {ATPS4mi}
# 518_AT3 is associated with reactions: {ATPS4mi}
# 27109_AT1 is associated with reactions: {ATPS4mi}
# 518_AT2 is associated with reactions: {ATPS4mi}
# 514_AT2 is associated with reactions: {ATPS4mi}
# 513_AT2 is associated with reactions: {ATPS4mi}
# 4905_AT1 is associated with reactions: {ATPS4mi}
# 515_AT3 is associated with reactions: {ATPS4mi}
# 517_AT2 is associated with reactions: {ATPS4mi}
# 521_AT1 is associated with reactions: {ATPS4mi}
# 509_AT2 is associated with reactions: {ATPS4mi}
# 10476_AT2 is associated with reactions: {ATPS4mi}
# 517_AT1 is associated with reactions: {ATPS4mi}
# 515_AT1 is associated with reactions: {ATPS4mi}
# 522_AT5 is associated with reactions: {ATPS4mi}
# 516_AT1 is associated with reactions: {ATPS4mi}
# 498_AT3 is associated with reactions: {ATPS4mi}
# 267020_AT1 is associated with reactions: {ATPS4mi}
# 522_AT3 is associated with reactions: {ATPS4mi}
# 498_AT1 is associated with reactions: {ATPS4mi}
# 498_AT2 is associated with reactions: {ATPS4mi}
# 518_AT1 is associated with reactions: {ATPS4mi}
# 514_AT1 is associated with reactions: {ATPS4mi}
# 522_AT2 is associated with reactions: {ATPS4mi}
# 9551_AT2 is associated with reactions: {ATPS4mi}
# 522_AT4 is associated with reactions: {ATPS4mi}
# 27089_AT1 is associated with reactions: {CYOOm2i, CYOR_u10mi}
# 10975_AT1 is associated with reactions: {CYOOm2i, CYOR_u10mi}
# 7381_AT1 is associated with reactions: {CYOOm2i, CYOR_u10mi}
# 29796_AT1 is associated with reactions: {CYOOm2i, CYOR_u10mi}
# 4519_AT1 is associated with reactions: {CYOOm2i, CYOR_u10mi}

# %%
#Guardar nuevo modelo con las 6rx necesarias para promover acetilación
cobra.io.write_sbml_model(model, "recon3d_6rx.xml")
