# %%
#Librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Cargar archivos con pandas
df_RNA=pd.read_csv("/home/bguzman/jupyter/UI/YMC/data/kuangRNAseq.txt", sep="\t",index_col=0)
df_OX= pd.read_csv("/home/bguzman/jupyter/UI/YMC/data/kuangOX.txt", sep="\t")
df_RB= pd.read_csv("/home/bguzman/jupyter/UI/YMC/data/kuangRB.txt", sep="\t")
df_RC= pd.read_csv("/home/bguzman/jupyter/UI/YMC/data/kuangRC.txt", sep="\t")

# %%
#Dejar solo las columnas de RNA-seq y excluir las de microarrays
df_RNA2=df_RNA.iloc[0:-2,-16::]

# %%
#Dejar solo los id de los genes
df_OX.iloc[0:-2,0] 
df_RB.iloc[0:-2,0] 
df_RC.iloc[0:-2,0]
# Out:
# 0         YLR208W
# 1         YKL196C
# 2         YOR102W
# 3         YLR424W
# 4         YJR161C
#           ...
# 1476    YCR024C-A
# 1477      YLL028W
# 1478      YPL193W
# 1479      YOR355W
# 1480      YGL015C
# Name: Systematic names, Length: 1481, dtype: object

# %%
#Definir listas
lista_RC=list(df_RC.iloc[0:-2,0])
lista_OX=list(df_OX.iloc[0:-2,0])
lista_RB=list(df_RB.iloc[0:-2,0])

# %%
df_RNA2.loc[lista_RB]
# Out:
#             RNAseq1   RNAseq2   RNAseq3   RNAseq4   RNAseq5   RNAseq6  \
# Gene name
# YDL003W   -0.924238 -0.573881 -0.603335 -0.493881  0.024683  1.226503
# YGL162W   -1.120432 -0.406534  0.269766  0.827700  2.113171 -0.261822
# YER016W   -1.168175 -0.717909 -0.445448 -0.503637  0.122711  0.590908
# YLL062C   -1.149541 -0.797456 -0.216315  0.588044 -0.291875  1.945945
# YOR073W   -0.746342 -0.170704 -0.398429 -0.420763 -0.477114 -0.856484
# ...             ...       ...       ...       ...       ...       ...
# YHL048W    0.630441  0.040198  0.230995 -2.465590 -2.465590  0.366530
# YGL259W   -0.544149 -0.146154  0.253270 -3.213195 -0.544149 -0.544149
# YGL259W   -0.544149 -0.146154  0.253270 -3.213195 -0.544149 -0.544149
# YGL259W   -0.544149 -0.146154  0.253270 -3.213195 -0.544149 -0.544149
# YGL259W   -0.544149 -0.146154  0.253270 -3.213195 -0.544149 -0.544149
#
#             RNAseq7   RNAseq8   RNAseq9  RNAseq10  RNAseq11  RNAseq12  \
# Gene name
# ...

# %%
#Genes etapa RC
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi2=df_RNA2.loc[lista_RC]
ax=sns.clustermap(dfi2, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#Genes etapa OX
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi2=df_RNA2.loc[lista_OX]
ax=sns.clustermap(dfi2, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#Genes etapa RC
#f, ax = plt.subplots(figsize=(14, 10))
dfi2=df_RNA2.loc[lista_RB]
ax=sns.clustermap(dfi2, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#cargar df que contiene intensidad de las marcas H3K9ac y H3K4me3
df_ac=pd.read_csv("/home/bguzman/jupyter/UI/YMC/analysis/dfi_T_all_ac.csv", index_col=0)
df_me=pd.read_csv("/home/bguzman/jupyter/UI/YMC/analysis/dfi_T_all.csv", index_col=0)

# %%
len(lista_RC)
# Out:
# 1481

# %%
#Relacionar listas RC, OX, RB con df de las marcas H3K9ac y H3K4me3
df_RC_ac=df_ac.loc[lista_RC]
df_RC_me=df_me.loc[lista_RC]
df_OX_ac=df_ac.loc[lista_OX]
df_OX_me=df_me.loc[lista_OX]
df_RB_ac=df_ac.loc[lista_RB]
df_RB_me=df_me.loc[lista_RB]

# %%
len(df_RC_ac)
# Out:
# 1481

# %%
#Realizar heatmap
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi_norm_row = df_RC_ac.apply(lambda x: (x-x.mean())/x.std(), axis = 1)
ax=sns.clustermap(dfi_norm_row, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#Realizar heatmap
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi2_norm_row = df_OX_ac.apply(lambda x: (x-x.mean())/x.std(), axis = 1)
ax=sns.clustermap(dfi2_norm_row, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#Realizar heatmap
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi3_norm_row = df_RB_ac.apply(lambda x: (x-x.mean())/x.std(), axis = 1)
ax=sns.clustermap(dfi3_norm_row, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#Realizar heatmap
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi4_norm_row = df_RC_me.apply(lambda x: (x-x.mean())/x.std(), axis = 1)
ax=sns.clustermap(dfi4_norm_row, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#Realizar heatmap
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi5_norm_row = df_OX_me.apply(lambda x: (x-x.mean())/x.std(), axis = 1)
ax=sns.clustermap(dfi5_norm_row, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()

# %%
#Realizar heatmap
#f, ax = plt.subplots(figsize=(14, 10))
# Normalize it by row:
dfi6_norm_row = df_RB_me.apply(lambda x: (x-x.mean())/x.std(), axis = 1)
ax=sns.clustermap(dfi6_norm_row, cmap=sns.color_palette("coolwarm", as_cmap=True),col_cluster=False
)

#ax.set(xlabel="Tiempo", ylabel="Genes")
#ax.xaxis.tick_top()
